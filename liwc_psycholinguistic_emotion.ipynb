# %%
import pandas as pd

# %%
class DatasetConfig():
    input_path: str
    output_path: str
    sheet_name: str
    usecols: list[str]
    save_cols: list[str]
    id_col: str

    def __init__(self, input_path: str, output_path: str, sheet_name: str, usecols: list[str], save_cols: list[str], id_col: str):
        self.input_path = input_path
        self.output_path = output_path
        self.sheet_name = sheet_name
        self.usecols = usecols
        self.save_cols = save_cols
        self.id_col = id_col

# %%
fakespeak_config = DatasetConfig(
    input_path="./data/Fakespeak-ENG/Fakespeak-ENG modified.xlsx",
    output_path="./data/Fakespeak-ENG/Analysis_output/Fakespeak_liwc.xlsx",
    sheet_name="Working",
    usecols=['ID', 'combinedLabel', 'originalTextType', 'originalBodyText', 'originalDateYear'],
    save_cols=["ID", "originalBodyText"],
    id_col="ID"
)

misinfotext_config = DatasetConfig(
    input_path="./data/MisInfoText/PolitiFact_original_modified.xlsx",
    output_path="./data/MisInfoText/Analysis_output/MisInfoText_liwc.xlsx",
    sheet_name="Working",
    usecols=None,
    save_cols=["factcheckURL", "originalBodyText"],
    id_col="factcheckURL"
)

# %%
using_dataset = misinfotext_config

# %%
dataset_df = pd.read_excel(
    using_dataset.input_path, 
    sheet_name=using_dataset.sheet_name, 
    usecols=using_dataset.usecols
)

# %%
dataset_df.head()
# Out:
#                                         factcheckURL  \
# 0  http://www.politifact.com/arizona/statements/2...
# 1  http://www.politifact.com/california/statement...
# 2  http://www.politifact.com/california/statement...
# 3  http://www.politifact.com/california/statement...
# 4  http://www.politifact.com/california/statement...
#
#                                          originalURL  \
# 0  https://associatedmediacoverage.com/three-stat...
# 1  https://users.focalbeam.com/fs/distribution:wl...
# 2  http://www.sacbee.com/opinion/op-ed/soapbox/ar...
# 3  https://nocagastax.com/california-gas-tax-hike...
# 4  https://chu.house.gov/media-center/press-relea...
#
#                                     originalBodyText  \
# 0  Residents of multiple states will be asked to ...
# 1  Sacramento, CA - United States Senator Dianne ...
# 2  We should anticipate black and gray markets in...
# 3  As a ballot initiative calling for repeal of a...
# 4  WASHINGTON, DC  The House of Representatives t...
#
#                                     originalHeadline originalTextType  \
# 0  Multiple States Have Agreed To Implement A ‘Tw...    News and blog
# 1  U.S. Senator Dianne Feinstein Opposes Prop. 64...    Press release
# 2          Why you should buy a locking gasoline cap    News and blog
# 3   California Gas-Tax-Hike Repeal Campaign Heats Up    News and blog
# 4       Rep. Chu Decries "Heartless" ACA Repeal Vote    Press release
#
#   originalDate  originalDateYear
# 0   2016-05-06              2016
# 1   2016-07-12              2016
# 2   2017-08-04              2017
# 3   2017-06-15              2017
# 4   2017-05-04              2017

# %%
dataset_name = using_dataset.input_path.split('/')[2]
data_for_liwc = dataset_df[[using_dataset.id_col, "originalBodyText"]]
data_for_liwc.to_csv(f"./{dataset_name}_for_liwc.csv", index=False)

# %% [markdown]
# Now that you've run the above, use the generated file as input for LIWC

# %% [markdown]
# Then, we will take the file generated by LIWC and continue with the analysis

# %%
liwc_file = "./MisInfoText_liwc_results.csv"
liwc_df = pd.read_csv(liwc_file)
liwc_df
# Out:
#                                           factcheckURL  Segment   WC  \
# 0    http://www.politifact.com/arizona/statements/2...        1  481
# 1    http://www.politifact.com/california/statement...        1  184
# 2    http://www.politifact.com/california/statement...        1  339
# 3    http://www.politifact.com/california/statement...        1  433
# 4    http://www.politifact.com/california/statement...        1  670
# ..                                                 ...      ...  ...
# 650  http://www.politifact.com/wisconsin/statements...        1   27
# 651  http://www.politifact.com/wisconsin/statements...        1   44
# 652  http://www.politifact.com/wisconsin/statements...        1   47
# 653  http://www.politifact.com/wisconsin/statements...        1  573
# 654  http://www.politifact.com/wisconsin/statements...        1  337
#
#      Analytic  Clout  Authentic   Tone    WPS  BigWords    Dic  ...  nonflu  \
# 0       96.43  82.60      16.18  45.23  28.29     29.31  82.12  ...     0.0
# 1       93.86  71.47       7.87   6.28  20.44     38.59  78.80  ...     0.0
# 2       93.61  31.80      42.71  20.23  16.95     25.37  79.35  ...     0.0
# 3       89.52  45.52      28.63  23.14  22.79     21.02  79.21  ...     0.0
# 4       89.11  56.98      18.27  22.08  23.93     28.51  83.28  ...     0.0
# ..        ...    ...        ...    ...    ...       ...    ...  ...     ...
# 650     99.00  40.06      52.89  99.00  27.00     22.22  85.19  ...     0.0
# 651     45.12  99.00      66.42   1.00  14.67     20.45  90.91  ...     0.0
# 652      4.97  84.86      91.07   4.04  15.67     25.53  87.23  ...     0.0
# 653     84.56  73.09       8.76  72.20  26.05     25.48  83.77  ...     0.0
# 654     94.67  72.49      29.38   4.25  18.72     28.78  77.74  ...     0.0
#
#      filler  AllPunc  Period  Comma  QMark  Exclam  Apostro  OtherP  Emoji
# 0       0.0    14.76    3.53   6.65    0.0     0.0     1.04    3.53    0.0
# 1       0.0    14.67    4.35   3.80    0.0     0.0     1.09    5.43    0.0
# 2       0.0    18.88    6.78   5.60    0.0     0.0     1.77    4.72    0.0
# 3       0.0    13.63    4.39   6.47    0.0     0.0     0.00    2.77    0.0
# 4       0.0    13.73    4.48   5.37    0.0     0.0     0.30    3.58    0.0
# ..      ...      ...     ...    ...    ...     ...      ...     ...    ...
# 650     0.0     3.70    3.70   0.00    0.0     0.0     0.00    0.00    0.0
# 651     0.0    15.91    6.82   2.27    0.0     0.0     0.00    6.82    0.0
# 652     0.0    23.40    6.38   4.26    0.0     0.0     6.38    6.38    0.0
# 653     0.0    11.17    4.54   4.89    0.0     0.0     0.00    1.75    0.0
# 654     0.0     9.20    5.34   2.97    0.0     0.0     0.30    0.59    0.0
#
# [655 rows x 120 columns]

# %%
full_df = dataset_df.set_index(using_dataset.id_col).join(liwc_df.set_index(using_dataset.id_col))
full_df
# Out:
#                                                                                           originalURL  \
# factcheckURL
# http://www.politifact.com/arizona/statements/20...  https://associatedmediacoverage.com/three-stat...
# http://www.politifact.com/california/statements...  https://users.focalbeam.com/fs/distribution:wl...
# http://www.politifact.com/california/statements...  http://www.sacbee.com/opinion/op-ed/soapbox/ar...
# http://www.politifact.com/california/statements...  https://nocagastax.com/california-gas-tax-hike...
# http://www.politifact.com/california/statements...  https://chu.house.gov/media-center/press-relea...
# ...                                                                                               ...
# http://www.politifact.com/wisconsin/statements/...  https://x.com/ScottWalker/status/9428776407421...
# http://www.politifact.com/wisconsin/statements/...  https://x.com/ScottWalker/status/9511017961011...
# http://www.politifact.com/wisconsin/statements/...  https://x.com/MahlonMitchell/status/9538161542...
# http://www.politifact.com/wisconsin/statements/...  http://dailycaller.com/2018/01/25/hey-look-sen...
# http://www.politifact.com/wisconsin/statements/...                     https://mahlonmitchell.com/bio
#
#                                                                                      originalBodyText  \
# factcheckURL
# http://www.politifact.com/arizona/statements/20...  Residents of multiple states will be asked to ...
# http://www.politifact.com/california/statements...  Sacramento, CA - United States Senator Dianne ...
# http://www.politifact.com/california/statements...  We should anticipate black and gray markets in...
# http://www.politifact.com/california/statements...  As a ballot initiative calling for repeal of a...
# http://www.politifact.com/california/statements...  WASHINGTON, DC  The House of Representatives t...
# ...                                                                                               ...
# http://www.politifact.com/wisconsin/statements/...  Road projects across the state are staying on ...
# http://www.politifact.com/wisconsin/statements/...  The last thing we need is more Madison in our ...
# http://www.politifact.com/wisconsin/statements/...  When \n@ScottWalker\n told firefighters we did...
# http://www.politifact.com/wisconsin/statements/...  Now that its 2018, an election year, I would l...
# http://www.politifact.com/wisconsin/statements/...  Mahlon Mitchell currently serves as President ...
#
#                                                                                      originalHeadline  \
# factcheckURL
# http://www.politifact.com/arizona/statements/20...  Multiple States Have Agreed To Implement A ‘Tw...
# http://www.politifact.com/california/statements...  U.S. Senator Dianne Feinstein Opposes Prop. 64...
# http://www.politifact.com/california/statements...          Why you should buy a locking gasoline cap
# http://www.politifact.com/california/statements...   California Gas-Tax-Hike Repeal Campaign Heats Up
# http://www.politifact.com/california/statements...       Rep. Chu Decries "Heartless" ACA Repeal Vote
# ...                                                                                               ...
# http://www.politifact.com/wisconsin/statements/...                                                NaN
# http://www.politifact.com/wisconsin/statements/...                                                NaN
# http://www.politifact.com/wisconsin/statements/...                                                NaN
# http://www.politifact.com/wisconsin/statements/...  HEY LOOK! Senator Tammy Baldwin Is Back In Wis...
# http://www.politifact.com/wisconsin/statements/...                       Mahlon Mitchell for Governor
#
#                                                    originalTextType  \
# factcheckURL
# http://www.politifact.com/arizona/statements/20...    News and blog
# http://www.politifact.com/california/statements...    Press release
# http://www.politifact.com/california/statements...    News and blog
# http://www.politifact.com/california/statements...    News and blog
# http://www.politifact.com/california/statements...    Press release
# ...                                                             ...
# http://www.politifact.com/wisconsin/statements/...     Social media
# http://www.politifact.com/wisconsin/statements/...     Social media
# http://www.politifact.com/wisconsin/statements/...     Social media
# http://www.politifact.com/wisconsin/statements/...    News and blog
# http://www.politifact.com/wisconsin/statements/...    Press release
#
#                                                    originalDate  \
# factcheckURL
# http://www.politifact.com/arizona/statements/20...   2016-05-06
# http://www.politifact.com/california/statements...   2016-07-12
# http://www.politifact.com/california/statements...   2017-08-04
# http://www.politifact.com/california/statements...   2017-06-15
# http://www.politifact.com/california/statements...   2017-05-04
# ...                                                         ...
# http://www.politifact.com/wisconsin/statements/...   2017-12-18
# http://www.politifact.com/wisconsin/statements/...   2018-01-10
# http://www.politifact.com/wisconsin/statements/...   2018-01-18
# http://www.politifact.com/wisconsin/statements/...   2018-01-25
# http://www.politifact.com/wisconsin/statements/...   2018-04-30
#
#                                                     originalDateYear  Segment  \
# factcheckURL
# http://www.politifact.com/arizona/statements/20...              2016        1
# http://www.politifact.com/california/statements...              2016        1
# http://www.politifact.com/california/statements...              2017        1
# http://www.politifact.com/california/statements...              2017        1
# http://www.politifact.com/california/statements...              2017        1
# ...                                                              ...      ...
# http://www.politifact.com/wisconsin/statements/...              2017        1
# http://www.politifact.com/wisconsin/statements/...              2018        1
# http://www.politifact.com/wisconsin/statements/...              2018        1
# http://www.politifact.com/wisconsin/statements/...              2018        1
# http://www.politifact.com/wisconsin/statements/...              2018        1
#
#                                                      WC  Analytic  Clout  ...  \
# factcheckURL                                                              ...
# http://www.politifact.com/arizona/statements/20...  481     96.43  82.60  ...
# http://www.politifact.com/california/statements...  184     93.86  71.47  ...
# http://www.politifact.com/california/statements...  339     93.61  31.80  ...
# http://www.politifact.com/california/statements...  433     89.52  45.52  ...
# http://www.politifact.com/california/statements...  670     89.11  56.98  ...
# ...                                                 ...       ...    ...  ...
# http://www.politifact.com/wisconsin/statements/...   27     99.00  40.06  ...
# http://www.politifact.com/wisconsin/statements/...   44     45.12  99.00  ...
# http://www.politifact.com/wisconsin/statements/...   47      4.97  84.86  ...
# http://www.politifact.com/wisconsin/statements/...  573     84.56  73.09  ...
# http://www.politifact.com/wisconsin/statements/...  337     94.67  72.49  ...
#
#                                                     nonflu  filler  AllPunc  \
# factcheckURL
# http://www.politifact.com/arizona/statements/20...     0.0     0.0    14.76
# http://www.politifact.com/california/statements...     0.0     0.0    14.67
# http://www.politifact.com/california/statements...     0.0     0.0    18.88
# http://www.politifact.com/california/statements...     0.0     0.0    13.63
# http://www.politifact.com/california/statements...     0.0     0.0    13.73
# ...                                                    ...     ...      ...
# http://www.politifact.com/wisconsin/statements/...     0.0     0.0     3.70
# http://www.politifact.com/wisconsin/statements/...     0.0     0.0    15.91
# http://www.politifact.com/wisconsin/statements/...     0.0     0.0    23.40
# http://www.politifact.com/wisconsin/statements/...     0.0     0.0    11.17
# http://www.politifact.com/wisconsin/statements/...     0.0     0.0     9.20
#
#                                                     Period  Comma  QMark  \
# factcheckURL
# http://www.politifact.com/arizona/statements/20...    3.53   6.65    0.0
# http://www.politifact.com/california/statements...    4.35   3.80    0.0
# http://www.politifact.com/california/statements...    6.78   5.60    0.0
# http://www.politifact.com/california/statements...    4.39   6.47    0.0
# http://www.politifact.com/california/statements...    4.48   5.37    0.0
# ...                                                    ...    ...    ...
# http://www.politifact.com/wisconsin/statements/...    3.70   0.00    0.0
# http://www.politifact.com/wisconsin/statements/...    6.82   2.27    0.0
# http://www.politifact.com/wisconsin/statements/...    6.38   4.26    0.0
# http://www.politifact.com/wisconsin/statements/...    4.54   4.89    0.0
# http://www.politifact.com/wisconsin/statements/...    5.34   2.97    0.0
#
#                                                     Exclam  Apostro  OtherP  \
# factcheckURL
# http://www.politifact.com/arizona/statements/20...     0.0     1.04    3.53
# http://www.politifact.com/california/statements...     0.0     1.09    5.43
# http://www.politifact.com/california/statements...     0.0     1.77    4.72
# http://www.politifact.com/california/statements...     0.0     0.00    2.77
# http://www.politifact.com/california/statements...     0.0     0.30    3.58
# ...                                                    ...      ...     ...
# http://www.politifact.com/wisconsin/statements/...     0.0     0.00    0.00
# http://www.politifact.com/wisconsin/statements/...     0.0     0.00    6.82
# http://www.politifact.com/wisconsin/statements/...     0.0     6.38    6.38
# http://www.politifact.com/wisconsin/statements/...     0.0     0.00    1.75
# http://www.politifact.com/wisconsin/statements/...     0.0     0.30    0.59
#
#                                                     Emoji
# factcheckURL
# http://www.politifact.com/arizona/statements/20...    0.0
# http://www.politifact.com/california/statements...    0.0
# http://www.politifact.com/california/statements...    0.0
# http://www.politifact.com/california/statements...    0.0
# http://www.politifact.com/california/statements...    0.0
# ...                                                   ...
# http://www.politifact.com/wisconsin/statements/...    0.0
# http://www.politifact.com/wisconsin/statements/...    0.0
# http://www.politifact.com/wisconsin/statements/...    0.0
# http://www.politifact.com/wisconsin/statements/...    0.0
# http://www.politifact.com/wisconsin/statements/...    0.0
#
# [655 rows x 125 columns]

# %%
grouped_by_year = full_df.groupby(by="originalDateYear")
years = grouped_by_year.groups
years_dfs = [grouped_by_year.get_group(year) for year in years]
years_dfs[0].head()
# Out:
#                                                                                           originalURL  \
# factcheckURL
# http://www.politifact.com/truth-o-meter/stateme...  https://www.johnmccain.com/Informing/News/Pres...
#
#                                                                                      originalBodyText  \
# factcheckURL
# http://www.politifact.com/truth-o-meter/stateme...  "On Monday, Senator Clinton told an audience a...
#
#                                                                                originalHeadline  \
# factcheckURL
# http://www.politifact.com/truth-o-meter/stateme...  Statement By John McCain on Hillary Clinton
#
#                                                    originalTextType  \
# factcheckURL
# http://www.politifact.com/truth-o-meter/stateme...    Press release
#
#                                                    originalDate  \
# factcheckURL
# http://www.politifact.com/truth-o-meter/stateme...   2007-08-23
#
#                                                     originalDateYear  Segment  \
# factcheckURL
# http://www.politifact.com/truth-o-meter/stateme...              2007        1
#
#                                                      WC  Analytic  Clout  ...  \
# factcheckURL                                                              ...
# http://www.politifact.com/truth-o-meter/stateme...  125     97.24  97.21  ...
#
#                                                     nonflu  filler  AllPunc  \
# factcheckURL
# http://www.politifact.com/truth-o-meter/stateme...     0.0     0.0     17.6
#
#                                                     Period  Comma  QMark  \
# factcheckURL
# http://www.politifact.com/truth-o-meter/stateme...     5.6    2.4    0.0
#
#                                                     Exclam  Apostro  OtherP  \
# factcheckURL
# http://www.politifact.com/truth-o-meter/stateme...     0.0      6.4     3.2
#
#                                                     Emoji
# factcheckURL
# http://www.politifact.com/truth-o-meter/stateme...    0.0
#
# [1 rows x 125 columns]

# %%
writer = pd.ExcelWriter(using_dataset.output_path, engine="xlsxwriter")

save_cols = set(
    using_dataset.save_cols + list(liwc_df.columns)
)
save_cols.remove(using_dataset.id_col) # Removing ID col because that's saved as the index

for df, year in zip(years_dfs, years):
    df.to_excel(writer, sheet_name=str(year), columns=save_cols)

writer.close()
