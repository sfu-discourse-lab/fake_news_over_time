# %%
import spacy
from spacy.tokens.doc import Doc
import pandas as pd
from dataset_config import BASE_FAKESPEAK_CONFIG, BASE_MISINFOTEXT_CONFIG
from helpers import get_groups, make_output_path, make_output_path_for_type

# %%
fakespeak_config = BASE_FAKESPEAK_CONFIG
misinfotext_config = BASE_MISINFOTEXT_CONFIG

# %%
using_dataset = misinfotext_config

# %%
dataset_df = pd.read_excel(
    using_dataset["input_path"], 
    sheet_name=using_dataset["sheet_name"], 
    usecols=using_dataset["usecols"]
)
dataset_df.head()

# %% [markdown]
# ## Calculating lexical density using spacy
#
# Lexical density is calculated by number of lexical words (nouns, verbs, adjectives, adverbs) divided by number of total words.

# %%
nlp = spacy.load('en_core_web_md')

# %%
dataset_df["doc"] = list(nlp.pipe(dataset_df[using_dataset["text_col"]]))

# %%
lexical_pos = ["PROPN", "NOUN", "VERB", "ADJ", "ADV"]

def calculate_lexical_density(doc: Doc):
    num_lexical_items = len([
        token
        for token in doc
        if token.pos_ in lexical_pos
    ])

    return num_lexical_items / len(doc)

# %%
dataset_df["lexical_density"] = dataset_df["doc"].apply(calculate_lexical_density)
dataset_df
# Out:
#                                           factcheckURL  \
# 0    http://www.politifact.com/arizona/statements/2...
# 1    http://www.politifact.com/california/statement...
# 2    http://www.politifact.com/california/statement...
# 3    http://www.politifact.com/california/statement...
# 4    http://www.politifact.com/california/statement...
# ..                                                 ...
# 650  http://www.politifact.com/wisconsin/statements...
# 651  http://www.politifact.com/wisconsin/statements...
# 652  http://www.politifact.com/wisconsin/statements...
# 653  http://www.politifact.com/wisconsin/statements...
# 654  http://www.politifact.com/wisconsin/statements...
#
#                                            originalURL  \
# 0    https://associatedmediacoverage.com/three-stat...
# 1    https://users.focalbeam.com/fs/distribution:wl...
# 2    http://www.sacbee.com/opinion/op-ed/soapbox/ar...
# 3    https://nocagastax.com/california-gas-tax-hike...
# 4    https://chu.house.gov/media-center/press-relea...
# ..                                                 ...
# 650  https://x.com/ScottWalker/status/9428776407421...
# 651  https://x.com/ScottWalker/status/9511017961011...
# 652  https://x.com/MahlonMitchell/status/9538161542...
# 653  http://dailycaller.com/2018/01/25/hey-look-sen...
# 654                     https://mahlonmitchell.com/bio
#
#                                       originalBodyText  \
# 0    Residents of multiple states will be asked to ...
# 1    Sacramento, CA - United States Senator Dianne ...
# 2    We should anticipate black and gray markets in...
# 3    As a ballot initiative calling for repeal of a...
# 4    WASHINGTON, DC  The House of Representatives t...
# ..                                                 ...
# 650  Road projects across the state are staying on ...
# 651  The last thing we need is more Madison in our ...
# 652  When \n@ScottWalker\n told firefighters we did...
# 653  Now that its 2018, an election year, I would l...
# 654  Mahlon Mitchell currently serves as President ...
#
#                                       originalHeadline originalTextType  \
# 0    Multiple States Have Agreed To Implement A ‘Tw...    News and blog
# 1    U.S. Senator Dianne Feinstein Opposes Prop. 64...    Press release
# 2            Why you should buy a locking gasoline cap    News and blog
# 3     California Gas-Tax-Hike Repeal Campaign Heats Up    News and blog
# 4         Rep. Chu Decries "Heartless" ACA Repeal Vote    Press release
# ..                                                 ...              ...
# 650                                                NaN     Social media
# 651                                                NaN     Social media
# 652                                                NaN     Social media
# 653  HEY LOOK! Senator Tammy Baldwin Is Back In Wis...    News and blog
# 654                       Mahlon Mitchell for Governor    Press release
#
#     originalDate  originalDateYear  \
# 0     2016-05-06              2016
# 1     2016-07-12              2016
# 2     2017-08-04              2017
# 3     2017-06-15              2017
# 4     2017-05-04              2017
# ..           ...               ...
# 650   2017-12-18              2017
# 651   2018-01-10              2018
# 652   2018-01-18              2018
# 653   2018-01-25              2018
# 654   2018-04-30              2018
#
#                                                    doc  lexical_density
# 0    (Residents, of, multiple, states, will, be, as...         0.474427
# 1    (Sacramento, ,, CA, -, United, States, Senator...         0.562212
# 2    (We, should, anticipate, black, and, gray, mar...         0.496368
# 3    (As, a, ballot, initiative, calling, for, repe...         0.538767
# 4    (WASHINGTON, ,, DC,  , The, House, of, Represe...         0.516796
# ..                                                 ...              ...
# 650  (Road, projects, across, the, state, are, stay...         0.500000
# 651  (The, last, thing, we, need, is, more, Madison...         0.469388
# 652  (When, \n, @ScottWalker, \n , told, firefighte...         0.433333
# 653  (Now, that, its, 2018, ,, an, election, year, ...         0.498442
# 654  (Mahlon, Mitchell, currently, serves, as, Pres...         0.528455
#
# [655 rows x 9 columns]

# %%
years, years_dfs = get_groups(dataset_df, using_dataset["year_col"])
years_dfs[0].head()
# Out:
#                                           factcheckURL  \
# 428  http://www.politifact.com/truth-o-meter/statem...
#
#                                            originalURL  \
# 428  https://www.johnmccain.com/Informing/News/Pres...
#
#                                       originalBodyText  \
# 428  "On Monday, Senator Clinton told an audience a...
#
#                                 originalHeadline originalTextType  \
# 428  Statement By John McCain on Hillary Clinton    Press release
#
#     originalDate  originalDateYear  \
# 428   2007-08-23              2007
#
#                                                    doc  lexical_density
# 428  (", On, Monday, ,, Senator, Clinton, told, an,...         0.472973

# %%
types, types_dfs = get_groups(dataset_df, using_dataset["type_col"])
types_dfs[0].head()
# Out:
#                                         factcheckURL  \
# 0  http://www.politifact.com/arizona/statements/2...
# 2  http://www.politifact.com/california/statement...
# 3  http://www.politifact.com/california/statement...
# 6  http://www.politifact.com/california/statement...
# 7  http://www.politifact.com/california/statement...
#
#                                          originalURL  \
# 0  https://associatedmediacoverage.com/three-stat...
# 2  http://www.sacbee.com/opinion/op-ed/soapbox/ar...
# 3  https://nocagastax.com/california-gas-tax-hike...
# 6  http://www.sfchronicle.com/opinion/openforum/a...
# 7  http://www.sfchronicle.com/politics/article/Th...
#
#                                     originalBodyText  \
# 0  Residents of multiple states will be asked to ...
# 2  We should anticipate black and gray markets in...
# 3  As a ballot initiative calling for repeal of a...
# 6  Recently, a group of special interests threate...
# 7  COSTA MESA, Orange County  It was a surreal vi...
#
#                                     originalHeadline originalTextType  \
# 0  Multiple States Have Agreed To Implement A ‘Tw...    News and blog
# 2          Why you should buy a locking gasoline cap    News and blog
# 3   California Gas-Tax-Hike Repeal Campaign Heats Up    News and blog
# 6  Repeal Californias gas tax increase, says GOP ...    News and blog
# 7  The pro-Russia, pro-weed, pro-Assange GOP cong...    News and blog
#
#   originalDate  originalDateYear  \
# 0   2016-05-06              2016
# 2   2017-08-04              2017
# 3   2017-06-15              2017
# 6   2017-10-19              2017
# 7   2017-09-14              2017
#
#                                                  doc  lexical_density
# 0  (Residents, of, multiple, states, will, be, as...         0.474427
# 2  (We, should, anticipate, black, and, gray, mar...         0.496368
# 3  (As, a, ballot, initiative, calling, for, repe...         0.538767
# 6  (Recently, ,, a, group, of, special, interests...         0.503425
# 7  (COSTA, MESA, ,, Orange, County,  , It, was, a...         0.498021

# %%
def get_summary_df(dfs: list[pd.DataFrame], years: list[int]):
    return pd.DataFrame(
        [df["lexical_density"].describe() for df in dfs],
        index=pd.Index(data=years, name="year")
    )

# %% [markdown]
# ## Writing dataframes to excel spreadsheet

# %%
def save_years(writer: pd.ExcelWriter, years: list[int], dfs: list[pd.DataFrame]):
    for year, df in zip(years, dfs):
        df.to_excel(
            writer,
            sheet_name=str(year),
            index=False,
            columns=[using_dataset["id_col"], "lexical_density"]
        )

    summary_df = get_summary_df(dfs, years)
    summary_df.to_excel(writer, sheet_name="Summary")

# %%
output_path = make_output_path(using_dataset, "lexical_density")

writer = pd.ExcelWriter(output_path, engine="xlsxwriter")
save_years(writer, years, years_dfs)
writer.close()

# %%
for type, df in zip(types, types_dfs):
    years, years_dfs = get_groups(df, using_dataset["year_col"])

    output_path = make_output_path_for_type(using_dataset, type, "lexical_density")

    writer = pd.ExcelWriter(output_path, engine="xlsxwriter")
    save_years(writer, years, years_dfs)
    writer.close()
# Out:
# Created directory ./data/MisInfoText/Analysis_output/news_and_blog
# Created directory ./data/MisInfoText/Analysis_output/press_release
# Created directory ./data/MisInfoText/Analysis_output/social_media
