# %%
import spacy
from spacy.tokens.doc import Doc
import pandas as pd
from dataset_config import BASE_FAKESPEAK_CONFIG, BASE_MISINFOTEXT_CONFIG
from helpers import get_groups, make_output_path, make_output_path_for_type, is_word

# %%
fakespeak_config = BASE_FAKESPEAK_CONFIG
misinfotext_config = BASE_MISINFOTEXT_CONFIG

# %%
using_dataset = misinfotext_config

# %%
dataset_df = pd.read_excel(
    using_dataset["input_path"], 
    sheet_name=using_dataset["sheet_name"], 
    usecols=using_dataset["usecols"]
)

# Removing 2007 and 2008 years because little data in them
dataset_df = dataset_df[~(dataset_df[using_dataset["year_col"]] == 2007) & ~(dataset_df[using_dataset["year_col"]] == 2008)]

dataset_df.head()
# Out:
#                                         factcheckURL  \
# 0  http://www.politifact.com/arizona/statements/2...
# 1  http://www.politifact.com/california/statement...
# 2  http://www.politifact.com/california/statement...
# 3  http://www.politifact.com/california/statement...
# 4  http://www.politifact.com/california/statement...
#
#                                          originalURL  \
# 0  https://associatedmediacoverage.com/three-stat...
# 1  https://users.focalbeam.com/fs/distribution:wl...
# 2  http://www.sacbee.com/opinion/op-ed/soapbox/ar...
# 3  https://nocagastax.com/california-gas-tax-hike...
# 4  https://chu.house.gov/media-center/press-relea...
#
#                                     originalBodyText  \
# 0  Residents of multiple states will be asked to ...
# 1  Sacramento, CA - United States Senator Dianne ...
# 2  We should anticipate black and gray markets in...
# 3  As a ballot initiative calling for repeal of a...
# 4  WASHINGTON, DC  The House of Representatives t...
#
#                                     originalHeadline originalTextType  \
# 0  Multiple States Have Agreed To Implement A ‘Tw...    News and blog
# 1  U.S. Senator Dianne Feinstein Opposes Prop. 64...    Press release
# 2          Why you should buy a locking gasoline cap    News and blog
# 3   California Gas-Tax-Hike Repeal Campaign Heats Up    News and blog
# 4       Rep. Chu Decries "Heartless" ACA Repeal Vote    Press release
#
#   originalDate  originalDateYear
# 0   2016-05-06              2016
# 1   2016-07-12              2016
# 2   2017-08-04              2017
# 3   2017-06-15              2017
# 4   2017-05-04              2017

# %% [markdown]
# ## Calculating lexical density using spacy
#
# Lexical density is calculated by number of lexical words (nouns, verbs, adjectives, adverbs) divided by number of total words, excluding punctuation.

# %%
nlp = spacy.load('en_core_web_md')
# Out:
# c:\Users\Adam\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\spacy\util.py:969: UserWarning: [W095] Model 'en_core_web_md' (3.5.0) was trained with spaCy v3.5.0 and may not be 100% compatible with the current version (3.8.8). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
dataset_df["doc"] = list(nlp.pipe(dataset_df[using_dataset["text_col"]]))

# %% [markdown]
# We count lexical ("content") words to be proper nouns, nouns, verbs, adjectives, and adverbs.
#
# We then calculate lexical density by dividing the number of lexical words by total number of words. This excludes non-word tokens like punctuation.

# %%
lexical_pos = ["PROPN", "NOUN", "VERB", "ADJ", "ADV"]

def calculate_lexical_density(doc: Doc):
    word_tokens = [token for token in doc if is_word(token)]
    
    num_lexical_items = len([
        token
        for token in word_tokens
        if token.pos_ in lexical_pos
    ])

    return num_lexical_items / len(word_tokens)

# %%
dataset_df["lexical_density"] = dataset_df["doc"].apply(calculate_lexical_density)
dataset_df
# Out:
#                                           factcheckURL  \
# 0    http://www.politifact.com/arizona/statements/2...
# 1    http://www.politifact.com/california/statement...
# 2    http://www.politifact.com/california/statement...
# 3    http://www.politifact.com/california/statement...
# 4    http://www.politifact.com/california/statement...
# ..                                                 ...
# 686  https://www.politifact.com/factchecks/2015/jul...
# 687  https://www.politifact.com/factchecks/2015/jun...
# 688  https://www.politifact.com/factchecks/2015/mar...
# 689  https://www.politifact.com/factchecks/2015/feb...
# 690  https://www.politifact.com/factchecks/2015/feb...
#
#                                            originalURL  \
# 0    https://associatedmediacoverage.com/three-stat...
# 1    https://users.focalbeam.com/fs/distribution:wl...
# 2    http://www.sacbee.com/opinion/op-ed/soapbox/ar...
# 3    https://nocagastax.com/california-gas-tax-hike...
# 4    https://chu.house.gov/media-center/press-relea...
# ..                                                 ...
# 686  https://x.com/DineshDSouza/status/618437306769...
# 687  https://x.com/Gavin_McInnes/status/61353424690...
# 688  http://www.wisdems.org/news/blog/view/2015-03-...
# 689  https://urbanintellectuals.com/sheriffs-call-f...
# 690  https://x.com/GovWalker/status/563109626552414208
#
#                                       originalBodyText  \
# 0    Residents of multiple states will be asked to ...
# 1    Sacramento, CA - United States Senator Dianne ...
# 2    We should anticipate black and gray markets in...
# 3    As a ballot initiative calling for repeal of a...
# 4    WASHINGTON, DC  The House of Representatives t...
# ..                                                 ...
# 686  Look closely at this Hillary photo; isn't that...
# 687  Leave the confederate flag up because the Civi...
# 688  The nonpartisan Legislative Fiscal Bureau yest...
# 689  President Obama is a lightening rod for critic...
# 690  The Wisconsin Idea will continue to thrive.  T...
#
#                                       originalHeadline originalTextType  \
# 0    Multiple States Have Agreed To Implement A ‘Tw...    News and blog
# 1    U.S. Senator Dianne Feinstein Opposes Prop. 64...    Press release
# 2            Why you should buy a locking gasoline cap    News and blog
# 3     California Gas-Tax-Hike Repeal Campaign Heats Up    News and blog
# 4         Rep. Chu Decries "Heartless" ACA Repeal Vote    Press release
# ..                                                 ...              ...
# 686                                                NaN     Social media
# 687                                                NaN     Social media
# 688  More Bad News For Working Families in Scott Wa...    News and blog
# 689  Sheriffs Call For Obama’s Lynching While Leade...    News and blog
# 690                                                NaN     Social media
#
#     originalDate  originalDateYear  \
# 0     2016-05-06              2016
# 1     2016-07-12              2016
# 2     2017-08-04              2017
# 3     2017-06-15              2017
# 4     2017-05-04              2017
# ..           ...               ...
# 686   2015-07-07              2015
# 687   2015-06-24              2015
# 688   2015-03-16              2015
# 689   2015-01-15              2015
# 690   2015-02-04              2015
#
#                                                    doc  lexical_density
# 0    (Residents, of, multiple, states, will, be, as...         0.548057
# 1    (Sacramento, ,, CA, -, United, States, Senator...         0.638298
# 2    (We, should, anticipate, black, and, gray, mar...         0.579096
# 3    (As, a, ballot, initiative, calling, for, repe...         0.607623
# 4    (WASHINGTON, ,, DC,  , The, House, of, Represe...         0.577875
# ..                                                 ...              ...
# 686  (Look, closely, at, this, Hillary, photo, ;, i...         0.411765
# 687  (Leave, the, confederate, flag, up, because, t...         0.458333
# 688  (The, nonpartisan, Legislative, Fiscal, Bureau...         0.556174
# 689  (President, Obama, is, a, lightening, rod, for...         0.540000
# 690  (The, Wisconsin, Idea, will, continue, to, thr...         0.681818
#
# [685 rows x 9 columns]

# %% [markdown]
# Get separate dataframes for each year

# %%
years, years_dfs = get_groups(dataset_df, using_dataset["year_col"])
years_dfs[0].head()
# Out:
#                                           factcheckURL  \
# 433  http://www.politifact.com/truth-o-meter/statem...
# 434  http://www.politifact.com/truth-o-meter/statem...
# 435  http://www.politifact.com/truth-o-meter/statem...
# 436  http://www.politifact.com/truth-o-meter/statem...
# 437  http://www.politifact.com/truth-o-meter/statem...
#
#                                            originalURL  \
# 433  https://bachmann.house.gov/News/DocumentSingle...
# 434  https://healthcare.nationalreview.com/post/?q=...
# 435  http://krugman.blogs.nytimes.com/2009/08/05/on...
# 436   https://www.facebook.com/notes/1020383705144285/
# 437  https://jumpinginpools.blogspot.com/2009/01/mi...
#
#                                       originalBodyText  \
# 433  Washington, D.C., Mar 25 - In response to sugg...
# 434  When most Americans talk about the need for he...
# 435  A number of people in the news analysis busine...
# 436  Yesterday President Obama responded to my stat...
# 437  Secretary of Defense Robert Gates is extremely...
#
#                                       originalHeadline originalTextType  \
# 433  Bachmann Demands Truth: Will Obama Administrat...    Press release
# 434  Taxpayer-Funded Abortion Is Not Health-Care Re...    News and blog
# 435          One of these things is not like the other    News and blog
# 436                                                NaN     Social media
# 437  Military to Pledge Oath To Obama, Not Constitu...    News and blog
#
#     originalDate  originalDateYear  \
# 433   2009-03-25              2009
# 434   2009-07-23              2009
# 435   2009-08-05              2009
# 436   2009-08-13              2009
# 437   2009-01-28              2009
#
#                                                    doc  lexical_density
# 433  (Washington, ,, D.C., ,, Mar, 25, -, In, respo...         0.556863
# 434  (When, most, Americans, talk, about, the, need...         0.580347
# 435  (A, number, of, people, in, the, news, analysi...         0.515021
# 436  (Yesterday, President, Obama, responded, to, m...         0.542100
# 437  (Secretary, of, Defense, Robert, Gates, is, ex...         0.531746

# %% [markdown]
# Get separate dataframes for each text type

# %%
types, types_dfs = get_groups(dataset_df, using_dataset["type_col"])
types_dfs[0].head()
# Out:
#                                         factcheckURL  \
# 0  http://www.politifact.com/arizona/statements/2...
# 2  http://www.politifact.com/california/statement...
# 3  http://www.politifact.com/california/statement...
# 6  http://www.politifact.com/california/statement...
# 7  http://www.politifact.com/california/statement...
#
#                                          originalURL  \
# 0  https://associatedmediacoverage.com/three-stat...
# 2  http://www.sacbee.com/opinion/op-ed/soapbox/ar...
# 3  https://nocagastax.com/california-gas-tax-hike...
# 6  http://www.sfchronicle.com/opinion/openforum/a...
# 7  http://www.sfchronicle.com/politics/article/Th...
#
#                                     originalBodyText  \
# 0  Residents of multiple states will be asked to ...
# 2  We should anticipate black and gray markets in...
# 3  As a ballot initiative calling for repeal of a...
# 6  Recently, a group of special interests threate...
# 7  COSTA MESA, Orange County  It was a surreal vi...
#
#                                     originalHeadline originalTextType  \
# 0  Multiple States Have Agreed To Implement A ‘Tw...    News and blog
# 2          Why you should buy a locking gasoline cap    News and blog
# 3   California Gas-Tax-Hike Repeal Campaign Heats Up    News and blog
# 6  Repeal Californias gas tax increase, says GOP ...    News and blog
# 7  The pro-Russia, pro-weed, pro-Assange GOP cong...    News and blog
#
#   originalDate  originalDateYear  \
# 0   2016-05-06              2016
# 2   2017-08-04              2017
# 3   2017-06-15              2017
# 6   2017-10-19              2017
# 7   2017-09-14              2017
#
#                                                  doc  lexical_density
# 0  (Residents, of, multiple, states, will, be, as...         0.548057
# 2  (We, should, anticipate, black, and, gray, mar...         0.579096
# 3  (As, a, ballot, initiative, calling, for, repe...         0.607623
# 6  (Recently, ,, a, group, of, special, interests...         0.573099
# 7  (COSTA, MESA, ,, Orange, County,  , It, was, a...         0.562782

# %% [markdown]
# Using pandas's built-in `.describe()` method for dataframes to get summary stats on lexical density for each year.

# %%
def get_summary_df(dfs: list[pd.DataFrame], years: list[int]):
    return pd.DataFrame(
        [df["lexical_density"].describe() for df in dfs],
        index=pd.Index(data=years, name="year")
    )

# %% [markdown]
# ## Writing dataframes to excel spreadsheet
#
# Save to a single Excel file with tabs for each year, and a final tab for the summary

# %%
def save_years(writer: pd.ExcelWriter, years: list[int], dfs: list[pd.DataFrame]):
    for year, df in zip(years, dfs):
        df.to_excel(
            writer,
            sheet_name=str(year),
            index=False,
            columns=[using_dataset["id_col"], "lexical_density"]
        )

    summary_df = get_summary_df(dfs, years)
    summary_df.to_excel(writer, sheet_name="Summary")

# %%
output_path = make_output_path(using_dataset, "lexical_density")

writer = pd.ExcelWriter(output_path, engine="xlsxwriter")
save_years(writer, years, years_dfs)
writer.close()

# %% [markdown]
# For each text type, we separate further into dataframes per year, and save the Excel files as above

# %%
for type, df in zip(types, types_dfs):
    years, years_dfs = get_groups(df, using_dataset["year_col"])

    output_path = make_output_path_for_type(using_dataset, type, "lexical_density")

    writer = pd.ExcelWriter(output_path, engine="xlsxwriter")
    save_years(writer, years, years_dfs)
    writer.close()
