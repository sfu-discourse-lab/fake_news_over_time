# %%
import pandas as pd
from helpers import get_years_dfs, run_stats_test

# %%
years_dfs = get_years_dfs("./output/liwc.xlsx")

# %%
summary_cols = ["WC", "Analytic", "Clout", "Authentic", "Tone", "WPS", "BigWords", "Dic", "Linguistic"]

# %% [markdown]
# ### First run stats analysis for all text types

# %%
for col in summary_cols:
    print(col, ":", run_stats_test(years_dfs, col), "\n")
# Out:
# Running test for non-normal distributions
# WC : KruskalResult(statistic=523.1412551172909, pvalue=7.151560641930592e-102)
#
# Running test for non-normal distributions
# Analytic : KruskalResult(statistic=55.74324803965012, pvalue=1.3388712549267573e-06)
#
# Running test for non-normal distributions
# Clout : KruskalResult(statistic=33.62089697685955, pvalue=0.00384807046600291)
#
# Running test for non-normal distributions
# Authentic : KruskalResult(statistic=15.899584387493231, pvalue=0.3887565981733448)
#
# Running test for non-normal distributions
# Tone : KruskalResult(statistic=38.80317436448169, pvalue=0.0006856983528262095)
#
# Running test for non-normal distributions
# WPS : KruskalResult(statistic=301.84242874410944, pvalue=2.314618220413296e-55)
#
# Running test for non-normal distributions
# BigWords : KruskalResult(statistic=106.11601340844157, pvalue=8.942602282989662e-16)
#
# Running test for non-normal distributions
# ...

# %% [markdown]
# There are statistically significant differences in word count (WC), Analytic, Clout, Tone, words per sentence (WPS), big words, Dic, and Linguistic between the years, but not Authentic

# %% [markdown]
# ### Now repeat for specific text types

# %% [markdown]
# #### News and blog

# %%
years_dfs = get_years_dfs("./output/news_and_blog/liwc_news_and_blog.xlsx")

# %%
for col in summary_cols:
    print(col, ":", run_stats_test(years_dfs, col), "\n")
# Out:
# Running test for non-normal distributions
# WC : KruskalResult(statistic=80.79148858778778, pvalue=5.003739517369868e-11)
#
# Running test for non-normal distributions
# Analytic : KruskalResult(statistic=27.009276914140187, pvalue=0.02866085609917458)
#
# Running test for non-normal distributions
# Clout : KruskalResult(statistic=52.84272440641569, pvalue=4.095171287414939e-06)
#
# Running test for non-normal distributions
# Authentic : KruskalResult(statistic=22.9006596871043, pvalue=0.08627193305612586)
#
# Running test for non-normal distributions
# Tone : KruskalResult(statistic=30.285366757232683, pvalue=0.010933088285751034)
#
# Running test for non-normal distributions
# WPS : KruskalResult(statistic=9.824781154461675, pvalue=0.8306144654824394)
#
# Running test for non-normal distributions
# BigWords : KruskalResult(statistic=44.99348579698883, pvalue=7.675410866730584e-05)
#
# Running test for non-normal distributions
# ...

# %% [markdown]
# There are statistically significant differences in word count, Analytic, Clout, Tone, big words, Dic, and Linguistic between the years, but not Authentic and words per sentence for news and blog.

# %% [markdown]
# #### Press release

# %%
years_dfs = get_years_dfs("./output/press_release/liwc_press_release.xlsx")

# %%
for col in summary_cols:
    print(col, ":", run_stats_test(years_dfs, col), "\n")
# Out:
# Running test for non-normal distributions
# WC : KruskalResult(statistic=16.751748027608976, pvalue=0.33392026250845863)
#
# Running test for non-normal distributions
# Analytic : KruskalResult(statistic=11.037434486206642, pvalue=0.7499362136002601)
#
# Running test for non-normal distributions
# Clout : KruskalResult(statistic=15.430536625840041, pvalue=0.4208722289952077)
#
# Running test for non-normal distributions
# Authentic : KruskalResult(statistic=15.0715807901765, pvalue=0.44627349766541863)
#
# Running test for non-normal distributions
# Tone : KruskalResult(statistic=10.527727268468619, pvalue=0.7852984688195361)
#
# Running test for non-normal distributions
# WPS : KruskalResult(statistic=16.197125922131693, pvalue=0.36907292183356694)
#
# Running test for non-normal distributions
# BigWords : KruskalResult(statistic=15.822941064525175, pvalue=0.3939157779029783)
#
# Running test for non-normal distributions
# ...

# %% [markdown]
# There are no statistically significant differences in any columns for press release.

# %% [markdown]
# #### Social media

# %%
years_dfs = get_years_dfs("./output/social_media/liwc_social_media.xlsx")

# %%
for col in summary_cols:
    print(col, ":", run_stats_test(years_dfs, col), "\n")
# Out:
# Running test for non-normal distributions
# WC : KruskalResult(statistic=55.89408740917252, pvalue=2.813746851293677e-07)
#
# Running test for non-normal distributions
# Analytic : KruskalResult(statistic=36.67416211969504, pvalue=0.0004659243134611404)
#
# Running test for non-normal distributions
# Clout : KruskalResult(statistic=12.265602248336547, pvalue=0.505994047528912)
#
# Running test for non-normal distributions
# Authentic : KruskalResult(statistic=11.91524155759977, pvalue=0.5346060420830303)
#
# Running test for non-normal distributions
# Tone : KruskalResult(statistic=nan, pvalue=nan)
#
# Running test for non-normal distributions
# WPS : KruskalResult(statistic=28.303126188633833, pvalue=0.008208278477906955)
#
# Running test for non-normal distributions
# BigWords : KruskalResult(statistic=48.218112980061605, pvalue=6.007968936315228e-06)
#
# Running test for non-normal distributions
# Dic : KruskalResult(statistic=83.80658043752835, pvalue=2.109548522894815e-12)
#
# ...

# %% [markdown]
# There are statistically significant differences in word count, Analytic, words per sentence, big words, Dic, and Linguistic between the years, but not Clout, Authentic, and Tone (not enough data points) for social media.
