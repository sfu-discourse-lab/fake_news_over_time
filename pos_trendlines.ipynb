# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import Axes

# %%
def plot_and_save_pos(df: pd.DataFrame, title: str, save_path: str):
    years = list(df["year"])

    pos_labels = list(df.columns)
    pos_labels.remove("year")

    fig, axes = plt.subplots(
        nrows=6, ncols=3, 
        figsize=(30, 50), 
        squeeze=False)

    fig.suptitle(title, fontsize=16)
    fig.subplots_adjust(top=0.95)

    axes_flat: list[Axes] = axes.flatten()

    for i, pos in enumerate(pos_labels):

        ax = axes_flat[i]
        
        ax.set_title(pos)
        ax.grid(True)

        ax.set_xlabel("year")
        ax.set_xticks(years)
        ax.set_xticklabels([str(y) for y in years])
        ax.tick_params(axis="x", rotation=45)

        ax.set_ylabel("Proportion of all tokens")

        ax.plot(years, df[pos], marker="o")
    
    plt.draw()
    fig.savefig(save_path)

    fig.show()


def load_and_plot(misinfotext_path: str, fakespeak_path: str, title: str, save_path: str):
    misinfotext_props_df = pd.read_excel(misinfotext_path, sheet_name="proportions")
    fakespeak_props_df = pd.read_excel(fakespeak_path, sheet_name="proportions")
    full_props_df = pd.concat([misinfotext_props_df, fakespeak_props_df]).fillna(0)

    plot_and_save_pos(full_props_df, title, save_path)

# %%
load_and_plot(
    misinfotext_path="./data/MisInfoText/Analysis_output/MisInfoText_POS_frequency.xlsx",
    fakespeak_path="./data/Fakespeak-ENG/Analysis_output/Fakespeak_POS_frequency.xlsx",
    title="POS proportions per year for all text types",
    save_path="./visualization/POS/all_types.png"
)
# Out:
# C:\Users\Adam\AppData\Local\Temp\ipykernel_14044\3767822345.py:36: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
load_and_plot(
    misinfotext_path="./data/MisInfoText/Analysis_output/news_and_blog/MisInfoText_news_and_blog_POS_frequency.xlsx",
    fakespeak_path="./data/Fakespeak-ENG/Analysis_output/news_and_blog/Fakespeak_news_and_blog_POS_frequency.xlsx",
    title="POS proportions per year for news and blog",
    save_path="./visualization/POS/news_and_blog.png"
)
# Out:
# C:\Users\Adam\AppData\Local\Temp\ipykernel_14044\3767822345.py:36: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
load_and_plot(
    misinfotext_path="./data/MisInfoText/Analysis_output/press_release/MisInfoText_press_release_POS_frequency.xlsx",
    fakespeak_path="./data/Fakespeak-ENG/Analysis_output/press_release/Fakespeak_press_release_POS_frequency.xlsx",
    title="POS proportions per year for press release",
    save_path="./visualization/POS/press_release.png"
)
# Out:
# C:\Users\Adam\AppData\Local\Temp\ipykernel_14044\3767822345.py:36: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
load_and_plot(
    misinfotext_path="./data/MisInfoText/Analysis_output/social_media/MisInfoText_social_media_POS_frequency.xlsx",
    fakespeak_path="./data/Fakespeak-ENG/Analysis_output/social_media/Fakespeak_social_media_POS_frequency.xlsx",
    title="POS proportions per year for social media",
    save_path="./visualization/POS/social_media.png"
)
# Out:
# C:\Users\Adam\AppData\Local\Temp\ipykernel_14044\3767822345.py:36: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
