# %%
import pandas as pd
from quote_extractor import QuoteExtractor

# %%
class DatasetConfig():
    input_path: str
    output_path: str
    quote_annotations_path: str
    sheet_name: str
    id_col: str
    usecols: list[str]

    def __init__(self, input_path: str, output_path: str, quote_annotations_path: str, sheet_name: str, id_col: str, usecols: list[str]):
        self.input_path = input_path
        self.output_path = output_path
        self.quote_annotations_path = quote_annotations_path
        self.sheet_name = sheet_name
        self.id_col = id_col
        self.usecols = usecols

# %%
fakespeak_config = DatasetConfig(
    # file_path="/content/drive/My Drive/fake_news_over_time/Fakespeak_ENG_modified.xlsx",
    input_path="./data/Fakespeak-ENG/Fakespeak-ENG modified.xlsx",
    output_path="./data/Fakespeak-ENG/Analysis_output/Fakespeak_quotes.xlsx",
    quote_annotations_path="./data/Fakespeak-ENG/Analysis_output/quote_annotations.json",
    sheet_name="Working",
    id_col="ID",
    usecols=['ID', 'combinedLabel', 'originalTextType', 'originalBodyText', 'originalDateYear'],
)

misinfotext_config = DatasetConfig(
    input_path="./data/MisInfoText/PolitiFact_original_modified.xlsx",
    output_path="./data/MisInfoText/Analysis_output/MisInfoText_quotes.xlsx",
    quote_annotations_path="./data/MisInfoText/Analysis_output/quote_annotations.json",
    sheet_name="Working",
    id_col="factcheckURL",
    usecols=None,
)

# %%
using_dataset = misinfotext_config

# %%
dataset_df = pd.read_excel(
    using_dataset.input_path, 
    sheet_name=using_dataset.sheet_name, 
    usecols=using_dataset.usecols)
dataset_df
# Out:
#                                           factcheckURL  \
# 0    http://www.politifact.com/arizona/statements/2...
# 1    http://www.politifact.com/california/statement...
# 2    http://www.politifact.com/california/statement...
# 3    http://www.politifact.com/california/statement...
# 4    http://www.politifact.com/california/statement...
# ..                                                 ...
# 650  http://www.politifact.com/wisconsin/statements...
# 651  http://www.politifact.com/wisconsin/statements...
# 652  http://www.politifact.com/wisconsin/statements...
# 653  http://www.politifact.com/wisconsin/statements...
# 654  http://www.politifact.com/wisconsin/statements...
#
#                                            originalURL  \
# 0    https://associatedmediacoverage.com/three-stat...
# 1    https://users.focalbeam.com/fs/distribution:wl...
# 2    http://www.sacbee.com/opinion/op-ed/soapbox/ar...
# 3    https://nocagastax.com/california-gas-tax-hike...
# 4    https://chu.house.gov/media-center/press-relea...
# ..                                                 ...
# 650  https://x.com/ScottWalker/status/9428776407421...
# 651  https://x.com/ScottWalker/status/9511017961011...
# 652  https://x.com/MahlonMitchell/status/9538161542...
# 653  http://dailycaller.com/2018/01/25/hey-look-sen...
# 654                     https://mahlonmitchell.com/bio
#
#                                       originalBodyText  \
# 0    Residents of multiple states will be asked to ...
# 1    Sacramento, CA - United States Senator Dianne ...
# 2    We should anticipate black and gray markets in...
# 3    As a ballot initiative calling for repeal of a...
# 4    WASHINGTON, DC  The House of Representatives t...
# ..                                                 ...
# 650  Road projects across the state are staying on ...
# 651  The last thing we need is more Madison in our ...
# 652  When \n@ScottWalker\n told firefighters we did...
# 653  Now that its 2018, an election year, I would l...
# 654  Mahlon Mitchell currently serves as President ...
#
#                                       originalHeadline originalTextType  \
# 0    Multiple States Have Agreed To Implement A ‘Tw...    News and blog
# 1    U.S. Senator Dianne Feinstein Opposes Prop. 64...    Press release
# 2            Why you should buy a locking gasoline cap    News and blog
# 3     California Gas-Tax-Hike Repeal Campaign Heats Up    News and blog
# 4         Rep. Chu Decries "Heartless" ACA Repeal Vote    Press release
# ..                                                 ...              ...
# 650                                                NaN     Social media
# 651                                                NaN     Social media
# 652                                                NaN     Social media
# 653  HEY LOOK! Senator Tammy Baldwin Is Back In Wis...    News and blog
# 654                       Mahlon Mitchell for Governor    Press release
#
#     originalDate  originalDateYear
# 0     2016-05-06              2016
# 1     2016-07-12              2016
# 2     2017-08-04              2017
# 3     2017-06-15              2017
# 4     2017-05-04              2017
# ..           ...               ...
# 650   2017-12-18              2017
# 651   2018-01-10              2018
# 652   2018-01-18              2018
# 653   2018-01-25              2018
# 654   2018-04-30              2018
#
# [655 rows x 7 columns]

# %%
quote_extractor = QuoteExtractor("en_core_web_lg", "./quote_verb_list.txt")
# Out:
# c:\Users\Adam\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\coreferee\manager.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
quote_annotations = quote_extractor.run_multiple(dataset_df[using_dataset.id_col], dataset_df["originalBodyText"])
# Out:
# Preprocessing texts...
# Creating spacy docs...
# Extracting quotes...
# Done extracting quotes

# %%
quote_annotations
# Out:
# [{'speaker': 'statistics gathered and published by The Humane Society of the United States',
#   'speaker_index': '(268,344)',
#   'quote': ', abandoned pet rates have sky-rocketed in Texas, Arizona, and Missouri over the past 2 years.\n .\n ',
#   'quote_index': '(344,443)',
#   'verb': 'according to',
#   'verb_index': '(255,267)',
#   'quote_token_count': 24,
#   'quote_type': 'AccordingTo',
#   'is_floating_quote': False},
#  {'speaker': 'state representatives',
#   'speaker_index': '(1326,1347)',
#   'quote': ', pet owners within Texas, Arizona, and Missouri are expected to be in compliance with the new ordinance by September 2016.',
#   'quote_index': '(1347,1470)',
#   'verb': 'according to',
#   'verb_index': '(1313,1325)',
#   'quote_token_count': 24,
#   'quote_type': 'AccordingTo',
#   'is_floating_quote': False},
#  {'speaker': 'representatives involved with the initiative,',
#   'speaker_index': '(1959,2004)',
#   'quote': 'a state funded, mandatory ‘pet registration’ process will be implemented as early as January 2017.',
#   'quote_index': '(2005,2103)',
#   'verb': 'according to',
#   'verb_index': '(1946,1958)',
#   'quote_token_count': 19,
#   'quote_type': 'AccordingTo',
#   'is_floating_quote': False},
#  {'speaker': 'representatives',
#   'speaker_index': '(2562,2577)',
#   'quote': ', an incentive program may be implemented to encourage citizens to report those out of compliance), The Humane Society of the United States is planning to hire an additional 1,300 employees within Texas, Arizona, and Missouri to patrol and enforce the ordinance.\n .\n ',
#   'quote_index': '(2577,2844)',
#   'verb': 'according to',
#   'verb_index': '(2549,2561)',
#   'quote_token_count': 50,
#   'quote_type': 'AccordingTo',
#   'is_floating_quote': False},
#  {'speaker': '',
#   'speaker_index': '(0,0)',
#   'quote': '"domestic animal the size of a cat or larger"',
#   'quote_index': '(1697,1742)',
#   'verb': '',
#   'verb_index': '',
#   'quote_token_count': 11,
#   'quote_type': 'Heuristic',
#   'is_floating_quote': False},
#  {'speaker': 'The AAA Foundation for Highway Safety',
#   'speaker_index': '(663,700)',
#   'quote': 'that deaths in marijuana-related car crashes have doubled since Washington state approved legalization',
#   'quote_index': '(709,811)',
#   'verb': 'reports',
#   'verb_index': '(701,708)',
#   'quote_token_count': 15,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': '',
#   'speaker_index': '(0,0)',
#   'quote': '"Proposition 64 is substantially different from legalization measures in other states and would repeal countless consumer protections just passed last year and signed into law by Governor Brown. It rolls back anti-smoking advertising protections we’ve had for decades and allows marijuana smoking ads in prime time, on programs with millions of children and teenage viewers.\n .\n "',
#   'quote_index': '(283,663)',
#   'verb': '',
#   'verb_index': '',
#   'quote_token_count': 66,
#   'quote_type': 'Heuristic',
#   'is_floating_quote': False},
#  {'speaker': 'NPR',
#   'speaker_index': '(511,514)',
#   'quote': 'Organized crime gangs are buying hundreds or thousands of gallons of diesel fuel, and reselling them to make an untraceable profit',
#   'quote_index': '(378,508)',
#   'verb': 'reported',
#   'verb_index': '(515,523)',
#   'quote_token_count': 22,
#   'quote_type': 'QCQSV',
#   'is_floating_quote': False},
#  {'speaker': 'Glendale police Officer Dan Suttles',
#   'speaker_index': '(558,593)',
#   'quote': 'Such crime is prevalent',
#   'quote_index': '(533,556)',
#   'verb': 'told',
#   'verb_index': '(594,598)',
#   'quote_token_count': 4,
#   'quote_type': 'CSV',
#   'is_floating_quote': False},
#  {'speaker': 'the Los Angeles Times',
#   'speaker_index': '(890,911)',
#   'quote': 'That led a reader to contact the police about a city gardener, who later was arrested for allegedly selling thousands of dollars of city-owned gasoline on the black market',
#   'quote_index': '(717,888)',
#   'verb': 'reported',
#   'verb_index': '(912,920)',
#   'quote_token_count': 32,
#   'quote_type': 'CSV',
#   'is_floating_quote': False},
#  {'speaker': 'One',
#   'speaker_index': '(926,929)',
#   'quote': 'how much gas and diesel thefts could rise',
#   'quote_index': '(944,985)',
#   'verb': 'predict',
#   'verb_index': '(936,943)',
#   'quote_token_count': 8,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'An LAO report',
#   'speaker_index': '(1192,1205)',
#   'quote': 'that in the two months before the tax increase took effect, tobacco tax revenue ran 24 percent and 37 percent above 2016 levels',
#   'quote_index': '(1212,1339)',
#   'verb': 'noted',
#   'verb_index': '(1206,1211)',
#   'quote_token_count': 24,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'the report',
#   'speaker_index': '(1475,1485)',
#   'quote': ', some cigarettes could be coming from states with taxes lower than California’s.\n .\n ',
#   'quote_index': '(1485,1571)',
#   'verb': 'according to',
#   'verb_index': '(1462,1474)',
#   'quote_token_count': 18,
#   'quote_type': 'AccordingTo',
#   'is_floating_quote': False},
#  {'speaker': 'The Bee',
#   'speaker_index': '(1640,1647)',
#   'quote': 'three-quarters of California’s largest cities saw violent crime rise in 2015, with Sacramento’s up 25 percent.\n ',
#   'quote_index': '(1658,1770)',
#   'verb': 'reported',
#   'verb_index': '(1648,1656)',
#   'quote_token_count': 23,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Jerry Brown',
#   'speaker_index': '(865,876)',
#   'quote': 'hes going to raise their gas taxes to the highest theyve ever been in history, and to top it off',
#   'quote_index': '(901,997)',
#   'verb': 'telling',
#   'verb_index': '(880,887)',
#   'quote_token_count': 23,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Allen',
#   'speaker_index': '(1241,1246)',
#   'quote': 'Solving the Wrong Problem Browns gas-tax hike will not solve the states traffic problems',
#   'quote_index': '(1151,1239)',
#   'verb': 'says',
#   'verb_index': '(1247,1251)',
#   'quote_token_count': 16,
#   'quote_type': 'CSV',
#   'is_floating_quote': False},
#  {'speaker': 'Allen',
#   'speaker_index': '(1327,1332)',
#   'quote': 'This new gas tax does not increase [road] capacity anywhere in the state',
#   'quote_index': '(1253,1325)',
#   'verb': 'said',
#   'verb_index': '(1333,1337)',
#   'quote_token_count': 15,
#   'quote_type': 'CSV',
#   'is_floating_quote': False},
#  {'speaker': 'Road Money for Roads David Spady, state director for the California chapter of Americans for Prosperity,',
#   'speaker_index': '(1537,1641)',
#   'quote': 'California should use existing road funds for roads only, before taking more money from taxpayers',
#   'quote_index': '(1647,1744)',
#   'verb': 'says',
#   'verb_index': '(1642,1646)',
#   'quote_token_count': 16,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Spady',
#   'speaker_index': '(1913,1918)',
#   'quote': 'California doesnt need more money for roads; it needs laws mandating that existing gas taxes and heavy-vehicles tax revenue is only spent on roads and infrastructure',
#   'quote_index': '(1746,1911)',
#   'verb': 'said',
#   'verb_index': '(1919,1923)',
#   'quote_token_count': 30,
#   'quote_type': 'CSV',
#   'is_floating_quote': False},
#  {'speaker': 'Highway Robbery Spady',
#   'speaker_index': '(2166,2187)',
#   'quote': 'California lawmakers used road funds as slush funds for their pet projects in the past, causing todays problems',
#   'quote_index': '(2193,2304)',
#   'verb': 'says',
#   'verb_index': '(2188,2192)',
#   'quote_token_count': 19,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Spady',
#   'speaker_index': '(2583,2588)',
#   'quote': 'Californias roads are a disaster because for years politicians have kicked the can down the road, diverted funds to projects like bike paths and trains, and allowed a bloated government pension system to crowd out funds that could have been used for infrastructure and repair',
#   'quote_index': '(2306,2581)',
#   'verb': 'said',
#   'verb_index': '(2589,2593)',
#   'quote_token_count': 47,
#   'quote_type': 'CSV',
#   'is_floating_quote': False},
#  {'speaker': 'the Independent Institute',
#   'speaker_index': '(1669,1694)',
#   'quote': 'it even lied to lawmakers to cover its tracks',
#   'quote_index': '(1775,1820)',
#   'verb': 'said',
#   'verb_index': '(1770,1774)',
#   'quote_token_count': 9,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'the Competitive Enterprise Institute.',
#   'speaker_index': '(1933,1970)',
#   'quote': 'California spends 4.7 times the national average for every mile of roadway we build and maintain,',
#   'quote_index': '(1822,1919)',
#   'verb': 'according to',
#   'verb_index': '(1920,1932)',
#   'quote_token_count': 17,
#   'quote_type': 'AccordingTo',
#   'is_floating_quote': False},
#  {'speaker': 'which',
#   'speaker_index': '(2372,2377)',
#   'quote': 'why unions and big business joined together to finance an extensive radio-and-newspaper campaign to promote the gas and car tax increase',
#   'quote_index': '(2387,2523)',
#   'verb': 'explains',
#   'verb_index': '(2378,2386)',
#   'quote_token_count': 25,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'House Majority Leader Kevin McCarthy',
#   'speaker_index': '(606,642)',
#   'quote': 'that Putin pays him',
#   'quote_index': '(662,681)',
#   'verb': 'said',
#   'verb_index': '(657,661)',
#   'quote_token_count': 4,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'He',
#   'speaker_index': '(683,685)',
#   'quote': 'the Charlottesville riots were staged by liberals and were a total hoax',
#   'quote_index': '(756,827)',
#   'verb': 'thinks',
#   'verb_index': '(749,755)',
#   'quote_token_count': 12,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'you',
#   'speaker_index': '(1284,1287)',
#   'quote': 'How is this guy still holding office in California',
#   'quote_index': '(1300,1350)',
#   'verb': 'thinking',
#   'verb_index': '(1290,1298)',
#   'quote_token_count': 9,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Orange County GOP chairman Fred Whitaker',
#   'speaker_index': '(2134,2174)',
#   'quote': 'hes not worried about Dana at all',
#   'quote_index': '(2180,2213)',
#   'verb': 'said',
#   'verb_index': '(2175,2179)',
#   'quote_token_count': 8,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Rohrabacher',
#   'speaker_index': '(2340,2351)',
#   'quote': 'this race will be the toughest',
#   'quote_index': '(2366,2396)',
#   'verb': 'acknowledges',
#   'verb_index': '(2352,2364)',
#   'quote_token_count': 6,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'the nations top intelligence agencies',
#   'speaker_index': '(2787,2824)',
#   'quote': 'that Russia interfered in the election',
#   'quote_index': '(2840,2878)',
#   'verb': 'concluded',
#   'verb_index': '(2830,2839)',
#   'quote_token_count': 6,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'he',
#   'speaker_index': '(3228,3230)',
#   'quote': 'That story is a total fabrication in order to do one thing: To prevent Donald Trump from exercising the legitimate authority he was given by the voters in the last election',
#   'quote_index': '(3054,3226)',
#   'verb': 'said',
#   'verb_index': '(3231,3235)',
#   'quote_token_count': 32,
#   'quote_type': 'CSV',
#   'is_floating_quote': False},
#  {'speaker': 'Rohrabacher',
#   'speaker_index': '(3500,3511)',
#   'quote': 'Assange told him that Russia wasnt involved in the theft of emails from the Democratic National Committee that Wikileaks released, but didnt say who was',
#   'quote_index': '(3517,3669)',
#   'verb': 'said',
#   'verb_index': '(3512,3516)',
#   'quote_token_count': 28,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'he',
#   'speaker_index': '(4000,4002)',
#   'quote': 'Oh, and calling them white nationalist riots is a liberal media deceit',
#   'quote_index': '(3928,3998)',
#   'verb': 'said',
#   'verb_index': '(4003,4007)',
#   'quote_token_count': 13,
#   'quote_type': 'CSV',
#   'is_floating_quote': False},
#  {'speaker': 'Rohrabacher',
#   'speaker_index': '(4260,4271)',
#   'quote': 'It was a setup for these dumb Civil War re-enactors',
#   'quote_index': '(4207,4258)',
#   'verb': 'said',
#   'verb_index': '(4272,4276)',
#   'quote_token_count': 12,
#   'quote_type': 'CSV',
#   'is_floating_quote': False},
#  {'speaker': 'the nonpartisan Politifact.',
#   'speaker_index': '(4615,4642)',
#   'quote': 'Those of you who are fans of conspiracy connoisseur and conservative commentator Alex Jones, host of Info Wars, will recognize that scenario as one of his dreamscapes, which is Pants on Fire groundless,',
#   'quote_index': '(4399,4601)',
#   'verb': 'according to',
#   'verb_index': '(4602,4614)',
#   'quote_token_count': 37,
#   'quote_type': 'AccordingTo',
#   'is_floating_quote': False},
#  {'speaker': 'the latest federal filing information, and real estate investor Harley Rouda has raised $319,335.',
#   'speaker_index': '(4922,5019)',
#   'quote': 'Keirstead raised $138,504 shortly after jumping into the race,',
#   'quote_index': '(4846,4908)',
#   'verb': 'according to',
#   'verb_index': '(4909,4921)',
#   'quote_token_count': 11,
#   'quote_type': 'AccordingTo',
#   'is_floating_quote': False},
#  {'speaker': 'Aaron McCall, who heads the local chapter of the resistance group Indivisible',
#   'speaker_index': '(5490,5567)',
#   'quote': 'People saw incumbent and an R by his name, so they assumed that he supported Republican values',
#   'quote_index': '(5389,5483)',
#   'verb': 'said',
#   'verb_index': '(5485,5489)',
#   'quote_token_count': 18,
#   'quote_type': 'CVS',
#   'is_floating_quote': False},
#  {'speaker': 'Republicans',
#   'speaker_index': '(5648,5659)',
#   'quote': 'We didnt realize he was this unhinged',
#   'quote_index': '(5668,5705)',
#   'verb': 'tell',
#   'verb_index': '(5660,5664)',
#   'quote_token_count': 8,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Rohrabacher',
#   'speaker_index': '(5707,5718)',
#   'quote': 'that part of him would like to just spend time working on screenplays, playing guitar and surfing with his wife and teenage triplets',
#   'quote_index': '(5726,5858)',
#   'verb': 'admits',
#   'verb_index': '(5719,5725)',
#   'quote_token_count': 24,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Ting',
#   'speaker_index': '(605,609)',
#   'quote': 'Trumps tax reform plan was nothing more than a middle-class tax increase',
#   'quote_index': '(531,603)',
#   'verb': 'said',
#   'verb_index': '(610,614)',
#   'quote_token_count': 14,
#   'quote_type': 'CSV',
#   'is_floating_quote': False},
#  {'speaker': 'Jeremiah Levine, an attorney with Morrison Foerster who represented the voting-rights groups',
#   'speaker_index': '(672,764)',
#   'quote': 'We are very pleased that Californians will have easier access to voter registration',
#   'quote_index': '(581,664)',
#   'verb': 'said',
#   'verb_index': '(667,671)',
#   'quote_token_count': 13,
#   'quote_type': 'QCQVS',
#   'is_floating_quote': False},
#  {'speaker': 'the lawsuit filed last May',
#   'speaker_index': '(1737,1763)',
#   'quote': ', California ranks "a dismal 46th in the nation" in its rate of registered voters.',
#   'quote_index': '(1763,1845)',
#   'verb': 'according to',
#   'verb_index': '(1724,1736)',
#   'quote_token_count': 18,
#   'quote_type': 'AccordingTo',
#   'is_floating_quote': False},
#  {'speaker': 'state data.\n .\n ',
#   'speaker_index': '(1936,1952)',
#   'quote': 'More than 5.5 million eligible voters were unregistered as of February 2017,',
#   'quote_index': '(1846,1922)',
#   'verb': 'according to',
#   'verb_index': '(1923,1935)',
#   'quote_token_count': 13,
#   'quote_type': 'AccordingTo',
#   'is_floating_quote': False},
#  {'speaker': '',
#   'speaker_index': '(0,0)',
#   'quote': '"We are especially satisfied that changes will be made before California’s statewide and federal primary elections."',
#   'quote_index': '(766,882)',
#   'verb': '',
#   'verb_index': '',
#   'quote_token_count': 20,
#   'quote_type': 'Heuristic',
#   'is_floating_quote': False},
#  {'speaker': 'who',
#   'speaker_index': '(633,636)',
#   'quote': '"Once again, Charlie Crist has put politics ahead of principled policy-making. Not only would this commonsense measure have provided women with vital information as they make a critical decision, but now Governor Crist’s veto also clears the way for taxpayer funding of abortion in Florida. This veto will now make it harder for Florida to fight Obamacare, since the bill would have enabled our state to opt out of the abortion coverage mandate in the federal health care law.\n .\n "',
#   'quote_index': '(140,622)',
#   'verb': 'agree',
#   'verb_index': '(637,642)',
#   'quote_token_count': 93,
#   'quote_type': 'Heuristic',
#   'is_floating_quote': False},
#  {'speaker': 'the latest PPP poll',
#   'speaker_index': '(894,913)',
#   'quote': ', Crist is only at 38% today with Democrats.',
#   'quote_index': '(913,957)',
#   'verb': 'according to',
#   'verb_index': '(881,893)',
#   'quote_token_count': 11,
#   'quote_type': 'AccordingTo',
#   'is_floating_quote': False},
#  {'speaker': 'Democrats who support Crist keep',
#   'speaker_index': '(1954,1986)',
#   'quote': 'well, we just need Dems to vote for Crist," but that just isn\'t going to happen in the margins he needs to win',
#   'quote_index': '(2002,2112)',
#   'verb': 'saying',
#   'verb_index': '(1987,1993)',
#   'quote_token_count': 27,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Hasner',
#   'speaker_index': '(382,388)',
#   'quote': 'that oral arguments would begin in the constitutional challenge launched by Florida and other states against the law',
#   'quote_index': '(264,380)',
#   'verb': 'noting',
#   'verb_index': '(257,263)',
#   'quote_token_count': 18,
#   'quote_type': 'VCS',
#   'is_floating_quote': False},
#  {'speaker': 'Hasner',
#   'speaker_index': '(382,388)',
#   'quote': 'the health-care law was undermining economic recovery',
#   'quote_index': '(398,451)',
#   'verb': 'insisted',
#   'verb_index': '(389,397)',
#   'quote_token_count': 9,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Hasner',
#   'speaker_index': '(800,806)',
#   'quote': 'Led by Florida Attorney General Pam Bondi, the states have already won significant legal victories against this overreach by the federal government',
#   'quote_index': '(646,793)',
#   'verb': 'said',
#   'verb_index': '(795,799)',
#   'quote_token_count': 23,
#   'quote_type': 'CVS',
#   'is_floating_quote': False},
#  {'speaker': 'the head of the Congressional Budget Office',
#   'speaker_index': '(1210,1253)',
#   'quote': 'that implementation of Obamacare would cost 800,000 jobs',
#   'quote_index': '(1280,1336)',
#   'verb': 'testified',
#   'verb_index': '(1254,1263)',
#   'quote_token_count': 8,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'an election supervisor',
#   'speaker_index': '(1265,1287)',
#   'quote': "it's not absolutely necessary to keep all of his or her polling places open a full 12 hours a day, which isn't unusual for rural areas",
#   'quote_index': '(1294,1428)',
#   'verb': 'finds',
#   'verb_index': '(1288,1293)',
#   'quote_token_count': 29,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Critics of the new election law',
#   'speaker_index': '(1537,1568)',
#   'quote': 'there will be less time to vote',
#   'quote_index': '(1577,1608)',
#   'verb': 'suggest',
#   'verb_index': '(1569,1576)',
#   'quote_token_count': 7,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'some critics',
#   'speaker_index': '(2662,2674)',
#   'quote': "third-party voter organizations don't have enough time to register voters under this new law",
#   'quote_index': '(2681,2773)',
#   'verb': 'claim',
#   'verb_index': '(2675,2680)',
#   'quote_token_count': 17,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'yet another major medical device manufacturer',
#   'speaker_index': '(995,1040)',
#   'quote': 'they were cutting more than 1,000 jobs because of new Obamacare taxes',
#   'quote_index': '(1051,1120)',
#   'verb': 'announced',
#   'verb_index': '(1041,1050)',
#   'quote_token_count': 12,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'she',
#   'speaker_index': '(187,190)',
#   'quote': 'In this district, there is a large number of people who went to the polls tonight who didnt support the president to begin with and dont support Democrats and its nothing more than that',
#   'quote_index': '(0,185)',
#   'verb': 'said',
#   'verb_index': '(191,195)',
#   'quote_token_count': 37,
#   'quote_type': 'CSV',
#   'is_floating_quote': False},
#  {'speaker': 'Mr. Turner',
#   'speaker_index': '(225,235)',
#   'quote': 'that the election had been a referendum on the president, his buoyant supporters,',
#   'quote_index': '(245,326)',
#   'verb': 'declared',
#   'verb_index': '(236,244)',
#   'quote_token_count': 15,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Mr. Turner',
#   'speaker_index': '(464,474)',
#   'quote': 'that voters elsewhere would also rebuke Mr. Obama in the elections next year',
#   'quote_index': '(485,561)',
#   'verb': 'predicted',
#   'verb_index': '(475,484)',
#   'quote_token_count': 13,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'he',
#   'speaker_index': '(593,595)',
#   'quote': 'We have lit one candle today',
#   'quote_index': '(563,591)',
#   'verb': 'said',
#   'verb_index': '(596,600)',
#   'quote_token_count': 6,
#   'quote_type': 'CSV',
#   'is_floating_quote': False},
#  {'speaker': 'Mr. Weprin',
#   'speaker_index': '(641,651)',
#   'quote': 'that he still hoped that he would overtake Mr. Turner as more returns came in',
#   'quote_index': '(756,833)',
#   'verb': 'telling',
#   'verb_index': '(733,740)',
#   'quote_token_count': 15,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Mr. Weprin',
#   'speaker_index': '(915,925)',
#   'quote': 'he had called Mr. Turner and had conceded the race',
#   'quote_index': '(931,981)',
#   'verb': 'said',
#   'verb_index': '(926,930)',
#   'quote_token_count': 10,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Mr. Weprin',
#   'speaker_index': '(1147,1157)',
#   'quote': 'Photo Im incredibly proud of the campaign that we ran, and incredibly grateful to the countless volunteers who worked day after day to bring our message to voters',
#   'quote_index': '(983,1145)',
#   'verb': 'said',
#   'verb_index': '(1158,1162)',
#   'quote_token_count': 30,
#   'quote_type': 'CSV',
#   'is_floating_quote': False},
#  {'speaker': 'Linda Goldberg, 61,',
#   'speaker_index': '(1940,1959)',
#   'quote': 'I am a registered Democrat, I have always been a registered Democrat, I come from a family of Democrats and I hate to say this, I voted Republican',
#   'quote_index': '(1787,1933)',
#   'verb': 'said',
#   'verb_index': '(1935,1939)',
#   'quote_token_count': 31,
#   'quote_type': 'CVS',
#   'is_floating_quote': False},
#  {'speaker': 'several voters interviewed on Tuesday',
#   'speaker_index': '(4104,4141)',
#   'quote': 'the Israel issue was a major factor in their decision to support Mr. Turner, who is Roman Catholic',
#   'quote_index': '(4147,4245)',
#   'verb': 'said',
#   'verb_index': '(4142,4146)',
#   'quote_token_count': 19,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Mr. Weprin',
#   'speaker_index': '(4301,4311)',
#   'quote': 'that Mr. Turner was in sync with the Tea Party and would seek to weaken Social Security and Medicare',
#   'quote_index': '(4394,4494)',
#   'verb': 'telling',
#   'verb_index': '(4381,4388)',
#   'quote_token_count': 19,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Photo Erik Huneke, 35, a history Ph.D. candidate who voted for Mr. Weprin,',
#   'speaker_index': '(4496,4570)',
#   'quote': 'that setting aside discussion of national symbolism, there was no question that Mr. Weprins platform better suited the political leanings of most voters in the district',
#   'quote_index': '(4576,4744)',
#   'verb': 'said',
#   'verb_index': '(4571,4575)',
#   'quote_token_count': 27,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Mr. Huneke',
#   'speaker_index': '(4789,4799)',
#   'quote': 'Its understandable for people to be upset',
#   'quote_index': '(4746,4787)',
#   'verb': 'said',
#   'verb_index': '(4800,4804)',
#   'quote_token_count': 7,
#   'quote_type': 'CSV',
#   'is_floating_quote': False},
#  {'speaker': 'Mr. Doherty, a retired social worker,',
#   'speaker_index': '(5165,5202)',
#   'quote': 'his concern about entitlement programs had been overshadowed by the opportunity he saw to express his unhappiness about the economy in the special election',
#   'quote_index': '(5208,5363)',
#   'verb': 'said',
#   'verb_index': '(5203,5207)',
#   'quote_token_count': 24,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'he',
#   'speaker_index': '(5455,5457)',
#   'quote': 'Advertisement Continue reading the main story We need to deliver a message to Washington',
#   'quote_index': '(5365,5453)',
#   'verb': 'said',
#   'verb_index': '(5458,5462)',
#   'quote_token_count': 14,
#   'quote_type': 'CSV',
#   'is_floating_quote': False},
#  {'speaker': 'Rooney',
#   'speaker_index': '(488,494)',
#   'quote': 'The family farm is a cornerstone of our nation’s economy and food supply, and it is a way of life for farmers across Florida and the country',
#   'quote_index': '(345,485)',
#   'verb': 'said',
#   'verb_index': '(495,499)',
#   'quote_token_count': 29,
#   'quote_type': 'QCQSV',
#   'is_floating_quote': False},
#  {'speaker': 'Washington',
#   'speaker_index': '(0,10)',
#   'quote': '"Preserving America’s Family Farm Act,"',
#   'quote_index': '(162,201)',
#   'verb': 'cosponsored',
#   'verb_index': '(135,146)',
#   'quote_token_count': 9,
#   'quote_type': 'Heuristic',
#   'is_floating_quote': False},
#  {'speaker': 'bill',
#   'speaker_index': '(729,733)',
#   'quote': '"The unreasonable, overreaching mandates proposed by the Department of Labor would severely restrict the ability of young people to work on family farms, and it would threaten generations of farm tradition and culture.\n .\n "',
#   'quote_index': '(501,725)',
#   'verb': 'uphold',
#   'verb_index': '(740,746)',
#   'quote_token_count': 41,
#   'quote_type': 'Heuristic',
#   'is_floating_quote': False},
#  {'speaker': 'him',
#   'speaker_index': '(145,148)',
#   'quote': 'how policies like Obamacare would impact his business and employees he had come to see as family',
#   'quote_index': '(157,253)',
#   'verb': 'explain',
#   'verb_index': '(149,156)',
#   'quote_token_count': 17,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'He',
#   'speaker_index': '(1436,1438)',
#   'quote': "that the individual mandate wasn't a tax",
#   'quote_index': '(1467,1507)',
#   'verb': 'assured',
#   'verb_index': '(1439,1446)',
#   'quote_token_count': 8,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'he',
#   'speaker_index': '(1584,1586)',
#   'quote': "that it was permissible under Congress' taxing power",
#   'quote_index': '(1613,1665)',
#   'verb': 'arguing',
#   'verb_index': '(1605,1612)',
#   'quote_token_count': 9,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Miami, FL — Congresswoman Frederica Wilson (FL-24)',
#   'speaker_index': '(0,50)',
#   'quote': 'that the Federal Aviation Administration has delayed the planned closure of the North Perry Airport contract control tower',
#   'quote_index': '(67,189)',
#   'verb': 'announced',
#   'verb_index': '(51,60)',
#   'quote_token_count': 18,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': '',
#   'speaker_index': '(0,0)',
#   'quote': '"Today’s announcement by the FAA is a step in the right direction. I will continue to make this airport my top priority, and I am confident that we will win long-term funding. This is part of a broader struggle to stop the "',
#   'quote_index': '(928,1152)',
#   'verb': '',
#   'verb_index': '',
#   'quote_token_count': 50,
#   'quote_type': 'Heuristic',
#   'is_floating_quote': False},
#  {'speaker': '',
#   'speaker_index': '(0,0)',
#   'quote': '", which destroys jobs and threatens our public safety, our children’s education, and our health.  In Congress, I am leading the charge to eliminate the "',
#   'quote_index': '(1161,1315)',
#   'verb': '',
#   'verb_index': '',
#   'quote_token_count': 33,
#   'quote_type': 'Heuristic',
#   'is_floating_quote': False},
#  {'speaker': 'He',
#   'speaker_index': '(6727,6729)',
#   'quote': 'that the more accurate description is "jobs that Americans won’t do at that price point"',
#   'quote_index': '(6751,6839)',
#   'verb': 'points',
#   'verb_index': '(6740,6746)',
#   'quote_token_count': 18,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': '',
#   'speaker_index': '(0,0)',
#   'quote': '"jobs that Americans won’t do"',
#   'quote_index': '(6695,6725)',
#   'verb': '',
#   'verb_index': '',
#   'quote_token_count': 8,
#   'quote_type': 'Heuristic',
#   'is_floating_quote': False},
#  {'speaker': 'He',
#   'speaker_index': '(6727,6729)',
#   'quote': 'that the more accurate description is "jobs that Americans won’t do at that price point"',
#   'quote_index': '(6751,6839)',
#   'verb': 'points',
#   'verb_index': '(6740,6746)',
#   'quote_token_count': 18,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': '',
#   'speaker_index': '(0,0)',
#   'quote': '"jobs that Americans won’t do"',
#   'quote_index': '(6695,6725)',
#   'verb': '',
#   'verb_index': '',
#   'quote_token_count': 8,
#   'quote_type': 'Heuristic',
#   'is_floating_quote': False},
#  {'speaker': 'Sanders',
#   'speaker_index': '(1199,1206)',
#   'quote': 'immigration reform will further damage youth job prospects',
#   'quote_index': '(1212,1270)',
#   'verb': 'says',
#   'verb_index': '(1207,1211)',
#   'quote_token_count': 8,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'the proposed statute as written',
#   'speaker_index': '(1990,2021)',
#   'quote': ', all the money would need to be spent in a year-and-three-months period.',
#   'quote_index': '(2021,2094)',
#   'verb': 'according to',
#   'verb_index': '(1977,1989)',
#   'quote_token_count': 20,
#   'quote_type': 'AccordingTo',
#   'is_floating_quote': False},
#  {'speaker': 'A GOP senate aide',
#   'speaker_index': '(2408,2425)',
#   'quote': 'that for the country to be able to spend $1.5 billion on such a program so fast',
#   'quote_index': '(2446,2525)',
#   'verb': 'told',
#   'verb_index': '(2426,2430)',
#   'quote_token_count': 18,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'A GOP senate aide',
#   'speaker_index': '(2408,2425)',
#   'quote': ', it would need to buy, lease or rent motor vehicles for beneficiaries of the new government handout',
#   'quote_index': '(2525,2625)',
#   'verb': 'told',
#   'verb_index': '(2426,2430)',
#   'quote_token_count': 19,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'the GOP aide',
#   'speaker_index': '(3027,3039)',
#   'quote': 'This appears to give states authority to buy, lease or rent motorcycles, cars and scooters or anything kids want to buy to get to and from a job',
#   'quote_index': '(2881,3025)',
#   'verb': 'said',
#   'verb_index': '(3040,3044)',
#   'quote_token_count': 30,
#   'quote_type': 'CSV',
#   'is_floating_quote': False},
#  {'speaker': 'Sen. Darren Soto',
#   'speaker_index': '(1637,1653)',
#   'quote': 'We need to get our economy back on track for these families, but',
#   'quote_index': '(1489,1553)',
#   'verb': 'said',
#   'verb_index': '(1632,1636)',
#   'quote_token_count': 14,
#   'quote_type': 'CVS',
#   'is_floating_quote': False},
#  {'speaker': 'Sen. Darren Soto',
#   'speaker_index': '(1637,1653)',
#   'quote': 'cutting our way to prosperity is just another part of Scotts State of Denial',
#   'quote_index': '(1554,1630)',
#   'verb': 'said',
#   'verb_index': '(1632,1636)',
#   'quote_token_count': 14,
#   'quote_type': 'CVS',
#   'is_floating_quote': False},
#  {'speaker': 'Soto',
#   'speaker_index': '(1731,1735)',
#   'quote': 'that no amount of election year about-faces on teacher pay and Medicaid expansion will convince Floridians that the Governor has their interests in mind',
#   'quote_index': '(1741,1893)',
#   'verb': 'said',
#   'verb_index': '(1736,1740)',
#   'quote_token_count': 26,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Castor Dentel',
#   'speaker_index': '(2062,2075)',
#   'quote': 'We know his record',
#   'quote_index': '(2037,2055)',
#   'verb': 'said',
#   'verb_index': '(2057,2061)',
#   'quote_token_count': 4,
#   'quote_type': 'CVS',
#   'is_floating_quote': False},
#  {'speaker': 'Bullard',
#   'speaker_index': '(2354,2361)',
#   'quote': 'We need a lasting and substantial commitment to public education, not a soundbite',
#   'quote_index': '(2266,2347)',
#   'verb': 'said',
#   'verb_index': '(2349,2353)',
#   'quote_token_count': 14,
#   'quote_type': 'CVS',
#   'is_floating_quote': False},
#  {'speaker': 'Rick Scott',
#   'speaker_index': '(2363,2373)',
#   'quote': 'he can just flip a switch and undo all of the harm he has done',
#   'quote_index': '(2381,2443)',
#   'verb': 'thinks',
#   'verb_index': '(2374,2380)',
#   'quote_token_count': 15,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Rick Scott',
#   'speaker_index': '(2363,2373)',
#   'quote': 'Well Governor, you need to walk the walk',
#   'quote_index': '(2444,2484)',
#   'verb': 'thinks',
#   'verb_index': '(2374,2380)',
#   'quote_token_count': 9,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Representative Mark Pafford',
#   'speaker_index': '(2486,2513)',
#   'quote': 'what makes these cuts so much worse is that this money isnt going back to the taxpayers or into other state projects; its being given away to corporations and special interests with no accountability',
#   'quote_index': '(2520,2719)',
#   'verb': 'said',
#   'verb_index': '(2514,2518)',
#   'quote_token_count': 36,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'preliminary estimates* released by VISIT FLORIDA',
#   'speaker_index': '(126,174)',
#   'quote': '– the state’s official tourism marketing corporation – 22.9 million visitors came to Florida in the third quarter of 2013 (July-September), an increase of 1.7 percent over the same period in 2012',
#   'quote_index': '(175,370)',
#   'verb': 'according to',
#   'verb_index': '(113,125)',
#   'quote_token_count': 38,
#   'quote_type': 'AccordingTo',
#   'is_floating_quote': False},
#  {'speaker': 'Governor Scott',
#   'speaker_index': '(465,479)',
#   'quote': 'Today’s announcement of another record quarter for visitation clearly shows ‘It’s Working’ in Florida',
#   'quote_index': '(487,588)',
#   'verb': 'said',
#   'verb_index': '(480,484)',
#   'quote_token_count': 18,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Tammy Gustafson, Chair of the VISIT FLORIDA Board of Directors',
#   'speaker_index': '(1719,1781)',
#   'quote': '"So far this year, we’re up nearly 2.5 million visitors who increased their spending by almost $3 billion, led by a double-digit increase in international visitors',
#   'quote_index': '(1548,1711)',
#   'verb': 'said',
#   'verb_index': '(1714,1718)',
#   'quote_token_count': 33,
#   'quote_type': 'QCQVS',
#   'is_floating_quote': False},
#  {'speaker': 'Will Seccombe, President and CEO of VISIT FLORIDA',
#   'speaker_index': '(2472,2521)',
#   'quote': 'Record visitor numbers equate to record visitor spending',
#   'quote_index': '(2408,2464)',
#   'verb': 'said',
#   'verb_index': '(2467,2471)',
#   'quote_token_count': 8,
#   'quote_type': 'QCQVS',
#   'is_floating_quote': False},
#  {'speaker': 'Carol Dover, President and CEO of the Florida Restaurant and Lodging Association',
#   'speaker_index': '(2698,2778)',
#   'quote': 'These newly released tourism numbers are encouraging to our more than 10,000 members of the Florida Restaurant and Lodging Association in our effort to attract over 100 million visitors to the Sunshine State',
#   'quote_index': '(2786,2993)',
#   'verb': 'said',
#   'verb_index': '(2779,2783)',
#   'quote_token_count': 33,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': '',
#   'speaker_index': '(0,0)',
#   'quote': '"This continued momentum is a testament to the strength of VISIT FLORIDA’s marketing efforts, the power of the Sunshine State brand and the dedication of the nearly 1.1 million Floridians who work in the state’s tourism industry."',
#   'quote_index': '(1783,2013)',
#   'verb': '',
#   'verb_index': '',
#   'quote_token_count': 43,
#   'quote_type': 'Heuristic',
#   'is_floating_quote': False},
#  {'speaker': '',
#   'speaker_index': '(0,0)',
#   'quote': '"With taxable sales up, occupancy rates up, rental car collections up, bed taxes up and average daily room rates up, Florida’s tourism industry has never been stronger."',
#   'quote_index': '(2523,2692)',
#   'verb': '',
#   'verb_index': '',
#   'quote_token_count': 35,
#   'quote_type': 'Heuristic',
#   'is_floating_quote': False},
#  {'speaker': 'Josh Schwerin of the Democratic Congressional Campaign Committee',
#   'speaker_index': '(390,454)',
#   'quote': 'It’s a shame that when Congresswoman Ros-Lehtinen had a chance to do something to help shorten the wait time at the VA she voted no',
#   'quote_index': '(251,382)',
#   'verb': 'said',
#   'verb_index': '(385,389)',
#   'quote_token_count': 28,
#   'quote_type': 'QCQVS',
#   'is_floating_quote': False},
#  {'speaker': 'the Associated Press',
#   'speaker_index': '(1619,1639)',
#   'quote': 'would "likely result" in the shutdown of the federal government',
#   'quote_index': '(1649,1712)',
#   'verb': 'reported',
#   'verb_index': '(1640,1648)',
#   'quote_token_count': 12,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'the OMB',
#   'speaker_index': '(1898,1905)',
#   'quote': 'that the shutdown "delayed workshops for 1,400 military service members to help them transition to civilian life and employment',
#   'quote_index': '(1915,2042)',
#   'verb': 'reported',
#   'verb_index': '(1906,1914)',
#   'quote_token_count': 20,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'defense officials',
#   'speaker_index': '(2338,2355)',
#   'quote': '"But until the lapse in federal funding ends, the families of deceased military personnel cannot expect to receive the "death gratuity" of $100,000 the Defense Department deposits in their bank account within 24 to 36 hours',
#   'quote_index': '(2113,2336)',
#   'verb': 'said',
#   'verb_index': '(2356,2360)',
#   'quote_token_count': 42,
#   'quote_type': 'CSV',
#   'is_floating_quote': False},
#  {'speaker': 'defense officials',
#   'speaker_index': '(2338,2355)',
#   'quote': ']Grieving families also cannot expect the military to cover the usual costs of travel to meet their loved ones returning home in American flag-draped coffins through Dover Air Force Base, or pay for funerals and burials, according to the Defense Department',
#   'quote_index': '(2363,2619)',
#   'verb': 'said',
#   'verb_index': '(2356,2360)',
#   'quote_token_count': 47,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'the VA',
#   'speaker_index': '(2833,2839)',
#   'quote': 'All public access to the VA’s 56 regional offices was suspended Tuesday because of a lack of funds',
#   'quote_index': '(2733,2831)',
#   'verb': 'said',
#   'verb_index': '(2840,2844)',
#   'quote_token_count': 19,
#   'quote_type': 'CSV',
#   'is_floating_quote': False},
#  {'speaker': 'the VA',
#   'speaker_index': '(2833,2839)',
#   'quote': ']The VA is also suspending services such as educational and vocational counseling and outreach programs, including those conducted at military facilities',
#   'quote_index': '(2847,3000)',
#   'verb': 'said',
#   'verb_index': '(2840,2844)',
#   'quote_token_count': 23,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Robert Chishold, a prominent veterans’ law attorney',
#   'speaker_index': '(4114,4165)',
#   'quote': 'That’s not what this country is about',
#   'quote_index': '(4074,4111)',
#   'verb': 'said',
#   'verb_index': '(4166,4170)',
#   'quote_token_count': 8,
#   'quote_type': 'CSV',
#   'is_floating_quote': False},
#  {'speaker': 'CNN',
#   'speaker_index': '(5073,5076)',
#   'quote': ', the cuts would have hurt some 11,000 homeless veterans who qualified for housing in 2011 but had not received vouchers.',
#   'quote_index': '(5076,5197)',
#   'verb': 'according to',
#   'verb_index': '(5060,5072)',
#   'quote_token_count': 22,
#   'quote_type': 'AccordingTo',
#   'is_floating_quote': False},
#  {'speaker': '',
#   'speaker_index': '(0,0)',
#   'quote': '"Congresswoman Ros-Lehtinen voted against a commonsense solution to this problem and our heroes deserve better."',
#   'quote_index': '(456,568)',
#   'verb': '',
#   'verb_index': '',
#   'quote_token_count': 20,
#   'quote_type': 'Heuristic',
#   'is_floating_quote': False},
#  {'speaker': 'the liars in the Democrat–controlled media',
#   'speaker_index': '(875,917)',
#   'quote': 'what these quislings have tried to force on Americans',
#   'quote_index': '(933,986)',
#   'verb': 'describe',
#   'verb_index': '(924,932)',
#   'quote_token_count': 9,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Even the Director of the FBI',
#   'speaker_index': '(132,160)',
#   'quote': 'that we cannot properly vet people coming from the Middle East',
#   'quote_index': '(166,228)',
#   'verb': 'said',
#   'verb_index': '(161,165)',
#   'quote_token_count': 12,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Obama',
#   'speaker_index': '(578,583)',
#   'quote': 'the problem with American health care was access',
#   'quote_index': '(592,640)',
#   'verb': 'thought',
#   'verb_index': '(584,591)',
#   'quote_token_count': 8,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'The Washington insiders',
#   'speaker_index': '(1007,1030)',
#   'quote': 'that Obamacare cannot be repealed',
#   'quote_index': '(1043,1076)',
#   'verb': 'say',
#   'verb_index': '(1039,1042)',
#   'quote_token_count': 6,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'today’s report',
#   'speaker_index': '(473,487)',
#   'quote': 'that negotiations began after Iran elected a ‘moderate’ leader',
#   'quote_index': '(409,471)',
#   'verb': 'telling',
#   'verb_index': '(390,397)',
#   'quote_token_count': 11,
#   'quote_type': 'VCS',
#   'is_floating_quote': False},
#  {'speaker': 'Rep. Murphy',
#   'speaker_index': '(375,386)',
#   'quote': 'In response to Marco Rubio’s transparent attempt to paper over his record of vehemently opposing all real forms of gun violence prevention, Patrick Murphy released the following statement:.\n "',
#   'quote_index': '(30,222)',
#   'verb': 'said',
#   'verb_index': '(370,374)',
#   'quote_token_count': 34,
#   'quote_type': 'CVS',
#   'is_floating_quote': False},
#  {'speaker': 'Rep. Murphy',
#   'speaker_index': '(375,386)',
#   'quote': 'Floridians won’t be fooled by Marco Rubio’s transparent attempt to paper over his relentless opposition to legislation that prevents gun violence',
#   'quote_index': '(222,367)',
#   'verb': 'said',
#   'verb_index': '(370,374)',
#   'quote_token_count': 23,
#   'quote_type': 'QCQVS',
#   'is_floating_quote': False},
#  {'speaker': 'he',
#   'speaker_index': '(847,849)',
#   'quote': 'instead of keeping Floridians safe',
#   'quote_index': '(901,935)',
#   'verb': 'continues',
#   'verb_index': '(850,859)',
#   'quote_token_count': 5,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': '',
#   'speaker_index': '(0,0)',
#   'quote': '"After the tragedy in Orlando, Rubio used the deaths of 49 innocent Floridians to run for re-election while voting against every bill that would have helped keep our families safe. He even voted against a bipartisan measure, introduced by a Republican, to prevent people on the No Fly List from purchasing guns.\n .\n "',
#   'quote_index': '(388,705)',
#   'verb': 'introduce',
#   'verb_index': '(724,733)',
#   'quote_token_count': 64,
#   'quote_type': 'Heuristic',
#   'is_floating_quote': False},
#  {'speaker': 'Morgan',
#   'speaker_index': '(293,299)',
#   'quote': 'that the job of African-Americans in this country is to mimic white Americans whenever possible',
#   'quote_index': '(310,405)',
#   'verb': 'explained',
#   'verb_index': '(300,309)',
#   'quote_token_count': 17,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Morgan, who deems himself an expert on minority issues, even though hes probably never read a book by a black scholar, or a book on poverty in America for that matter',
#   'speaker_index': '(735,901)',
#   'quote': 'most issues in the black Escambia community are perceived as opposed to real',
#   'quote_index': '(908,984)',
#   'verb': 'says',
#   'verb_index': '(903,907)',
#   'quote_token_count': 13,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Sheriff Morgan',
#   'speaker_index': '(1196,1210)',
#   'quote': 'The problem isnt racism',
#   'quote_index': '(1171,1194)',
#   'verb': 'says',
#   'verb_index': '(1211,1215)',
#   'quote_token_count': 5,
#   'quote_type': 'CSV',
#   'is_floating_quote': False},
#  {'speaker': 'you',
#   'speaker_index': '(1770,1773)',
#   'quote': 'that the mainstream media would be reporting this story non-stop',
#   'quote_index': '(1786,1850)',
#   'verb': 'think',
#   'verb_index': '(1780,1785)',
#   'quote_token_count': 12,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'The Gateway Pundit',
#   'speaker_index': '(3485,3503)',
#   'quote': 'the FBI seized smashed hard drives belonging to Imran Awan',
#   'quote_index': '(3524,3582)',
#   'verb': 'reported',
#   'verb_index': '(3515,3523)',
#   'quote_token_count': 10,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'John Cardillo',
#   'speaker_index': '(4091,4104)',
#   'quote': 'Florida politicos who have known Wasserman Schultz for years are telling me she’s a nervous wreck, barely able to function since Imran Awan’s arrest',
#   'quote_index': '(4115,4263)',
#   'verb': 'reports',
#   'verb_index': '(4105,4112)',
#   'quote_token_count': 27,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'The current mayor',
#   'speaker_index': '(1585,1602)',
#   'quote': 'both former mayors failed to adequately maintain the sewer system in the 14 years before he took office',
#   'quote_index': '(1612,1715)',
#   'verb': 'said',
#   'verb_index': '(1607,1611)',
#   'quote_token_count': 18,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Kriseman',
#   'speaker_index': '(1717,1725)',
#   'quote': 'he inherited their mess',
#   'quote_index': '(1731,1754)',
#   'verb': 'said',
#   'verb_index': '(1726,1730)',
#   'quote_token_count': 4,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'the city',
#   'speaker_index': '(2006,2014)',
#   'quote': 'One question has a clear answer',
#   'quote_index': '(1938,1969)',
#   'verb': 'says',
#   'verb_index': '(2015,2019)',
#   'quote_token_count': 6,
#   'quote_type': 'CSV',
#   'is_floating_quote': False},
#  {'speaker': 'the city',
#   'speaker_index': '(2006,2014)',
#   'quote': 'it has discharged nearly 186 million gallons of sewage over the last two summers',
#   'quote_index': '(2020,2100)',
#   'verb': 'says',
#   'verb_index': '(2015,2019)',
#   'quote_token_count': 14,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Kriseman',
#   'speaker_index': '(2489,2497)',
#   'quote': 'Clearly, there is no comparison in the numbers',
#   'quote_index': '(2440,2486)',
#   'verb': 'said',
#   'verb_index': '(2498,2502)',
#   'quote_token_count': 9,
#   'quote_type': 'QCQSV',
#   'is_floating_quote': False},
#  {'speaker': 'Baker',
#   'speaker_index': '(3055,3060)',
#   'quote': "Albert Whitted sewage plant was behind much of Kriseman's troubles",
#   'quote_index': '(3177,3243)',
#   'verb': 'saying',
#   'verb_index': '(3093,3099)',
#   'quote_token_count': 11,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Baker',
#   'speaker_index': '(4400,4405)',
#   'quote': '"We invested everything that was recommended to me by either my staff or FDEP under the consent order to get the system to the point where we didn\'t have spills',
#   'quote_index': '(4237,4397)',
#   'verb': 'said',
#   'verb_index': '(4406,4410)',
#   'quote_token_count': 32,
#   'quote_type': 'QCQSV',
#   'is_floating_quote': False},
#  {'speaker': 'Kriseman',
#   'speaker_index': '(4804,4812)',
#   'quote': "the Baker administration didn't spend enough to keep the system ahead of the natural curve of deteriorating pipes",
#   'quote_index': '(4818,4931)',
#   'verb': 'said',
#   'verb_index': '(4813,4817)',
#   'quote_token_count': 19,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Kriseman',
#   'speaker_index': '(4983,4991)',
#   'quote': 'He had a consent order that had to be followed',
#   'quote_index': '(4934,4980)',
#   'verb': 'said',
#   'verb_index': '(4992,4996)',
#   'quote_token_count': 10,
# ...
#   'quote_index': '(1579,1742)',
#   'verb': 'concluded',
#   'verb_index': '(1569,1578)',
#   'quote_token_count': 27,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'the large amount of geothermal heat beneath the ice sheet,',
#   'speaker_index': '(1818,1876)',
#   'quote': 'why ice streams and subglacial lakes are so abundant and dynamic in this region',
#   'quote_index': '(1928,2007)',
#   'verb': 'explain',
#   'verb_index': '(1920,1927)',
#   'quote_token_count': 14,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'One',
#   'speaker_index': '(257,260)',
#   'quote': 'that someone in Sweden is mad as hell and bringing fire and brimstone to the facilities that are to be used for refugees',
#   'quote_index': '(271,391)',
#   'verb': 'say',
#   'verb_index': '(267,270)',
#   'quote_token_count': 23,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Two more shelters intended for refugees',
#   'speaker_index': '(484,523)',
#   'quote': 'a recent series arson of attacks that police believe are directed against arriving asylum seekers amidst the migrant crisis in Europe',
#   'quote_index': '(564,697)',
#   'verb': 'continuing',
#   'verb_index': '(553,563)',
#   'quote_token_count': 21,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'multiple Vatican cardinals',
#   'speaker_index': '(150,176)',
#   'quote': 'Pope Francis is the false prophet foretold in holy scripture and prophecy',
#   'quote_index': '(207,280)',
#   'verb': 'declaring',
#   'verb_index': '(197,206)',
#   'quote_token_count': 12,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Hardcore Francis apologists',
#   'speaker_index': '(1002,1029)',
#   'quote': 'the quote was taken out of context,',
#   'quote_index': '(1036,1071)',
#   'verb': 'claim',
#   'verb_index': '(1030,1035)',
#   'quote_token_count': 8,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'he',
#   'speaker_index': '(1266,1268)',
#   'quote': 'that Jesus Christ made himself the devil, the serpent, for us, according to LOsservatore Romano, the daily newspaper of the Vatican',
#   'quote_index': '(1274,1405)',
#   'verb': 'said',
#   'verb_index': '(1269,1273)',
#   'quote_token_count': 25,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Pope Francis',
#   'speaker_index': '(2056,2068)',
#   'quote': 'that the United States of America has a distorted vision of the world and Americans',
#   'quote_index': '(2110,2193)',
#   'verb': 'told',
#   'verb_index': '(2069,2073)',
#   'quote_token_count': 15,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'the Pope',
#   'speaker_index': '(2512,2520)',
#   'quote': 'that the United Nations doesnt have enough power and must be granted full governmental control for the good of humanity',
#   'quote_index': '(2526,2645)',
#   'verb': 'said',
#   'verb_index': '(2521,2525)',
#   'quote_token_count': 21,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Vladimir Putin',
#   'speaker_index': '(2716,2730)',
#   'quote': 'that Franciss unconventional teachings disqualified the Pope from calling himself a man of God',
#   'quote_index': '(2738,2832)',
#   'verb': 'argued',
#   'verb_index': '(2731,2737)',
#   'quote_token_count': 14,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Franciss own Cardinals',
#   'speaker_index': '(2834,2856)',
#   'quote': 'that he was installed in unusual circumstances, with the assistance of globalist powerbrokers like George Soros',
#   'quote_index': '(2921,3032)',
#   'verb': 'telling',
#   'verb_index': '(2889,2896)',
#   'quote_token_count': 17,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'First Lady Melania Trump',
#   'speaker_index': '(0,24)',
#   'quote': 'that if ISIS terrorists lay a finger on Barron Trump, she will scratch his eyes out',
#   'quote_index': '(66,149)',
#   'verb': 'warned',
#   'verb_index': '(29,35)',
#   'quote_token_count': 17,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'MEMRI',
#   'speaker_index': '(895,900)',
#   'quote': "Barron Trump goes to this school in Washington,'",
#   'quote_index': '(833,881)',
#   'verb': 'according to',
#   'verb_index': '(882,894)',
#   'quote_token_count': 10,
#   'quote_type': 'AccordingTo',
#   'is_floating_quote': False},
#  {'speaker': 'Melania Trump',
#   'speaker_index': '(1191,1204)',
#   'quote': 'that if his chickens come home to roost in my house, if anything happens to my son, I will scratch his eyes out',
#   'quote_index': '(1222,1333)',
#   'verb': 'warned',
#   'verb_index': '(1209,1215)',
#   'quote_token_count': 25,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Melania Trump',
#   'speaker_index': '(1424,1437)',
#   'quote': 'Supporting terrorists anywhere in the world can have serious and long term consequences',
#   'quote_index': '(1335,1422)',
#   'verb': 'said',
#   'verb_index': '(1438,1442)',
#   'quote_token_count': 13,
#   'quote_type': 'CSV',
#   'is_floating_quote': False},
#  {'speaker': 'Melania Trump',
#   'speaker_index': '(1424,1437)',
#   'quote': 'if any of these psychopaths so much as lay a finger on Barron there will be hell to pay',
#   'quote_index': '(1448,1535)',
#   'verb': 'said',
#   'verb_index': '(1438,1442)',
#   'quote_token_count': 19,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'the First Lady',
#   'speaker_index': '(1636,1650)',
#   'quote': 'Explaining that death threats from Islamic State terrorists have already had an impact on her son',
#   'quote_index': '(1537,1634)',
#   'verb': 'said',
#   'verb_index': '(1651,1655)',
#   'quote_token_count': 16,
#   'quote_type': 'CSV',
#   'is_floating_quote': False},
#  {'speaker': 'the First Lady',
#   'speaker_index': '(1636,1650)',
#   'quote': 'This is all on the head of Barack Obama',
#   'quote_index': '(1656,1695)',
#   'verb': 'said',
#   'verb_index': '(1651,1655)',
#   'quote_token_count': 9,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'HRW',
#   'speaker_index': '(762,765)',
#   'quote': 'the girls were detained for more than a year before the trial and never confessed committing any crime.',
#   'quote_index': '(766,869)',
#   'verb': 'according to',
#   'verb_index': '(749,761)',
#   'quote_token_count': 19,
#   'quote_type': 'AccordingTo',
#   'is_floating_quote': False},
#  {'speaker': 'The order',
#   'speaker_index': '(298,307)',
#   'quote': 'the un-American attitude displayed by the players, who repeatedly kneel during the National Anthem, burn flags in their locker rooms, and disrespect our country in every way imaginable',
#   'quote_index': '(314,498)',
#   'verb': 'notes',
#   'verb_index': '(308,313)',
#   'quote_token_count': 33,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'A white House spokeswoman',
#   'speaker_index': '(975,1000)',
#   'quote': 'that the President hopes to see all the "athletes protesting our police and our flag or otherwise using their positions to spread hate" fired and replaced with people who "love and respect America',
#   'quote_index': '(1021,1217)',
#   'verb': 'told',
#   'verb_index': '(1001,1005)',
#   'quote_token_count': 36,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': '',
#   'speaker_index': '(0,0)',
#   'quote': '"until it is clear that players and team owners respect their country."',
#   'quote_index': '(681,752)',
#   'verb': '',
#   'verb_index': '',
#   'quote_token_count': 15,
#   'quote_type': 'Heuristic',
#   'is_floating_quote': False},
#  {'speaker': '',
#   'speaker_index': '(0,0)',
#   'quote': '"if all of the problems are solved."',
#   'quote_index': '(933,969)',
#   'verb': '',
#   'verb_index': '',
#   'quote_token_count': 10,
#   'quote_type': 'Heuristic',
#   'is_floating_quote': False},
#  {'speaker': 'mayor Carmen Yulin Cruz',
#   'speaker_index': '(528,551)',
#   'quote': 'We simply don’t have the staff or resources to distribute countrywide',
#   'quote_index': '(456,525)',
#   'verb': 'told',
#   'verb_index': '(552,556)',
#   'quote_token_count': 12,
#   'quote_type': 'QCQSV',
#   'is_floating_quote': False},
#  {'speaker': '',
#   'speaker_index': '(0,0)',
#   'quote': '"anyone can come to San Juan if they need supplies."',
#   'quote_index': '(588,640)',
#   'verb': 'adding',
#   'verb_index': '(576,582)',
#   'quote_token_count': 13,
#   'quote_type': 'Heuristic',
#   'is_floating_quote': False},
#  {'speaker': 'Tulsa firefighters',
#   'speaker_index': '(77,95)',
#   'quote': 'that someone broke in the school threw the east wing door',
#   'quote_index': '(100,157)',
#   'verb': 'say',
#   'verb_index': '(96,99)',
#   'quote_token_count': 11,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': '',
#   'speaker_index': '(0,0)',
#   'quote': '"A well regulated State National Guard, being helpful to the safety and security of a State in times of need, along with the strictly regulated right of the people to keep and bear a limited number of non-automatic Arms for sport and hunting, with respect to the primary right of all people to be free from gun violence, this shall not be infringed."',
#   'quote_index': '(121,471)',
#   'verb': '',
#   'verb_index': '',
#   'quote_token_count': 72,
#   'quote_type': 'Heuristic',
#   'is_floating_quote': False},
#  {'speaker': 'The worlds youngest leader, newly-elected Sebastian Kurz,',
#   'speaker_index': '(0,57)',
#   'quote': 'that his Open Society Foundation has 28 days to cease and desist operations in Austria or face legal action for attempting to undermine the democracy of the nation',
#   'quote_index': '(84,247)',
#   'verb': 'informed',
#   'verb_index': '(62,70)',
#   'quote_token_count': 28,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': '31-year-old Sebastian Kurz, Austrias youngest ever leader,',
#   'speaker_index': '(249,307)',
#   'quote': 'that action must be taken immediately, after news broke that George Soros has donated $18 billion of his $24 billion dollar fortune to his Open Society Foundation',
#   'quote_index': '(328,490)',
#   'verb': 'told',
#   'verb_index': '(312,316)',
#   'quote_token_count': 30,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Kurz',
#   'speaker_index': '(527,531)',
#   'quote': 'The situation has become critical',
#   'quote_index': '(492,525)',
#   'verb': 'said',
#   'verb_index': '(532,536)',
#   'quote_token_count': 5,
#   'quote_type': 'CSV',
#   'is_floating_quote': False},
#  {'speaker': 'Kurz, a self-described truther who says he was red pilled by the 9/11 film Loose Change,',
#   'speaker_index': '(728,816)',
#   'quote': 'that he understands the Soros agenda',
#   'quote_index': '(824,860)',
#   'verb': 'claims',
#   'verb_index': '(817,823)',
#   'quote_token_count': 6,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'that',
#   'speaker_index': '(65,69)',
#   'quote': 'that they "have the right to compete in the free market regardless of who the competition is',
#   'quote_index': '(77,169)',
#   'verb': 'states',
#   'verb_index': '(70,76)',
#   'quote_token_count': 18,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'that',
#   'speaker_index': '(177,181)',
#   'quote': '"Since the guy on the corner is fleecing the terrified storm survivor for $7 per bottle, that’s what we get to charge the federal government.\n .\n And they’re paying it.\n .\n The Clintons stand to bring hundreds of millions of dollars into their foundation for "',
#   'quote_index': '(200,460)',
#   'verb': 'translates',
#   'verb_index': '(182,192)',
#   'quote_token_count': 57,
#   'quote_type': 'Heuristic',
#   'is_floating_quote': False},
#  {'speaker': '',
#   'speaker_index': '(0,0)',
#   'quote': '" that they can funnel to themselves as administrative costs and "',
#   'quote_index': '(472,538)',
#   'verb': '',
#   'verb_index': '',
#   'quote_token_count': 12,
#   'quote_type': 'Heuristic',
#   'is_floating_quote': False},
#  {'speaker': '',
#   'speaker_index': '(0,0)',
#   'quote': '".\n .\n Ships headed for Africa were re-routed through the Panama Canal at "',
#   'quote_index': '(547,622)',
#   'verb': '',
#   'verb_index': '',
#   'quote_token_count': 19,
#   'quote_type': 'Heuristic',
#   'is_floating_quote': False},
#  {'speaker': '',
#   'speaker_index': '(0,0)',
#   'quote': '" to bring the supplies they were carrying directly to the Gulf Coast.\n .\n Other items they were gouging were toilet paper at $10 per roll and tampons at $25 each. A bag of ice was going for $17 yesterday and is expected to skyrocket to $30 by tomorrow.\n .\n Remember…these aren’t what consumers pay. This is what FEMA is under contract to pay due to Obama era rules that give special consideration to "',
#   'quote_index': '(635,1037)',
#   'verb': '',
#   'verb_index': '',
#   'quote_token_count': 90,
#   'quote_type': 'Heuristic',
#   'is_floating_quote': False},
#  {'speaker': 'MAYADIN, SYRIAAbu Bakr al-Baghdadi, the leader of the Islamic State,',
#   'speaker_index': '(0,68)',
#   'quote': 'that ISIS would be immediately surrendering its fight to establish a powerful caliphate after viewing an interview in which pop singer Katy Perry said,',
#   'quote_index': '(111,262)',
#   'verb': 'confirming',
#   'verb_index': '(100,110)',
#   'quote_token_count': 25,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'al-Baghdadi',
#   'speaker_index': '(815,826)',
#   'quote': 'Despite my previous belief that we must slay the infidel in the name of Allah until Islam rules the world, I just cant deny that Katys words have touched my heart',
#   'quote_index': '(651,813)',
#   'verb': 'said',
#   'verb_index': '(827,831)',
#   'quote_token_count': 33,
#   'quote_type': 'CSV',
#   'is_floating_quote': False},
#  {'speaker': 'he',
#   'speaker_index': '(1036,1038)',
#   'quote': 'Its all so clear now',
#   'quote_index': '(1014,1034)',
#   'verb': 'added',
#   'verb_index': '(1039,1044)',
#   'quote_token_count': 5,
#   'quote_type': 'CSV',
#   'is_floating_quote': False},
#  {'speaker': 'reports',
#   'speaker_index': '(1382,1389)',
#   'quote': ', al-Baghdadi further confirmed that a recent advertisement in which Kendall Jenner offered a group of riot police a Pepsi was also influential in his decision to immediately cease their murderous reign of terror and lead ISIS down a path of peace.',
#   'quote_index': '(1389,1637)',
#   'verb': 'according to',
#   'verb_index': '(1369,1381)',
#   'quote_token_count': 45,
#   'quote_type': 'AccordingTo',
#   'is_floating_quote': False},
#  {'speaker': 'Pelosi',
#   'speaker_index': '(395,401)',
#   'quote': 'For too long we have been relying on an archaic idea that the President can only serve the United States if he or she has lived here all his or her life',
#   'quote_index': '(240,392)',
#   'verb': 'said',
#   'verb_index': '(402,406)',
#   'quote_token_count': 32,
#   'quote_type': 'CSV',
#   'is_floating_quote': False},
#  {'speaker': 'Pelosi',
#   'speaker_index': '(631,637)',
#   'quote': 'that it would not because "the embrace of the American people would be enough to ensure that the person does their very best',
#   'quote_index': '(648,772)',
#   'verb': 'explained',
#   'verb_index': '(638,647)',
#   'quote_token_count': 24,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  {'speaker': 'Rep. Olbermann',
#   'speaker_index': '(875,889)',
#   'quote': '"We are always willing to bring someone in from another country to run our corporations',
#   'quote_index': '(780,867)',
#   'verb': 'says',
#   'verb_index': '(870,874)',
#   'quote_token_count': 16,
#   'quote_type': 'QCQVS',
#   'is_floating_quote': False},
#  {'speaker': 'bill',
#   'speaker_index': '(428,432)',
#   'quote': '" Pelosi said in a statement. "',
#   'quote_index': '(393,424)',
#   'verb': 'prove',
#   'verb_index': '(439,444)',
#   'quote_token_count': 8,
#   'quote_type': 'Heuristic',
#   'is_floating_quote': False},
#  {'speaker': 'Michigan DNR Marine Biologist Dr. Debra Polowotski',
#   'speaker_index': '(134,184)',
#   'quote': 'the 21 foot-long giant squid to be a very rare fresh-water species of genus Architeuthis',
#   'quote_index': '(226,314)',
#   'verb': 'confirmed',
#   'verb_index': '(216,225)',
#   'quote_token_count': 19,
#   'quote_type': 'SVC',
#   'is_floating_quote': False},
#  ...]

# %%
dataset_df["quotes"] = [[doc["quote"] for doc in docs] 
                        for docs in quote_annotations]
dataset_df["quote_lengths"] = [[doc["quote_token_count"] for doc in docs] 
                        for docs in quote_annotations]
dataset_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 dataset_df["quotes"] = [[doc["quote"] for doc in docs]
#       2                         for docs in quote_annotations]
#       3 dataset_df["quote_lengths"] = [[doc["quote_token_count"] for doc in docs]
#       4                         for docs in quote_annotations]
#       5 dataset_df
#
# Cell In[8], line 1, in <listcomp>(.0)
# ----> 1 dataset_df["quotes"] = [[doc["quote"] for doc in docs]
#       2                         for docs in quote_annotations]
#       3 dataset_df["quote_lengths"] = [[doc["quote_token_count"] for doc in docs]
#       4                         for docs in quote_annotations]
#       5 dataset_df
#
# Cell In[8], line 1, in <listcomp>(.0)
# ----> 1 dataset_df["quotes"] = [[doc["quote"] for doc in docs]
#       2                         for docs in quote_annotations]
#       3 dataset_df["quote_lengths"] = [[doc["quote_token_count"] for doc in docs]
#       4                         for docs in quote_annotations]
#       5 dataset_df
#
# TypeError: string indices must be integers, not 'str'

# %%
all_quotes_df = dataset_df.explode(["quotes", "quote_lengths"])\
    .rename(columns={"quotes": "quote"})\
    .rename(columns={"quote_lengths": "quote_length"})
all_quotes_df = all_quotes_df[all_quotes_df["quote"].notna()]
all_quotes_df

# %%
grouped_by_year = all_quotes_df.groupby(by="originalDateYear")
years = grouped_by_year.groups
years_dfs = [grouped_by_year.get_group(year) for year in years]
years_dfs[0].head()

# %%
num_quotes_per_year = grouped_by_year["quote"].count()
num_quotes_per_year

# %%
quote_length_summary_df = pd.DataFrame(
    [df["quote_length"].convert_dtypes().describe() for df in years_dfs],
    index=pd.Index(data=years, name="year")
)
quote_length_summary_df

# %%
only_news_blog_social_media_df = all_quotes_df[(all_quotes_df["originalTextType"] == "News and blog") | (all_quotes_df["originalTextType"] == "Social media")]
only_news_blog_social_media_df

# %%
grouped_by_year_news_blog_social_media = only_news_blog_social_media_df.groupby(by="originalDateYear")
years_news_blog_social_media = grouped_by_year_news_blog_social_media.groups
years_news_blog_social_media_dfs = [grouped_by_year_news_blog_social_media.get_group(year) for year in years_news_blog_social_media]
years_news_blog_social_media_dfs[0].head()

# %%
num_quotes_per_year_news_blog_social_media = grouped_by_year_news_blog_social_media["quote"].count()
num_quotes_per_year_news_blog_social_media

# %%
quote_length_summary_news_blog_social_media_df = pd.DataFrame(
    [df["quote_length"].convert_dtypes().describe() for df in years_news_blog_social_media_dfs],
    index=pd.Index(data=years_news_blog_social_media, name="year")
)
quote_length_summary_news_blog_social_media_df

# %%
writer = pd.ExcelWriter(using_dataset.output_path, engine="xlsxwriter")

for df, year in zip(years_dfs, years):
    df\
        .sort_values(by="quote_length")\
        .to_excel(writer, sheet_name=str(year), index=False, columns=["quote", "quote_length", "originalDateYear"])

num_quotes_per_year.to_excel(writer, sheet_name="Number of quotes")
quote_length_summary_df.to_excel(writer, sheet_name="Quote length summary")

writer.close()

# %%
output_path = using_dataset.output_path
output_path_split = output_path.split("/")
output_path_split.insert(len(output_path_split) - 1, "news_blog_and_social_media")
output_path_news_blog_social_media = "/".join(output_path_split)
output_path_news_blog_social_media

# %%
writer = pd.ExcelWriter(output_path_news_blog_social_media, engine="xlsxwriter")

for df, year in zip(years_news_blog_social_media_dfs, years_news_blog_social_media):
    df\
        .sort_values(by="quote_length")\
        .to_excel(writer, sheet_name=str(year), index=False, columns=["quote", "quote_length", "originalDateYear"])

num_quotes_per_year_news_blog_social_media.to_excel(writer, sheet_name="Number of quotes")
quote_length_summary_news_blog_social_media_df.to_excel(writer, sheet_name="Quote length summary")

writer.close()
