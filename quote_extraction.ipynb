# %%
import pandas as pd
from quote_extractor import QuoteExtractor

# %%
class DatasetConfig():
    input_path: str
    output_path: str
    quote_annotations_path: str
    sheet_name: str
    id_col: str
    usecols: list[str]

    def __init__(self, input_path: str, output_path: str, quote_annotations_path: str, sheet_name: str, id_col: str, usecols: list[str]):
        self.input_path = input_path
        self.output_path = output_path
        self.quote_annotations_path = quote_annotations_path
        self.sheet_name = sheet_name
        self.id_col = id_col
        self.usecols = usecols

# %%
fakespeak_config = DatasetConfig(
    # file_path="/content/drive/My Drive/fake_news_over_time/Fakespeak_ENG_modified.xlsx",
    input_path="./data/Fakespeak-ENG/Fakespeak-ENG modified.xlsx",
    output_path="./data/Fakespeak-ENG/Analysis_output/Fakespeak_quotes.xlsx",
    quote_annotations_path="./data/Fakespeak-ENG/Analysis_output/quote_annotations.json",
    sheet_name="Working",
    id_col="ID",
    usecols=['ID', 'combinedLabel', 'originalTextType', 'originalBodyText', 'originalDateYear'],
)

misinfotext_config = DatasetConfig(
    input_path="./data/MisInfoText/PolitiFact_original_modified.xlsx",
    output_path="./data/MisInfoText/Analysis_output/MisInfoText_quotes.xlsx",
    quote_annotations_path="./data/MisInfoText/Analysis_output/quote_annotations.json",
    sheet_name="Working",
    id_col="factcheckURL",
    usecols=None,
)

# %%
using_dataset = misinfotext_config

# %%
dataset_df = pd.read_excel(
    using_dataset.input_path, 
    sheet_name=using_dataset.sheet_name, 
    usecols=using_dataset.usecols)
dataset_df
# Out:
#                                           factcheckURL  \
# 0    http://www.politifact.com/arizona/statements/2...
# 1    http://www.politifact.com/california/statement...
# 2    http://www.politifact.com/california/statement...
# 3    http://www.politifact.com/california/statement...
# 4    http://www.politifact.com/california/statement...
# ..                                                 ...
# 650  http://www.politifact.com/wisconsin/statements...
# 651  http://www.politifact.com/wisconsin/statements...
# 652  http://www.politifact.com/wisconsin/statements...
# 653  http://www.politifact.com/wisconsin/statements...
# 654  http://www.politifact.com/wisconsin/statements...
#
#                                            originalURL  \
# 0    https://associatedmediacoverage.com/three-stat...
# 1    https://users.focalbeam.com/fs/distribution:wl...
# 2    http://www.sacbee.com/opinion/op-ed/soapbox/ar...
# 3    https://nocagastax.com/california-gas-tax-hike...
# 4    https://chu.house.gov/media-center/press-relea...
# ..                                                 ...
# 650  https://x.com/ScottWalker/status/9428776407421...
# 651  https://x.com/ScottWalker/status/9511017961011...
# 652  https://x.com/MahlonMitchell/status/9538161542...
# 653  http://dailycaller.com/2018/01/25/hey-look-sen...
# 654                     https://mahlonmitchell.com/bio
#
#                                       originalBodyText  \
# 0    Residents of multiple states will be asked to ...
# 1    Sacramento, CA - United States Senator Dianne ...
# 2    We should anticipate black and gray markets in...
# 3    As a ballot initiative calling for repeal of a...
# 4    WASHINGTON, DC  The House of Representatives t...
# ..                                                 ...
# 650  Road projects across the state are staying on ...
# 651  The last thing we need is more Madison in our ...
# 652  When \n@ScottWalker\n told firefighters we did...
# 653  Now that its 2018, an election year, I would l...
# 654  Mahlon Mitchell currently serves as President ...
#
#                                       originalHeadline originalTextType  \
# 0    Multiple States Have Agreed To Implement A ‘Tw...    News and blog
# 1    U.S. Senator Dianne Feinstein Opposes Prop. 64...    Press release
# 2            Why you should buy a locking gasoline cap    News and blog
# 3     California Gas-Tax-Hike Repeal Campaign Heats Up    News and blog
# 4         Rep. Chu Decries "Heartless" ACA Repeal Vote    Press release
# ..                                                 ...              ...
# 650                                                NaN     Social media
# 651                                                NaN     Social media
# 652                                                NaN     Social media
# 653  HEY LOOK! Senator Tammy Baldwin Is Back In Wis...    News and blog
# 654                       Mahlon Mitchell for Governor    Press release
#
#     originalDate  originalDateYear
# 0     2016-05-06              2016
# 1     2016-07-12              2016
# 2     2017-08-04              2017
# 3     2017-06-15              2017
# 4     2017-05-04              2017
# ..           ...               ...
# 650   2017-12-18              2017
# 651   2018-01-10              2018
# 652   2018-01-18              2018
# 653   2018-01-25              2018
# 654   2018-04-30              2018
#
# [655 rows x 7 columns]

# %%
quote_extractor = QuoteExtractor("en_core_web_lg", "./quote_verb_list.txt")
# Out:
# c:\Users\Adam\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\coreferee\manager.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
from utils import preprocess_text

# %%
subset = dataset_df.head(30)
subset
# Out:
#                                          factcheckURL  \
# 0   http://www.politifact.com/arizona/statements/2...
# 1   http://www.politifact.com/california/statement...
# 2   http://www.politifact.com/california/statement...
# 3   http://www.politifact.com/california/statement...
# 4   http://www.politifact.com/california/statement...
# 5   http://www.politifact.com/california/statement...
# 6   http://www.politifact.com/california/statement...
# 7   http://www.politifact.com/california/statement...
# 8   http://www.politifact.com/california/statement...
# 9   http://www.politifact.com/california/statement...
# 10  http://www.politifact.com/florida/statements/2...
# 11  http://www.politifact.com/florida/statements/2...
# 12  http://www.politifact.com/florida/statements/2...
# 13  http://www.politifact.com/florida/statements/2...
# 14  http://www.politifact.com/florida/statements/2...
# 15  http://www.politifact.com/florida/statements/2...
# 16  http://www.politifact.com/florida/statements/2...
# 17  http://www.politifact.com/florida/statements/2...
# 18  http://www.politifact.com/florida/statements/2...
# 19  http://www.politifact.com/florida/statements/2...
# 20  http://www.politifact.com/florida/statements/2...
# 21  http://www.politifact.com/florida/statements/2...
# 22  http://www.politifact.com/florida/statements/2...
# 23  http://www.politifact.com/florida/statements/2...
# 24  http://www.politifact.com/florida/statements/2...
# 25  http://www.politifact.com/florida/statements/2...
# 26  http://www.politifact.com/florida/statements/2...
# 27  http://www.politifact.com/florida/statements/2...
# 28  http://www.politifact.com/florida/statements/2...
# 29  http://www.politifact.com/florida/statements/2...
#
#                                           originalURL  \
# 0   https://associatedmediacoverage.com/three-stat...
# 1   https://users.focalbeam.com/fs/distribution:wl...
# 2   http://www.sacbee.com/opinion/op-ed/soapbox/ar...
# 3   https://nocagastax.com/california-gas-tax-hike...
# 4   https://chu.house.gov/media-center/press-relea...
# 5   http://melendezforca.com/assemblywoman-melende...
# 6   http://www.sfchronicle.com/opinion/openforum/a...
# 7   http://www.sfchronicle.com/politics/article/Th...
# 8   http://m.sfgate.com/bayarea/article/California...
# 9   https://www.wnd.com/2018/01/major-state-to-reg...
# 10  http://www.theledger.com/article/20100403/COLU...
# 11  https://www.marcorubio.com/rubio-comments-on-c...
# 12  http://www.stevenschale.com/blog/2010/8/31/sor...
# 13  http://www.sunshinestatenews.com/blog/adam-has...
# 14  https://www.tampabay.com/opinion/columns/flori...
# 15  http://www.flgov.com/2011/11/14/gov-rick-scott...
# 16  https://conservativebyte.com/2011/08/socialist...
# 17  http://www.nytimes.com/2011/09/14/nyregion/ny-...
# 18  http://rooney.house.gov/index.php?option=com_c...
# 19  http://articles.orlandosentinel.com/2012-07-08...
# 20  https://docs.google.com/document/d/1OLlgB-MB_r...
# 21    https://x.com/JebBush/status/405836597368602624
# 22  https://redstate.com/rubiopress/2013/01/30/app...
# 23  https://redstate.com/rubiopress/2013/01/30/app...
# 24  http://www.breitbart.com/Big-Government/2013/0...
# 25  http://www.floridadems.org/newsroom/pressrelea...
# 26  https://www.flgov.com/2013/11/15/gov-scott-ano...
# 27  https://x.com/islandrichards/status/3865010788...
# 28  http://www.rubio.senate.gov/public/index.cfm/p...
# 29  http://myemail.constantcontact.com/FOR-IMMEDIA...
#
#                                      originalBodyText  \
# 0   Residents of multiple states will be asked to ...
# 1   Sacramento, CA - United States Senator Dianne ...
# 2   We should anticipate black and gray markets in...
# 3   As a ballot initiative calling for repeal of a...
# 4   WASHINGTON, DC  The House of Representatives t...
# 5   SACRAMENTO  Assemblywoman Melissa A. Melendez ...
# 6   Recently, a group of special interests threate...
# 7   COSTA MESA, Orange County  It was a surreal vi...
# 8   SACRAMENTO  California lawmakers are targeting...
# 9   WASHINGTON – California will take the next ste...
# 10  Had Senate Bill 6 simply rewarded exceptional ...
# 11  Miami, FL – U.S. Senate candidate Marco Rubio ...
# 12  Charlie Crist will not be Florida's next Unite...
# 13  Former state House Majority Leader Adam Hasner...
# 14  One of my most important responsibilities as s...
# 15  11/14/2011  President Obamas latest observatio...
# 16  This should come as a surprise to absolutely n...
# 17  In this district, there is a large number of p...
# 18  Washington, D.C. – U.S. Rep. Tom Rooney (FL-16...
# 19  When Mitt Romney visited Florida on my behalf ...
# 20  Miami, FL — Congresswoman Frederica Wilson (FL...
# 21  Why would our President close our Embassy to t...
# 22  I appreciate the opportunity to respond to Eri...
# 23  I appreciate the opportunity to respond to Eri...
# 24  Breitbart News has learned there is a provisio...
# 25  News FL Dems: Rick Scott State of the State No...
# 26  Florida has already welcomed more than 72 mill...
# 27  It is official. Obama has jumped the shark and...
# 28  Washington, D.C.  U.S. Senator Marco Rubio (R-...
# 29  The Hispanic vote will make a difference in th...
#
#                                      originalHeadline originalTextType  \
# 0   Multiple States Have Agreed To Implement A ‘Tw...    News and blog
# 1   U.S. Senator Dianne Feinstein Opposes Prop. 64...    Press release
# 2           Why you should buy a locking gasoline cap    News and blog
# 3    California Gas-Tax-Hike Repeal Campaign Heats Up    News and blog
# 4        Rep. Chu Decries "Heartless" ACA Repeal Vote    Press release
# 5   Assemblywoman Melendez Responds to Governor Br...    Press release
# 6   Repeal Californias gas tax increase, says GOP ...    News and blog
# 7   The pro-Russia, pro-weed, pro-Assange GOP cong...    News and blog
# 8   California Democrats want businesses to give h...    News and blog
# 9   California to register illegal aliens to vote ...    News and blog
# 10                SB 6 Education Bill Is a Power Grab    News and blog
# 11             Rubio Comments On Crist’s HB 1143 Veto    Press release
# 12                                      Sorry Charlie    News and blog
# 13  Adam Hasner Hammers Obama on Health Care, Call...    Press release
# 14         Florida's early voting remains at 96 hours    News and blog
# 15  Gov. Rick Scott reacts to President Obamas cla...    Press release
# 16  Socialist Party of America Releases The Names ...    News and blog
# 17         Bob Turner Wins Anthony Weiners House Seat    News and blog
# 18  Rooney Cosponsors Bill to Block DOL Attack on ...    Press release
# 19  Sen. Marco Rubio: Obamacare's taxes punish ind...    News and blog
# 20  CONGRESSWOMAN FREDERICA WILSON SUCCESSFULLY \n...    Press release
# 21                                                NaN     Social media
# 22    Applying Conservative Principles To Immigration    News and blog
# 23    Applying Conservative Principles To Immigration    News and blog
# 24  New Immigration Bill Has Taxpayer Subsidized O...    News and blog
# 25  FL Dems: Rick Scott State of the State Nothing...    Press release
# 26     Gov. Scott: Another Record for Florida Tourism    Press release
# 27                                                NaN     Social media
# 28  Rubio Hails House Passage Of Bill To Defund Ob...    Press release
# 29  FOR IMMEDIATE RELEASE\n\n \n\nRICK SCOTT WANTS...    Press release
#
#    originalDate  originalDateYear
# 0    2016-05-06              2016
# 1    2016-07-12              2016
# 2    2017-08-04              2017
# 3    2017-06-15              2017
# 4    2017-05-04              2017
# 5    2017-05-11              2017
# 6    2017-10-19              2017
# 7    2017-09-14              2017
# 8    2018-01-18              2018
# 9    2018-01-21              2018
# 10   2010-04-03              2010
# 11   2010-11-06              2010
# 12   2010-08-31              2010
# 13   2011-06-08              2011
# 14   2011-05-23              2011
# 15   2011-11-14              2011
# 16   2011-08-16              2011
# 17   2011-09-14              2011
# 18   2012-05-27              2012
# 19   2012-07-08              2012
# 20   2013-04-05              2013
# 21   2013-11-28              2013
# 22   2013-01-30              2013
# 23   2013-01-30              2013
# 24   2013-06-24              2013
# 25   2013-03-04              2013
# 26   2013-11-15              2013
# 27   2013-10-05              2013
# 28   2013-09-20              2013
# 29   2014-01-15              2014

# %%
print(preprocess_text(subset["originalBodyText"].iloc[20]))
# Out:
# Miami, FL — Congresswoman Frederica Wilson (FL-24) announced today that the Federal Aviation Administration has delayed the planned closure of the North Perry Airport contract control tower. Following the Congresswoman’s month-long campaign to save the tower, which included fact finding, speeches, official requests, and legislation, Congresswoman Wilson was notified, this morning, by FAA officials that the tower had been granted a temporary reprieve from closure.
#  .
#  Congresswoman Wilson will hold a news conference, Monday, April 8, 2013, at 11:30 a.m., at the North Perry Airport control tower to update the public. In the meantime, the Congresswoman will continue her advocacy for permanent funding for the facility, which Congresswoman Wilson has repeatedly described as essential for public safety, the regional economy, and national air traffic regulation. Congresswoman Wilson released the following statement:.
#  .
#  "Today’s announcement by the FAA is a step in the right direction. I will continue to make this airport my top priority, and I am confident that we will win long-term funding. This is part of a broader struggle to stop the "sequester", which destroys jobs and threatens our public safety, our children’s education, and our health.  In Congress, I am leading the charge to eliminate the "sequester," immediately, by sponsoring H.R. 900, the Cancel the Sequester Act.

# %%
processed = subset["originalBodyText"].apply(preprocess_text)
processed

# %%
quote_annotations = quote_extractor.run_multiple(subset[using_dataset.id_col], subset["originalBodyText"])

# %%
quote_annotations = quote_extractor.run_multiple(dataset_df[using_dataset.id_col], dataset_df["originalBodyText"])

# %%
dataset_df["quotes"] = [[doc["quote"] for doc in docs] 
                        for docs in quote_annotations]
dataset_df["quote_lengths"] = [[doc["quote_token_count"] for doc in docs] 
                        for docs in quote_annotations]
dataset_df

# %%
all_quotes_df = dataset_df.explode(["quotes", "quote_lengths"])\
    .rename(columns={"quotes": "quote"})\
    .rename(columns={"quote_lengths": "quote_length"})
all_quotes_df = all_quotes_df[all_quotes_df["quote"].notna()]
all_quotes_df

# %%
grouped_by_year = all_quotes_df.groupby(by="originalDateYear")
years = grouped_by_year.groups
years_dfs = [grouped_by_year.get_group(year) for year in years]
years_dfs[0].head()

# %%
num_quotes_per_year = grouped_by_year["quote"].count()
num_quotes_per_year

# %%
quote_length_summary_df = pd.DataFrame(
    [df["quote_length"].convert_dtypes().describe() for df in years_dfs],
    index=pd.Index(data=years, name="year")
)
quote_length_summary_df

# %%
only_news_blog_social_media_df = all_quotes_df[(all_quotes_df["originalTextType"] == "News and blog") | (all_quotes_df["originalTextType"] == "Social media")]
only_news_blog_social_media_df

# %%
grouped_by_year_news_blog_social_media = only_news_blog_social_media_df.groupby(by="originalDateYear")
years_news_blog_social_media = grouped_by_year_news_blog_social_media.groups
years_news_blog_social_media_dfs = [grouped_by_year_news_blog_social_media.get_group(year) for year in years_news_blog_social_media]
years_news_blog_social_media_dfs[0].head()

# %%
num_quotes_per_year_news_blog_social_media = grouped_by_year_news_blog_social_media["quote"].count()
num_quotes_per_year_news_blog_social_media

# %%
quote_length_summary_news_blog_social_media_df = pd.DataFrame(
    [df["quote_length"].convert_dtypes().describe() for df in years_news_blog_social_media_dfs],
    index=pd.Index(data=years_news_blog_social_media, name="year")
)
quote_length_summary_news_blog_social_media_df

# %%
writer = pd.ExcelWriter(using_dataset.output_path, engine="xlsxwriter")

for df, year in zip(years_dfs, years):
    df\
        .sort_values(by="quote_length")\
        .to_excel(writer, sheet_name=str(year), index=False, columns=["quote", "quote_length", "originalDateYear"])

num_quotes_per_year.to_excel(writer, sheet_name="Number of quotes")
quote_length_summary_df.to_excel(writer, sheet_name="Quote length summary")

writer.close()

# %%
output_path = using_dataset.output_path
output_path_split = output_path.split("/")
output_path_split.insert(len(output_path_split) - 1, "news_blog_and_social_media")
output_path_news_blog_social_media = "/".join(output_path_split)
output_path_news_blog_social_media

# %%
writer = pd.ExcelWriter(output_path_news_blog_social_media, engine="xlsxwriter")

for df, year in zip(years_news_blog_social_media_dfs, years_news_blog_social_media):
    df\
        .sort_values(by="quote_length")\
        .to_excel(writer, sheet_name=str(year), index=False, columns=["quote", "quote_length", "originalDateYear"])

num_quotes_per_year_news_blog_social_media.to_excel(writer, sheet_name="Number of quotes")
quote_length_summary_news_blog_social_media_df.to_excel(writer, sheet_name="Quote length summary")

writer.close()
