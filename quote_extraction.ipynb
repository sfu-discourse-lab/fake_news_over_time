# %%
import pandas as pd
from quote_extractor import QuoteExtractor

# %%
class DatasetConfig():
    input_path: str
    output_path: str
    quote_annotations_path: str
    sheet_name: str
    id_col: str
    usecols: list[str]

    def __init__(self, input_path: str, output_path: str, quote_annotations_path: str, sheet_name: str, id_col: str, usecols: list[str]):
        self.input_path = input_path
        self.output_path = output_path
        self.quote_annotations_path = quote_annotations_path
        self.sheet_name = sheet_name
        self.id_col = id_col
        self.usecols = usecols

# %%
fakespeak_config = DatasetConfig(
    # file_path="/content/drive/My Drive/fake_news_over_time/Fakespeak_ENG_modified.xlsx",
    input_path="./data/Fakespeak-ENG/Fakespeak-ENG modified.xlsx",
    output_path="./data/Fakespeak-ENG/Analysis_output/Fakespeak_quotes.xlsx",
    quote_annotations_path="./data/Fakespeak-ENG/Analysis_output/quote_annotations.json",
    sheet_name="Working",
    id_col="ID",
    usecols=['ID', 'combinedLabel', 'originalTextType', 'originalBodyText', 'originalDateYear'],
)

misinfotext_config = DatasetConfig(
    input_path="./data/MisInfoText/PolitiFact_original_modified.xlsx",
    output_path="./data/MisInfoText/Analysis_output/MisInfoText_quotes.xlsx",
    quote_annotations_path="./data/MisInfoText/Analysis_output/quote_annotations.json",
    sheet_name="Working",
    id_col="factcheckURL",
    usecols=None,
)

# %%
using_dataset = misinfotext_config

# %%
dataset_df = pd.read_excel(
    using_dataset.input_path, 
    sheet_name=using_dataset.sheet_name, 
    usecols=using_dataset.usecols)
dataset_df
# Out:
#                                           factcheckURL  \
# 0    http://www.politifact.com/arizona/statements/2...
# 1    http://www.politifact.com/california/statement...
# 2    http://www.politifact.com/california/statement...
# 3    http://www.politifact.com/california/statement...
# 4    http://www.politifact.com/california/statement...
# ..                                                 ...
# 650  http://www.politifact.com/wisconsin/statements...
# 651  http://www.politifact.com/wisconsin/statements...
# 652  http://www.politifact.com/wisconsin/statements...
# 653  http://www.politifact.com/wisconsin/statements...
# 654  http://www.politifact.com/wisconsin/statements...
#
#                                            originalURL  \
# 0    https://associatedmediacoverage.com/three-stat...
# 1    https://users.focalbeam.com/fs/distribution:wl...
# 2    http://www.sacbee.com/opinion/op-ed/soapbox/ar...
# 3    https://nocagastax.com/california-gas-tax-hike...
# 4    https://chu.house.gov/media-center/press-relea...
# ..                                                 ...
# 650  https://x.com/ScottWalker/status/9428776407421...
# 651  https://x.com/ScottWalker/status/9511017961011...
# 652  https://x.com/MahlonMitchell/status/9538161542...
# 653  http://dailycaller.com/2018/01/25/hey-look-sen...
# 654                     https://mahlonmitchell.com/bio
#
#                                       originalBodyText  \
# 0    Residents of multiple states will be asked to ...
# 1    Sacramento, CA - United States Senator Dianne ...
# 2    We should anticipate black and gray markets in...
# 3    As a ballot initiative calling for repeal of a...
# 4    WASHINGTON, DC  The House of Representatives t...
# ..                                                 ...
# 650  Road projects across the state are staying on ...
# 651  The last thing we need is more Madison in our ...
# 652  When \n@ScottWalker\n told firefighters we did...
# 653  Now that its 2018, an election year, I would l...
# 654  Mahlon Mitchell currently serves as President ...
#
#                                       originalHeadline originalTextType  \
# 0    Multiple States Have Agreed To Implement A ‘Tw...    News and blog
# 1    U.S. Senator Dianne Feinstein Opposes Prop. 64...    Press release
# 2            Why you should buy a locking gasoline cap    News and blog
# 3     California Gas-Tax-Hike Repeal Campaign Heats Up    News and blog
# 4         Rep. Chu Decries "Heartless" ACA Repeal Vote    Press release
# ..                                                 ...              ...
# 650                                                NaN     Social media
# 651                                                NaN     Social media
# 652                                                NaN     Social media
# 653  HEY LOOK! Senator Tammy Baldwin Is Back In Wis...    News and blog
# 654                       Mahlon Mitchell for Governor    Press release
#
#     originalDate  originalDateYear
# 0     2016-05-06              2016
# 1     2016-07-12              2016
# 2     2017-08-04              2017
# 3     2017-06-15              2017
# 4     2017-05-04              2017
# ..           ...               ...
# 650   2017-12-18              2017
# 651   2018-01-10              2018
# 652   2018-01-18              2018
# 653   2018-01-25              2018
# 654   2018-04-30              2018
#
# [655 rows x 7 columns]

# %%
quote_extractor = QuoteExtractor("en_core_web_lg", "./quote_verb_list.txt")
# Out:
# c:\Users\Adam\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\coreferee\manager.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
quote_annotations = quote_extractor.run_multiple(dataset_df[using_dataset.id_col], dataset_df["originalBodyText"])
# Out:
# Preprocessing texts...
# Creating spacy docs...
# Extracting quotes...
# Done extracting quotes

# %%
dataset_df["quotes"] = [[doc["quote"] for doc in docs] 
                        for docs in quote_annotations]
dataset_df["quote_lengths"] = [[doc["quote_token_count"] for doc in docs] 
                        for docs in quote_annotations]
dataset_df
# Out:
#                                           factcheckURL  \
# 0    http://www.politifact.com/arizona/statements/2...
# 1    http://www.politifact.com/california/statement...
# 2    http://www.politifact.com/california/statement...
# 3    http://www.politifact.com/california/statement...
# 4    http://www.politifact.com/california/statement...
# ..                                                 ...
# 650  http://www.politifact.com/wisconsin/statements...
# 651  http://www.politifact.com/wisconsin/statements...
# 652  http://www.politifact.com/wisconsin/statements...
# 653  http://www.politifact.com/wisconsin/statements...
# 654  http://www.politifact.com/wisconsin/statements...
#
#                                            originalURL  \
# 0    https://associatedmediacoverage.com/three-stat...
# 1    https://users.focalbeam.com/fs/distribution:wl...
# 2    http://www.sacbee.com/opinion/op-ed/soapbox/ar...
# 3    https://nocagastax.com/california-gas-tax-hike...
# 4    https://chu.house.gov/media-center/press-relea...
# ..                                                 ...
# 650  https://x.com/ScottWalker/status/9428776407421...
# 651  https://x.com/ScottWalker/status/9511017961011...
# 652  https://x.com/MahlonMitchell/status/9538161542...
# 653  http://dailycaller.com/2018/01/25/hey-look-sen...
# 654                     https://mahlonmitchell.com/bio
#
#                                       originalBodyText  \
# 0    Residents of multiple states will be asked to ...
# 1    Sacramento, CA - United States Senator Dianne ...
# 2    We should anticipate black and gray markets in...
# 3    As a ballot initiative calling for repeal of a...
# 4    WASHINGTON, DC  The House of Representatives t...
# ..                                                 ...
# 650  Road projects across the state are staying on ...
# 651  The last thing we need is more Madison in our ...
# 652  When \n@ScottWalker\n told firefighters we did...
# 653  Now that its 2018, an election year, I would l...
# 654  Mahlon Mitchell currently serves as President ...
#
#                                       originalHeadline originalTextType  \
# 0    Multiple States Have Agreed To Implement A ‘Tw...    News and blog
# 1    U.S. Senator Dianne Feinstein Opposes Prop. 64...    Press release
# 2            Why you should buy a locking gasoline cap    News and blog
# 3     California Gas-Tax-Hike Repeal Campaign Heats Up    News and blog
# 4         Rep. Chu Decries "Heartless" ACA Repeal Vote    Press release
# ..                                                 ...              ...
# 650                                                NaN     Social media
# 651                                                NaN     Social media
# 652                                                NaN     Social media
# 653  HEY LOOK! Senator Tammy Baldwin Is Back In Wis...    News and blog
# 654                       Mahlon Mitchell for Governor    Press release
#
#     originalDate  originalDateYear  \
# 0     2016-05-06              2016
# 1     2016-07-12              2016
# 2     2017-08-04              2017
# 3     2017-06-15              2017
# 4     2017-05-04              2017
# ..           ...               ...
# 650   2017-12-18              2017
# 651   2018-01-10              2018
# 652   2018-01-18              2018
# 653   2018-01-25              2018
# 654   2018-04-30              2018
#
#                                                 quotes  \
# 0    [, abandoned pet rates have sky-rocketed in Te...
# 1    [that deaths in marijuana-related car crashes ...
# 2    [Organized crime gangs are buying hundreds or ...
# 3    [hes going to raise their gas taxes to the hig...
# 4                                                   []
# ..                                                 ...
# 650                                                 []
# 651                                                 []
# 652                                                 []
# 653                                                 []
# 654  [families and spouses of fire fighters who die...
#
#                     quote_lengths
# 0            [24, 24, 19, 50, 11]
# 1                        [15, 63]
# 2      [22, 4, 32, 8, 24, 18, 23]
# 3    [23, 16, 15, 16, 30, 19, 47]
# 4                              []
# ..                            ...
# 650                            []
# 651                            []
# 652                            []
# 653                            []
# 654                          [20]
#
# [655 rows x 9 columns]

# %%
all_quotes_df = dataset_df.explode(["quotes", "quote_lengths"])\
    .rename(columns={"quotes": "quote"})\
    .rename(columns={"quote_lengths": "quote_length"})
all_quotes_df = all_quotes_df[all_quotes_df["quote"].notna()]
all_quotes_df
# Out:
#                                           factcheckURL  \
# 0    http://www.politifact.com/arizona/statements/2...
# 0    http://www.politifact.com/arizona/statements/2...
# 0    http://www.politifact.com/arizona/statements/2...
# 0    http://www.politifact.com/arizona/statements/2...
# 0    http://www.politifact.com/arizona/statements/2...
# ..                                                 ...
# 642  http://www.politifact.com/wisconsin/statements...
# 645  http://www.politifact.com/wisconsin/statements...
# 645  http://www.politifact.com/wisconsin/statements...
# 646  http://www.politifact.com/wisconsin/statements...
# 654  http://www.politifact.com/wisconsin/statements...
#
#                                            originalURL  \
# 0    https://associatedmediacoverage.com/three-stat...
# 0    https://associatedmediacoverage.com/three-stat...
# 0    https://associatedmediacoverage.com/three-stat...
# 0    https://associatedmediacoverage.com/three-stat...
# 0    https://associatedmediacoverage.com/three-stat...
# ..                                                 ...
# 642  https://x.com/SheriffClarke/status/83266463840...
# 645  http://www.citizenactionwi.org/johnson_cease_d...
# 645  http://www.citizenactionwi.org/johnson_cease_d...
# 646  http://resistancereport.com/politics/senator-c...
# 654                     https://mahlonmitchell.com/bio
#
#                                       originalBodyText  \
# 0    Residents of multiple states will be asked to ...
# 0    Residents of multiple states will be asked to ...
# 0    Residents of multiple states will be asked to ...
# 0    Residents of multiple states will be asked to ...
# 0    Residents of multiple states will be asked to ...
# ..                                                 ...
# 642  Michelle Obama said she was never proud of her...
# 645  Dissent is patriotic, that's what we believe. ...
# 645  Dissent is patriotic, that's what we believe. ...
# 646  Senator Ron Johnson (R-Wisconsin) apparently d...
# 654  Mahlon Mitchell currently serves as President ...
#
#                                       originalHeadline originalTextType  \
# 0    Multiple States Have Agreed To Implement A ‘Tw...    News and blog
# 0    Multiple States Have Agreed To Implement A ‘Tw...    News and blog
# 0    Multiple States Have Agreed To Implement A ‘Tw...    News and blog
# 0    Multiple States Have Agreed To Implement A ‘Tw...    News and blog
# 0    Multiple States Have Agreed To Implement A ‘Tw...    News and blog
# ..                                                 ...              ...
# 642                                                NaN     Social media
# 645                        Citizen Action of Wisconsin    News and blog
# 645                        Citizen Action of Wisconsin    News and blog
# 646  Republican Senator Threatens Citizens with Arr...    News and blog
# 654                       Mahlon Mitchell for Governor    Press release
#
#     originalDate  originalDateYear  \
# 0     2016-05-06              2016
# 0     2016-05-06              2016
# 0     2016-05-06              2016
# 0     2016-05-06              2016
# 0     2016-05-06              2016
# ..           ...               ...
# 642   2017-02-17              2017
# 645   2017-02-28              2017
# 645   2017-02-28              2017
# 646   2017-03-02              2017
# 654   2018-04-30              2018
#
#                                                  quote quote_length
# 0    , abandoned pet rates have sky-rocketed in Tex...           24
# 0    , pet owners within Texas, Arizona, and Missou...           24
# 0    a state funded, mandatory ‘pet registration’ p...           19
# 0    , an incentive program may be implemented to e...           50
# 0        "domestic animal the size of a cat or larger"           11
# ..                                                 ...          ...
# 642  she was never proud of her country til they el...           13
# 645  this was an "extraordinary unusual" letter and...           21
# 645                    "We will NOT Cease and Desist!"            9
# 646  the citizens who pay his salary should get to ...           12
# 654  families and spouses of fire fighters who die ...           20
#
# [2312 rows x 9 columns]

# %%
grouped_by_year = all_quotes_df.groupby(by="originalDateYear")
years = grouped_by_year.groups
years_dfs = [grouped_by_year.get_group(year) for year in years]
years_dfs[0].head()
# Out:
#                                           factcheckURL  \
# 428  http://www.politifact.com/truth-o-meter/statem...
# 428  http://www.politifact.com/truth-o-meter/statem...
# 428  http://www.politifact.com/truth-o-meter/statem...
#
#                                            originalURL  \
# 428  https://www.johnmccain.com/Informing/News/Pres...
# 428  https://www.johnmccain.com/Informing/News/Pres...
# 428  https://www.johnmccain.com/Informing/News/Pres...
#
#                                       originalBodyText  \
# 428  "On Monday, Senator Clinton told an audience a...
# 428  "On Monday, Senator Clinton told an audience a...
# 428  "On Monday, Senator Clinton told an audience a...
#
#                                 originalHeadline originalTextType  \
# 428  Statement By John McCain on Hillary Clinton    Press release
# 428  Statement By John McCain on Hillary Clinton    Press release
# 428  Statement By John McCain on Hillary Clinton    Press release
#
#     originalDate  originalDateYear  \
# 428   2007-08-23              2007
# 428   2007-08-23              2007
# 428   2007-08-23              2007
#
#                                                  quote quote_length
# 428      that the surge of troops in Iraq was 'working           10
# 428  the surge 'has failed' and that we should 'beg...           18
# 428  "The fact that the New York senator can revers...           81

# %%
num_quotes_per_year = grouped_by_year["quote"].count()
num_quotes_per_year
# Out:
# originalDateYear
# 2007      3
# 2008     49
# 2009    105
# 2010     97
# 2011    174
# 2012    160
# 2013    203
# 2014    133
# 2015     17
# 2016    296
# 2017    649
# 2018    426
# Name: quote, dtype: int64

# %%
quote_length_summary_df = pd.DataFrame(
    [df["quote_length"].convert_dtypes().describe() for df in years_dfs],
    index=pd.Index(data=years, name="year")
)
quote_length_summary_df
# Out:
#       count       mean        std   min   25%   50%    75%    max
# year
# 2007    3.0  36.333333  38.888730  10.0  14.0  18.0  49.50   81.0
# 2008   49.0  22.183673  21.419105   5.0   9.0  12.0  27.00   95.0
# 2009  105.0  21.476190  13.661495   6.0  11.0  18.0  26.00   74.0
# 2010   97.0  23.134021  15.727251   4.0  13.0  19.0  29.00   92.0
# 2011  174.0  22.660920  14.625774   4.0  13.0  20.0  28.75  105.0
# 2012  160.0  20.706250  14.072408   4.0  10.0  18.0  27.25   71.0
# 2013  203.0  19.955665  13.542489   4.0  11.0  17.0  25.00   90.0
# 2014  133.0  20.180451  14.105573   4.0  10.0  18.0  23.00   89.0
# 2015   17.0  20.000000  30.667572   4.0   8.0  12.0  20.00  136.0
# 2016  296.0  22.185811  15.839532   4.0  11.0  18.0  27.00   93.0
# 2017  649.0  21.425270  14.992108   4.0  11.0  17.0  27.00  122.0
# 2018  426.0  20.795775  12.870324   4.0  11.0  18.0  28.00   95.0

# %%
only_news_blog_social_media_df = all_quotes_df[(all_quotes_df["originalTextType"] == "News and blog") | (all_quotes_df["originalTextType"] == "Social media")]
only_news_blog_social_media_df
# Out:
#                                           factcheckURL  \
# 0    http://www.politifact.com/arizona/statements/2...
# 0    http://www.politifact.com/arizona/statements/2...
# 0    http://www.politifact.com/arizona/statements/2...
# 0    http://www.politifact.com/arizona/statements/2...
# 0    http://www.politifact.com/arizona/statements/2...
# ..                                                 ...
# 631  http://www.politifact.com/wisconsin/statements...
# 642  http://www.politifact.com/wisconsin/statements...
# 645  http://www.politifact.com/wisconsin/statements...
# 645  http://www.politifact.com/wisconsin/statements...
# 646  http://www.politifact.com/wisconsin/statements...
#
#                                            originalURL  \
# 0    https://associatedmediacoverage.com/three-stat...
# 0    https://associatedmediacoverage.com/three-stat...
# 0    https://associatedmediacoverage.com/three-stat...
# 0    https://associatedmediacoverage.com/three-stat...
# 0    https://associatedmediacoverage.com/three-stat...
# ..                                                 ...
# 631  http://freepatriot.org/2014/07/04/obama-admini...
# 642  https://x.com/SheriffClarke/status/83266463840...
# 645  http://www.citizenactionwi.org/johnson_cease_d...
# 645  http://www.citizenactionwi.org/johnson_cease_d...
# 646  http://resistancereport.com/politics/senator-c...
#
#                                       originalBodyText  \
# 0    Residents of multiple states will be asked to ...
# 0    Residents of multiple states will be asked to ...
# 0    Residents of multiple states will be asked to ...
# 0    Residents of multiple states will be asked to ...
# 0    Residents of multiple states will be asked to ...
# ..                                                 ...
# 631  This past week the Obama administration filed ...
# 642  Michelle Obama said she was never proud of her...
# 645  Dissent is patriotic, that's what we believe. ...
# 645  Dissent is patriotic, that's what we believe. ...
# 646  Senator Ron Johnson (R-Wisconsin) apparently d...
#
#                                       originalHeadline originalTextType  \
# 0    Multiple States Have Agreed To Implement A ‘Tw...    News and blog
# 0    Multiple States Have Agreed To Implement A ‘Tw...    News and blog
# 0    Multiple States Have Agreed To Implement A ‘Tw...    News and blog
# 0    Multiple States Have Agreed To Implement A ‘Tw...    News and blog
# 0    Multiple States Have Agreed To Implement A ‘Tw...    News and blog
# ..                                                 ...              ...
# 631  Obama Administration Suing Wisconsin Company f...    News and blog
# 642                                                NaN     Social media
# 645                        Citizen Action of Wisconsin    News and blog
# 645                        Citizen Action of Wisconsin    News and blog
# 646  Republican Senator Threatens Citizens with Arr...    News and blog
#
#     originalDate  originalDateYear  \
# 0     2016-05-06              2016
# 0     2016-05-06              2016
# 0     2016-05-06              2016
# 0     2016-05-06              2016
# 0     2016-05-06              2016
# ..           ...               ...
# 631   2014-07-04              2014
# 642   2017-02-17              2017
# 645   2017-02-28              2017
# 645   2017-02-28              2017
# 646   2017-03-02              2017
#
#                                                  quote quote_length
# 0    , abandoned pet rates have sky-rocketed in Tex...           24
# 0    , pet owners within Texas, Arizona, and Missou...           24
# 0    a state funded, mandatory ‘pet registration’ p...           19
# 0    , an incentive program may be implemented to e...           50
# 0        "domestic animal the size of a cat or larger"           11
# ..                                                 ...          ...
# 631  "When speaking English fluently is not, in fac...           33
# 642  she was never proud of her country til they el...           13
# 645  this was an "extraordinary unusual" letter and...           21
# 645                    "We will NOT Cease and Desist!"            9
# 646  the citizens who pay his salary should get to ...           12
#
# [1909 rows x 9 columns]

# %%
grouped_by_year_news_blog_social_media = only_news_blog_social_media_df.groupby(by="originalDateYear")
years_news_blog_social_media = grouped_by_year_news_blog_social_media.groups
years_news_blog_social_media_dfs = [grouped_by_year_news_blog_social_media.get_group(year) for year in years_news_blog_social_media]
years_news_blog_social_media_dfs[0].head()
# Out:
#                                           factcheckURL  \
# 429  http://www.politifact.com/truth-o-meter/statem...
# 430  http://www.politifact.com/truth-o-meter/statem...
# 430  http://www.politifact.com/truth-o-meter/statem...
# 432  http://www.politifact.com/truth-o-meter/statem...
# 432  http://www.politifact.com/truth-o-meter/statem...
#
#                                            originalURL  \
# 429  http://www.nypost.com/seven/03212008/postopini...
# 430  https://www.citizenlink.org/focusaction/update...
# 430  https://www.citizenlink.org/focusaction/update...
# 432  http://www.nysun.com/opinion/palin-on-ahmadine...
# 432  http://www.nysun.com/opinion/palin-on-ahmadine...
#
#                                       originalBodyText  \
# 429  NOW that Hillary Clintons schedule as first la...
# 430  What does it take to be the most liberal membe...
# 430  What does it take to be the most liberal membe...
# 432  Governor Palin, the Republican nominee for vic...
# 432  Governor Palin, the Republican nominee for vic...
#
#                                originalHeadline originalTextType originalDate  \
# 429                   HEAVY HITTER? NOT HILLARY    News and blog   2008-03-21
# 430                    March 2008 Action Update    News and blog   2008-03-26
# 430                    March 2008 Action Update    News and blog   2008-03-26
# 432  Palin on Ahmadinejad: 'He Must Be Stopped'    News and blog   2008-09-22
# 432  Palin on Ahmadinejad: 'He Must Be Stopped'    News and blog   2008-09-22
#
#      originalDateYear                                              quote  \
# 429              2008                          to be was nowhere evident
# 430              2008              he is "opposed" to same-sex "marriage
# 430              2008                     this link was accessed in 2007
# 432              2008  that Iran is running at least 3,800 centrifuge...
# 432              2008  , U.S. intelligence agencies believe the Irani...
#
#     quote_length
# 429            5
# 430           11
# 430            6
# 432           17
# 432           20

# %%
num_quotes_per_year_news_blog_social_media = grouped_by_year_news_blog_social_media["quote"].count()
num_quotes_per_year_news_blog_social_media
# Out:
# originalDateYear
# 2008     11
# 2009     78
# 2010     82
# 2011    107
# 2012     98
# 2013    161
# 2014     81
# 2015     17
# 2016    255
# 2017    610
# 2018    409
# Name: quote, dtype: int64

# %%
quote_length_summary_news_blog_social_media_df = pd.DataFrame(
    [df["quote_length"].convert_dtypes().describe() for df in years_news_blog_social_media_dfs],
    index=pd.Index(data=years_news_blog_social_media, name="year")
)
quote_length_summary_news_blog_social_media_df
# Out:
#       count       mean        std  min   25%   50%    75%    max
# year
# 2008   11.0  12.454545   6.218740  5.0   7.5  11.0  18.50   22.0
# 2009   78.0  20.512821  13.587373  6.0  10.0  17.0  25.75   74.0
# 2010   82.0  20.841463  11.527176  4.0  12.0  17.5  27.75   54.0
# 2011  107.0  19.411215  11.827337  4.0  12.0  17.0  25.00   91.0
# 2012   98.0  19.265306  12.845274  4.0  10.0  17.0  23.75   71.0
# 2013  161.0  18.149068  11.883398  4.0  10.0  16.0  22.00   90.0
# 2014   81.0  19.333333  12.522979  4.0  10.0  18.0  23.00   89.0
# 2015   17.0  20.000000  30.667572  4.0   8.0  12.0  20.00  136.0
# 2016  255.0  21.082353  15.368604  4.0  11.0  17.0  26.00   93.0
# 2017  610.0  20.852459  14.422474  4.0  11.0  17.0  26.00  122.0
# 2018  409.0  21.004890  13.038216  4.0  11.0  18.0  28.00   95.0

# %%
writer = pd.ExcelWriter(using_dataset.output_path, engine="xlsxwriter")

for df, year in zip(years_dfs, years):
    df\
        .sort_values(by="quote_length")\
        .to_excel(writer, sheet_name=str(year), index=False, columns=["quote", "quote_length", "originalDateYear"])

num_quotes_per_year.to_excel(writer, sheet_name="Number of quotes")
quote_length_summary_df.to_excel(writer, sheet_name="Quote length summary")

writer.close()

# %%
output_path = using_dataset.output_path
output_path_split = output_path.split("/")
output_path_split.insert(len(output_path_split) - 1, "news_blog_and_social_media")
output_path_news_blog_social_media = "/".join(output_path_split)
output_path_news_blog_social_media
# Out:
# './data/MisInfoText/Analysis_output/news_blog_and_social_media/MisInfoText_quotes.xlsx'

# %%
writer = pd.ExcelWriter(output_path_news_blog_social_media, engine="xlsxwriter")

for df, year in zip(years_news_blog_social_media_dfs, years_news_blog_social_media):
    df\
        .sort_values(by="quote_length")\
        .to_excel(writer, sheet_name=str(year), index=False, columns=["quote", "quote_length", "originalDateYear"])

num_quotes_per_year_news_blog_social_media.to_excel(writer, sheet_name="Number of quotes")
quote_length_summary_news_blog_social_media_df.to_excel(writer, sheet_name="Quote length summary")

writer.close()
