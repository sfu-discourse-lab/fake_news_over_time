# %%
import pandas as pd
from quote_extractor import QuoteExtractor
from dataset_config import BASE_FAKESPEAK_CONFIG, BASE_MISINFOTEXT_CONFIG

# %%
fakespeak_config = BASE_FAKESPEAK_CONFIG | {
    "output_path": "./data/Fakespeak-ENG/Analysis_output/Fakespeak_quotes.xlsx"
}

misinfotext_config = BASE_MISINFOTEXT_CONFIG | {
    "output_path": "./data/MisInfoText/Analysis_output/MisInfoText_quotes.xlsx"
}

# %%
using_dataset = fakespeak_config

# %%
dataset_df = pd.read_excel(
    using_dataset["input_path"], 
    sheet_name=using_dataset["sheet_name"], 
    usecols=using_dataset["usecols"])
dataset_df
# Out:
#                                                 ID  combinedLabel  \
# 0             Politifact_FALSE_Social media_687276          False
# 1              Politifact_FALSE_Social media_25111          False
# 2             Politifact_FALSE_Social media_735424          False
# 3             Politifact_FALSE_Social media_594307          False
# 4             Politifact_FALSE_Social media_839325          False
# ...                                            ...            ...
# 2956  Politifact_Pants on Fire_Social media_876628  Pants on Fire
# 2957  Politifact_Pants on Fire_Social media_231170  Pants on Fire
# 2958  Politifact_Pants on Fire_Social media_874359  Pants on Fire
# 2959  Politifact_Pants on Fire_Social media_635418  Pants on Fire
# 2960  Politifact_Pants on Fire_Social media_621529  Pants on Fire
#
#      originalTextType                                   originalBodyText  \
# 0        Social media  Mexico is paying for the Wall through the new ...
# 1        Social media  Chuck Schumer: "why should American citizens b...
# 2        Social media  Billions of dollars are sent to the State of C...
# 3        Social media  If 50 Billion $$ were set aside to go towards ...
# 4        Social media  Huge@#CD 9 news. \n@ncsbe\n sent letter to eve...
# ...               ...                                                ...
# 2956     Social media  A great lesson in Optics 101: The Monroe Doctr...
# 2957     Social media  “One of these Joe’s is not like the other… one...
# 2958     Social media  Autopsies Prove that COVID-19 is a Disseminate...
# 2959     Social media  She collapsed when she saw jfk jr. as she was ...
# 2960     Social media  ANYBODY ELSE FIND IT FUNNY THAT ISRAEL WAS ATT...
#
#       originalDateYear
# 0                 2019
# 1                 2019
# 2                 2019
# 3                 2019
# 4                 2019
# ...                ...
# 2956              2023
# 2957              2023
# 2958              2020
# 2959              2021
# 2960              2023
#
# [2961 rows x 5 columns]

# %%
quote_extractor = QuoteExtractor("en_core_web_lg", "./config/quote_verb_list.txt")
# Out:
# c:\Users\Adam\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\coreferee\manager.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
quote_annotations = quote_extractor.run_multiple(
    dataset_df[using_dataset["id_col"]], 
    dataset_df[using_dataset["text_col"]]
)
# Out:
# Preprocessing texts...
# Creating spacy docs...
# Extracting quotes...
# Done extracting quotes

# %%
dataset_df["quotes"] = [[doc["quote"] for doc in docs] 
                        for docs in quote_annotations]
dataset_df["quote_lengths"] = [[doc["quote_token_count"] for doc in docs] 
                        for docs in quote_annotations]
dataset_df
# Out:
#                                                 ID  combinedLabel  \
# 0             Politifact_FALSE_Social media_687276          False
# 1              Politifact_FALSE_Social media_25111          False
# 2             Politifact_FALSE_Social media_735424          False
# 3             Politifact_FALSE_Social media_594307          False
# 4             Politifact_FALSE_Social media_839325          False
# ...                                            ...            ...
# 2956  Politifact_Pants on Fire_Social media_876628  Pants on Fire
# 2957  Politifact_Pants on Fire_Social media_231170  Pants on Fire
# 2958  Politifact_Pants on Fire_Social media_874359  Pants on Fire
# 2959  Politifact_Pants on Fire_Social media_635418  Pants on Fire
# 2960  Politifact_Pants on Fire_Social media_621529  Pants on Fire
#
#      originalTextType                                   originalBodyText  \
# 0        Social media  Mexico is paying for the Wall through the new ...
# 1        Social media  Chuck Schumer: "why should American citizens b...
# 2        Social media  Billions of dollars are sent to the State of C...
# 3        Social media  If 50 Billion $$ were set aside to go towards ...
# 4        Social media  Huge@#CD 9 news. \n@ncsbe\n sent letter to eve...
# ...               ...                                                ...
# 2956     Social media  A great lesson in Optics 101: The Monroe Doctr...
# 2957     Social media  “One of these Joe’s is not like the other… one...
# 2958     Social media  Autopsies Prove that COVID-19 is a Disseminate...
# 2959     Social media  She collapsed when she saw jfk jr. as she was ...
# 2960     Social media  ANYBODY ELSE FIND IT FUNNY THAT ISRAEL WAS ATT...
#
#       originalDateYear                                             quotes  \
# 0                 2019                                                 []
# 1                 2019  ["why should American citizens be responsible ...
# 2                 2019                                                 []
# 3                 2019                                                 []
# 4                 2019                                                 []
# ...                ...                                                ...
# 2956              2023  [that the United States would not tolerate fur...
# 2957              2023  ["One of these Joe’s is not like the other… on...
# 2958              2020  [were never needed.\n , they were cured with, ...
# 2959              2021                                                 []
# 2960              2023                                                 []
#
#                            quote_lengths
# 0                                     []
# 1                                   [18]
# 2                                     []
# 3                                     []
# 4                                     []
# ...                                  ...
# 2956                            [12, 13]
# 2957                                [21]
# 2958  [5, 4, 18, 12, 13, 15, 51, 42, 14]
# 2959                                  []
# 2960                                  []
#
# [2961 rows x 7 columns]

# %%
all_quotes_df = dataset_df.explode(["quotes", "quote_lengths"])\
    .rename(columns={"quotes": "quote"})\
    .rename(columns={"quote_lengths": "quote_length"})
all_quotes_df = all_quotes_df[all_quotes_df["quote"].notna()]
all_quotes_df
# Out:
#                                                 ID  combinedLabel  \
# 1              Politifact_FALSE_Social media_25111          False
# 13            Politifact_FALSE_Social media_169258          False
# 14             Politifact_FALSE_Social media_19711          False
# 18             Politifact_FALSE_Social media_60177          False
# 19           Politifact_FALSE_News and blog_605527          False
# ...                                            ...            ...
# 2958  Politifact_Pants on Fire_Social media_874359  Pants on Fire
# 2958  Politifact_Pants on Fire_Social media_874359  Pants on Fire
# 2958  Politifact_Pants on Fire_Social media_874359  Pants on Fire
# 2958  Politifact_Pants on Fire_Social media_874359  Pants on Fire
# 2958  Politifact_Pants on Fire_Social media_874359  Pants on Fire
#
#      originalTextType                                   originalBodyText  \
# 1        Social media  Chuck Schumer: "why should American citizens b...
# 13       Social media  According to the 2016 Annual Survey of School ...
# 14       Social media  .@realDonaldTrump on people asking for asylum ...
# 18       Social media  Thank you North Carolina. You showed up in mas...
# 19      News and blog  Hollywood legend Tom Selleck has praised Donal...
# ...               ...                                                ...
# 2958     Social media  Autopsies Prove that COVID-19 is a Disseminate...
# 2958     Social media  Autopsies Prove that COVID-19 is a Disseminate...
# 2958     Social media  Autopsies Prove that COVID-19 is a Disseminate...
# 2958     Social media  Autopsies Prove that COVID-19 is a Disseminate...
# 2958     Social media  Autopsies Prove that COVID-19 is a Disseminate...
#
#       originalDateYear                                              quote  \
# 1                 2019  "why should American citizens be responsible t...
# 13                2019  , U.S. Census Bureau, West Virginia spends mor...
# 14                2019          "These aren't people. These are animals."
# 18                2019  that the state fund our public school legislat...
# 19                2019     I’m completely sure that he is the best so far
# ...                ...                                                ...
# 2958              2020  , treatment in ICUs is useless if thromboembol...
# 2958              2020  , inflammation induces thrombosis through a co...
# 2958              2020  "Thanks to 50 autopsies performed on patients ...
# 2958              2020  "If we ventilate a lung where blood does not c...
# 2958              2020  "It is venous microthrombosis, not pneumonia, ...
#
#      quote_length
# 1              18
# 13             26
# 14             11
# 18              9
# 19             11
# ...           ...
# 2958           13
# 2958           15
# 2958           51
# 2958           42
# 2958           14
#
# [4445 rows x 7 columns]

# %%
grouped_by_year = all_quotes_df.groupby(by="originalDateYear")
years = grouped_by_year.groups
years_dfs = [grouped_by_year.get_group(year) for year in years]
years_dfs[0].head()
# Out:
#                                        ID combinedLabel originalTextType  \
# 1     Politifact_FALSE_Social media_25111         False     Social media
# 13   Politifact_FALSE_Social media_169258         False     Social media
# 14    Politifact_FALSE_Social media_19711         False     Social media
# 18    Politifact_FALSE_Social media_60177         False     Social media
# 19  Politifact_FALSE_News and blog_605527         False    News and blog
#
#                                      originalBodyText  originalDateYear  \
# 1   Chuck Schumer: "why should American citizens b...              2019
# 13  According to the 2016 Annual Survey of School ...              2019
# 14  .@realDonaldTrump on people asking for asylum ...              2019
# 18  Thank you North Carolina. You showed up in mas...              2019
# 19  Hollywood legend Tom Selleck has praised Donal...              2019
#
#                                                 quote quote_length
# 1   "why should American citizens be responsible t...           18
# 13  , U.S. Census Bureau, West Virginia spends mor...           26
# 14          "These aren't people. These are animals."           11
# 18  that the state fund our public school legislat...            9
# 19     I’m completely sure that he is the best so far           11

# %%
num_quotes_per_year = grouped_by_year["quote"].count()
num_quotes_per_year
# Out:
# originalDateYear
# 2019     192
# 2020     970
# 2021    1200
# 2022     648
# 2023    1196
# 2024     239
# Name: quote, dtype: int64

# %%
quote_length_summary_df = pd.DataFrame(
    [df["quote_length"].convert_dtypes().describe() for df in years_dfs],
    index=pd.Index(data=years, name="year")
)
quote_length_summary_df
# Out:
#        count       mean        std  min    25%   50%   75%    max
# year
# 2019   192.0  20.567708  16.172357  4.0  10.00  16.0  25.0   98.0
# 2020   970.0  21.423711  16.149548  4.0  10.00  17.0  27.0  104.0
# 2021  1200.0  21.812500  15.994391  4.0  10.75  17.0  28.0  110.0
# 2022   648.0  21.762346  16.050702  4.0  11.00  18.0  27.0  137.0
# 2023  1196.0  21.866221  14.671938  4.0  12.00  18.0  28.0  120.0
# 2024   239.0  24.238494  17.143169  4.0  12.00  20.0  31.0   96.0

# %%
only_news_blog_social_media_df = all_quotes_df[(all_quotes_df["originalTextType"] == "News and blog") | (all_quotes_df["originalTextType"] == "Social media")]
only_news_blog_social_media_df
# Out:
#                                                 ID  combinedLabel  \
# 1              Politifact_FALSE_Social media_25111          False
# 13            Politifact_FALSE_Social media_169258          False
# 14             Politifact_FALSE_Social media_19711          False
# 18             Politifact_FALSE_Social media_60177          False
# 19           Politifact_FALSE_News and blog_605527          False
# ...                                            ...            ...
# 2958  Politifact_Pants on Fire_Social media_874359  Pants on Fire
# 2958  Politifact_Pants on Fire_Social media_874359  Pants on Fire
# 2958  Politifact_Pants on Fire_Social media_874359  Pants on Fire
# 2958  Politifact_Pants on Fire_Social media_874359  Pants on Fire
# 2958  Politifact_Pants on Fire_Social media_874359  Pants on Fire
#
#      originalTextType                                   originalBodyText  \
# 1        Social media  Chuck Schumer: "why should American citizens b...
# 13       Social media  According to the 2016 Annual Survey of School ...
# 14       Social media  .@realDonaldTrump on people asking for asylum ...
# 18       Social media  Thank you North Carolina. You showed up in mas...
# 19      News and blog  Hollywood legend Tom Selleck has praised Donal...
# ...               ...                                                ...
# 2958     Social media  Autopsies Prove that COVID-19 is a Disseminate...
# 2958     Social media  Autopsies Prove that COVID-19 is a Disseminate...
# 2958     Social media  Autopsies Prove that COVID-19 is a Disseminate...
# 2958     Social media  Autopsies Prove that COVID-19 is a Disseminate...
# 2958     Social media  Autopsies Prove that COVID-19 is a Disseminate...
#
#       originalDateYear                                              quote  \
# 1                 2019  "why should American citizens be responsible t...
# 13                2019  , U.S. Census Bureau, West Virginia spends mor...
# 14                2019          "These aren't people. These are animals."
# 18                2019  that the state fund our public school legislat...
# 19                2019     I’m completely sure that he is the best so far
# ...                ...                                                ...
# 2958              2020  , treatment in ICUs is useless if thromboembol...
# 2958              2020  , inflammation induces thrombosis through a co...
# 2958              2020  "Thanks to 50 autopsies performed on patients ...
# 2958              2020  "If we ventilate a lung where blood does not c...
# 2958              2020  "It is venous microthrombosis, not pneumonia, ...
#
#      quote_length
# 1              18
# 13             26
# 14             11
# 18              9
# 19             11
# ...           ...
# 2958           13
# 2958           15
# 2958           51
# 2958           42
# 2958           14
#
# [4329 rows x 7 columns]

# %%
grouped_by_year_news_blog_social_media = only_news_blog_social_media_df.groupby(by="originalDateYear")
years_news_blog_social_media = grouped_by_year_news_blog_social_media.groups
years_news_blog_social_media_dfs = [grouped_by_year_news_blog_social_media.get_group(year) for year in years_news_blog_social_media]
years_news_blog_social_media_dfs[0].head()
# Out:
#                                        ID combinedLabel originalTextType  \
# 1     Politifact_FALSE_Social media_25111         False     Social media
# 13   Politifact_FALSE_Social media_169258         False     Social media
# 14    Politifact_FALSE_Social media_19711         False     Social media
# 18    Politifact_FALSE_Social media_60177         False     Social media
# 19  Politifact_FALSE_News and blog_605527         False    News and blog
#
#                                      originalBodyText  originalDateYear  \
# 1   Chuck Schumer: "why should American citizens b...              2019
# 13  According to the 2016 Annual Survey of School ...              2019
# 14  .@realDonaldTrump on people asking for asylum ...              2019
# 18  Thank you North Carolina. You showed up in mas...              2019
# 19  Hollywood legend Tom Selleck has praised Donal...              2019
#
#                                                 quote quote_length
# 1   "why should American citizens be responsible t...           18
# 13  , U.S. Census Bureau, West Virginia spends mor...           26
# 14          "These aren't people. These are animals."           11
# 18  that the state fund our public school legislat...            9
# 19     I’m completely sure that he is the best so far           11

# %%
num_quotes_per_year_news_blog_social_media = grouped_by_year_news_blog_social_media["quote"].count()
num_quotes_per_year_news_blog_social_media
# Out:
# originalDateYear
# 2019     163
# 2020     934
# 2021    1186
# 2022     619
# 2023    1192
# 2024     235
# Name: quote, dtype: int64

# %%
quote_length_summary_news_blog_social_media_df = pd.DataFrame(
    [df["quote_length"].convert_dtypes().describe() for df in years_news_blog_social_media_dfs],
    index=pd.Index(data=years_news_blog_social_media, name="year")
)
quote_length_summary_news_blog_social_media_df
# Out:
#        count       mean        std  min   25%   50%   75%    max
# year
# 2019   163.0  20.061350  15.880220  4.0  10.0  15.0  24.0   98.0
# 2020   934.0  21.129550  16.110195  4.0  10.0  17.0  26.0  104.0
# 2021  1186.0  21.620573  15.612265  4.0  10.0  17.0  28.0  110.0
# 2022   619.0  20.915994  14.668264  4.0  10.0  17.0  26.0  137.0
# 2023  1192.0  21.833893  14.632903  4.0  12.0  18.0  28.0  120.0
# 2024   235.0  24.089362  17.010193  4.0  12.0  20.0  30.5   96.0

# %%
writer = pd.ExcelWriter(using_dataset.output_path, engine="xlsxwriter")

for df, year in zip(years_dfs, years):
    df\
        .sort_values(by="quote_length")\
        .to_excel(writer, sheet_name=str(year), index=False, columns=["quote", "quote_length", "originalDateYear"])

num_quotes_per_year.to_excel(writer, sheet_name="Number of quotes")
quote_length_summary_df.to_excel(writer, sheet_name="Quote length summary")

writer.close()

# %%
output_path = using_dataset.output_path
output_path_split = output_path.split("/")
output_path_split.insert(len(output_path_split) - 1, "news_blog_and_social_media")
output_path_news_blog_social_media = "/".join(output_path_split)
output_path_news_blog_social_media
# Out:
# './data/Fakespeak-ENG/Analysis_output/news_blog_and_social_media/Fakespeak_quotes.xlsx'

# %%
writer = pd.ExcelWriter(output_path_news_blog_social_media, engine="xlsxwriter")

for df, year in zip(years_news_blog_social_media_dfs, years_news_blog_social_media):
    df\
        .sort_values(by="quote_length")\
        .to_excel(writer, sheet_name=str(year), index=False, columns=["quote", "quote_length", "originalDateYear"])

num_quotes_per_year_news_blog_social_media.to_excel(writer, sheet_name="Number of quotes")
quote_length_summary_news_blog_social_media_df.to_excel(writer, sheet_name="Quote length summary")

writer.close()
