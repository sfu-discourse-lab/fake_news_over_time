# %%
import pandas as pd
import spacy
from spacy.tokens.doc import Doc
from dataset_config import BASE_FAKESPEAK_CONFIG, BASE_MISINFOTEXT_CONFIG
from helpers import get_groups, make_output_path, make_output_path_for_type, is_word

# %%
fakespeak_config = BASE_FAKESPEAK_CONFIG
misinfotext_config = BASE_MISINFOTEXT_CONFIG

# %%
using_dataset = misinfotext_config

# %%
dataset_df = pd.read_excel(
    using_dataset["input_path"],
    sheet_name=using_dataset["sheet_name"],
    usecols=using_dataset["usecols"]
)
dataset_df.head()
# Out:
#                                         factcheckURL  \
# 0  http://www.politifact.com/arizona/statements/2...
# 1  http://www.politifact.com/california/statement...
# 2  http://www.politifact.com/california/statement...
# 3  http://www.politifact.com/california/statement...
# 4  http://www.politifact.com/california/statement...
#
#                                          originalURL  \
# 0  https://associatedmediacoverage.com/three-stat...
# 1  https://users.focalbeam.com/fs/distribution:wl...
# 2  http://www.sacbee.com/opinion/op-ed/soapbox/ar...
# 3  https://nocagastax.com/california-gas-tax-hike...
# 4  https://chu.house.gov/media-center/press-relea...
#
#                                     originalBodyText  \
# 0  Residents of multiple states will be asked to ...
# 1  Sacramento, CA - United States Senator Dianne ...
# 2  We should anticipate black and gray markets in...
# 3  As a ballot initiative calling for repeal of a...
# 4  WASHINGTON, DC  The House of Representatives t...
#
#                                     originalHeadline originalTextType  \
# 0  Multiple States Have Agreed To Implement A ‘Tw...    News and blog
# 1  U.S. Senator Dianne Feinstein Opposes Prop. 64...    Press release
# 2          Why you should buy a locking gasoline cap    News and blog
# 3   California Gas-Tax-Hike Repeal Campaign Heats Up    News and blog
# 4       Rep. Chu Decries "Heartless" ACA Repeal Vote    Press release
#
#   originalDate  originalDateYear
# 0   2016-05-06              2016
# 1   2016-07-12              2016
# 2   2017-08-04              2017
# 3   2017-06-15              2017
# 4   2017-05-04              2017

# %%
nlp = spacy.load("en_core_web_md")
# Out:
# c:\Users\Adam\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\spacy\util.py:969: UserWarning: [W095] Model 'en_core_web_md' (3.5.0) was trained with spaCy v3.5.0 and may not be 100% compatible with the current version (3.8.8). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# c:\Users\Adam\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\coreferee\manager.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
dataset_df["doc"] = list(nlp.pipe(dataset_df[using_dataset["text_col"]]))
dataset_df.head()
# Out:
#                                         factcheckURL  \
# 0  http://www.politifact.com/arizona/statements/2...
# 1  http://www.politifact.com/california/statement...
# 2  http://www.politifact.com/california/statement...
# 3  http://www.politifact.com/california/statement...
# 4  http://www.politifact.com/california/statement...
#
#                                          originalURL  \
# 0  https://associatedmediacoverage.com/three-stat...
# 1  https://users.focalbeam.com/fs/distribution:wl...
# 2  http://www.sacbee.com/opinion/op-ed/soapbox/ar...
# 3  https://nocagastax.com/california-gas-tax-hike...
# 4  https://chu.house.gov/media-center/press-relea...
#
#                                     originalBodyText  \
# 0  Residents of multiple states will be asked to ...
# 1  Sacramento, CA - United States Senator Dianne ...
# 2  We should anticipate black and gray markets in...
# 3  As a ballot initiative calling for repeal of a...
# 4  WASHINGTON, DC  The House of Representatives t...
#
#                                     originalHeadline originalTextType  \
# 0  Multiple States Have Agreed To Implement A ‘Tw...    News and blog
# 1  U.S. Senator Dianne Feinstein Opposes Prop. 64...    Press release
# 2          Why you should buy a locking gasoline cap    News and blog
# 3   California Gas-Tax-Hike Repeal Campaign Heats Up    News and blog
# 4       Rep. Chu Decries "Heartless" ACA Repeal Vote    Press release
#
#   originalDate  originalDateYear  \
# 0   2016-05-06              2016
# 1   2016-07-12              2016
# 2   2017-08-04              2017
# 3   2017-06-15              2017
# 4   2017-05-04              2017
#
#                                                  doc
# 0  (Residents, of, multiple, states, will, be, as...
# 1  (Sacramento, ,, CA, -, United, States, Senator...
# 2  (We, should, anticipate, black, and, gray, mar...
# 3  (As, a, ballot, initiative, calling, for, repe...
# 4  (WASHINGTON, ,, DC,  , The, House, of, Represe...

# %%
def get_proportion_upper_to_alpha_tokens(doc: Doc):
    try:
        word_tokens = [token for token in doc if is_word(token)]

        num_upper_tokens = sum(
            1 for token in word_tokens 
            if token.is_upper
        )
        
        num_alpha_tokens = sum(1 for token in word_tokens if token.is_alpha)

        # Sometimes spacy counts non-alpha tokens as uppercase (e.g. WW3).
        # If the proportion exceeds 1, then it's reasonable that
        # the whole text is uppercase.
        if num_upper_tokens > num_alpha_tokens:
            return 1

        return num_upper_tokens / num_alpha_tokens
    except:
        # Some articles don't have any words at all (e.g. just a link),
        # which ends up dividing by zero and throwing an exception.
        # So just return 0 in that case.
        return 0

# %%
dataset_df["proportion_upper_to_alpha_tokens"] = dataset_df["doc"].apply(get_proportion_upper_to_alpha_tokens)
dataset_df = dataset_df.sort_values("proportion_upper_to_alpha_tokens", ascending=False)

dataset_df.head()
# Out:
#                                           factcheckURL  \
# 506  http://www.politifact.com/truth-o-meter/statem...
# 183  http://www.politifact.com/punditfact/statement...
# 502  http://www.politifact.com/truth-o-meter/statem...
# 514  http://www.politifact.com/truth-o-meter/statem...
# 634  http://www.politifact.com/wisconsin/statements...
#
#                                            originalURL  \
# 506           https://www.instagram.com/p/BCYF4O6mhex/
# 183  https://x.com/cbrandonellis/status/89526051024...
# 502  https://www.facebook.com/LiberalsAreCool/posts...
# 514  https://www.facebook.com/OccupyDemocrats/photo...
# 634  http://www.wisn.com/politics/chris-larson-on-c...
#
#                                       originalBodyText  \
# 506  "FIRST THEY IGNORE YOU, THEN THEY LAUGH AT YOU...
# 183  BILL CLINTON GAVE NORTH KOREA $5 BILLION AND T...
# 502  TUITION-FREE PUBLIC UNIVERSITIES AND COLLEGES ...
# 514  HAS TAKEN LESS VACATION DAYS THAN ANY OTHER PR...
# 634  Chris Larson on Chris Abele: 'He finally showe...
#
#                                       originalHeadline originalTextType  \
# 506                                                NaN     Social media
# 183                                                NaN     Social media
# 502                                                NaN     Social media
# 514                                                NaN     Social media
# 634  Chris Larson on Chris Abele: 'He finally showe...    Press release
#
#     originalDate  originalDateYear  \
# 506   2016-02-29              2016
# 183   2017-08-09              2017
# 502   2016-06-02              2016
# 514   2016-08-20              2016
# 634   2016-04-06              2016
#
#                                                    doc  \
# 506  (", FIRST, THEY, IGNORE, YOU, ,, THEN, THEY, L...
# 183  (BILL, CLINTON, GAVE, NORTH, KOREA, $, 5, BILL...
# 502  (TUITION, -, FREE, PUBLIC, UNIVERSITIES, AND, ...
# 514  (HAS, TAKEN, LESS, VACATION, DAYS, THAN, ANY, ...
# 634  (Chris, Larson, on, Chris, Abele, :, ', He, fi...
#
#      proportion_upper_to_alpha_tokens
# 506                          1.000000
# 183                          1.000000
# 502                          1.000000
# 514                          1.000000
# 634                          0.810526

# %%
years, years_dfs = get_groups(dataset_df, using_dataset["year_col"])
years_dfs[0].head()
# Out:
#                                           factcheckURL  \
# 428  http://www.politifact.com/truth-o-meter/statem...
#
#                                            originalURL  \
# 428  https://www.johnmccain.com/Informing/News/Pres...
#
#                                       originalBodyText  \
# 428  "On Monday, Senator Clinton told an audience a...
#
#                                 originalHeadline originalTextType  \
# 428  Statement By John McCain on Hillary Clinton    Press release
#
#     originalDate  originalDateYear  \
# 428   2007-08-23              2007
#
#                                                    doc  \
# 428  (", On, Monday, ,, Senator, Clinton, told, an,...
#
#      proportion_upper_to_alpha_tokens
# 428                             0.008

# %%
types, types_dfs = get_groups(dataset_df, using_dataset["type_col"])
types_dfs[0].head()
# Out:
#                                           factcheckURL  \
# 220  http://www.politifact.com/punditfact/statement...
# 394  http://www.politifact.com/texas/statements/201...
# 325  http://www.politifact.com/punditfact/statement...
# 167  http://www.politifact.com/punditfact/statement...
# 211  http://www.politifact.com/punditfact/statement...
#
#                                            originalURL  \
# 220  http://usanewstoday.org/index.php/2017/01/02/c...
# 394  https://truethevote.org/news/attny-gen-eric-ho...
# 325  https://internationalflashnews.blogspot.com/20...
# 167  http://dailysnark.com/harambe-dead-gorilla-got...
# 211  https://donaldtrumppotus45.com/2017/01/26/brea...
#
#                                       originalBodyText  \
# 220  If this is true it will mean an opening for an...
# 394  Holder is against Texas Plans for Redistrictin...
# 325  AMID AN INTERVIEW ON CNN’S “AC360,” FORMER PRE...
# 167  You may asked what the Unites States did to na...
# 211  For years, the debate has raged over whether o...
#
#                                       originalHeadline originalTextType  \
# 220  CONFIRMED ! JUSTICE RUTH BADER GINSBURG IS RES...    News and blog
# 394  Attny Gen. Eric Holder is Coming to Austin - W...    News and blog
# 325  MITT ROMNEY: ‘TRUMP HAS SOME VERY SERIOUS EMOT...    News and blog
# 167  Harambe, A Dead Gorilla, Got Over 15,000 Votes...    News and blog
# 211  BREAKING! President Trump Makes ENGLISH The OF...    News and blog
#
#     originalDate  originalDateYear  \
# 220   2017-01-02              2017
# 394   2011-12-12              2011
# 325   2018-06-06              2018
# 167   2016-11-08              2016
# 211   2017-01-29              2017
#
#                                                    doc  \
# 220  (If, this, is, true, it, will, mean, an, openi...
# 394  (Holder, is, against, Texas, Plans, for, Redis...
# 325  (AMID, AN, INTERVIEW, ON, CNN, ’S, “, AC360, ,...
# 167  (You, may, asked, what, the, Unites, States, d...
# 211  (For, years, ,, the, debate, has, raged, over,...
#
#      proportion_upper_to_alpha_tokens
# 220                          0.612963
# 394                          0.483516
# 325                          0.172414
# 167                          0.120773
# 211                          0.096154

# %%
def get_summary_df(dfs: list[pd.DataFrame], years: list[int]):
    return pd.DataFrame(
        [df["proportion_upper_to_alpha_tokens"].describe() for df in dfs],
        index=pd.Index(data=years, name="year")
    )

# %% [markdown]
# ## Writing dataframes to excel spreadsheet

# %%
save_cols = [
    using_dataset["id_col"], 
    using_dataset["text_col"], 
    using_dataset["type_col"], 
    "proportion_upper_to_alpha_tokens"
]

def save_years(writer: pd.ExcelWriter, years: list[int], dfs: list[pd.DataFrame]):
    for year, df in zip(years, dfs):
        df.to_excel(
            writer,
            sheet_name=str(year),
            index=False,
            columns=save_cols
        )

    get_summary_df(dfs, years).to_excel(writer, sheet_name="Proportion Summary")

# %%
output_path = make_output_path(using_dataset, "all_caps")

writer = pd.ExcelWriter(output_path, engine="xlsxwriter")
save_years(writer, years, years_dfs)
writer.close()

# %%
for type, df in zip(types, types_dfs):
    years, years_dfs = get_groups(df, using_dataset["year_col"])

    output_path = make_output_path_for_type(using_dataset, type, "all_caps")

    writer = pd.ExcelWriter(output_path, engine="xlsxwriter")
    save_years(writer, years, years_dfs)
    writer.close()
