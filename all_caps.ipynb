# %%
import pandas as pd

# %%
class DatasetConfig():
    input_path: str
    output_path: str
    sheet_name: str
    usecols: list[str]
    cols_to_save: list[str]

    def __init__(self, input_path: str, output_path: str, sheet_name: str, usecols: list[str], cols_to_save: list[str]):
        self.input_path = input_path
        self.output_path = output_path
        self.sheet_name = sheet_name
        self.usecols = usecols
        self.cols_to_save = cols_to_save

# %%
fakespeak_config = DatasetConfig(
    input_path="./data/Fakespeak-ENG/Fakespeak-ENG modified.xlsx",
    output_path="./data/Fakespeak-ENG/Analysis_output/Fakespeak_lexical_density.xlsx",
    sheet_name="Working",
    usecols=['ID', 'combinedLabel', 'originalTextType', 'originalBodyText', 'originalDateYear'],
    cols_to_save=["ID", "combinedLabel", "originalTextType", "originalBodyText", "lexical_density"]
)

misinfotext_config = DatasetConfig(
    input_path="./data/MisInfoText/PolitiFact_original_modified.xlsx",
    output_path="./data/MisInfoText/Analysis_output/MisInfoText_lexical_density.xlsx",
    sheet_name="Working",
    usecols=None,
    cols_to_save=["factcheckURL", "originalURL", "originalTextType", "originalBodyText", "lexical_density"]
)

# %%
using_dataset = fakespeak_config

# %%
dataset_df = pd.read_excel(
    using_dataset.input_path,
    sheet_name=using_dataset.sheet_name,
    usecols=using_dataset.usecols
)
dataset_df
# Out:
#                                                 ID  combinedLabel  \
# 0             Politifact_FALSE_Social media_687276          False
# 1              Politifact_FALSE_Social media_25111          False
# 2             Politifact_FALSE_Social media_735424          False
# 3             Politifact_FALSE_Social media_594307          False
# 4             Politifact_FALSE_Social media_839325          False
# ...                                            ...            ...
# 2956  Politifact_Pants on Fire_Social media_876628  Pants on Fire
# 2957  Politifact_Pants on Fire_Social media_231170  Pants on Fire
# 2958  Politifact_Pants on Fire_Social media_874359  Pants on Fire
# 2959  Politifact_Pants on Fire_Social media_635418  Pants on Fire
# 2960  Politifact_Pants on Fire_Social media_621529  Pants on Fire
#
#      originalTextType                                   originalBodyText  \
# 0        Social media  Mexico is paying for the Wall through the new ...
# 1        Social media  Chuck Schumer: "why should American citizens b...
# 2        Social media  Billions of dollars are sent to the State of C...
# 3        Social media  If 50 Billion $$ were set aside to go towards ...
# 4        Social media  Huge@#CD 9 news. \n@ncsbe\n sent letter to eve...
# ...               ...                                                ...
# 2956     Social media  A great lesson in Optics 101: The Monroe Doctr...
# 2957     Social media  “One of these Joe’s is not like the other… one...
# 2958     Social media  Autopsies Prove that COVID-19 is a Disseminate...
# 2959     Social media  She collapsed when she saw jfk jr. as she was ...
# 2960     Social media  ANYBODY ELSE FIND IT FUNNY THAT ISRAEL WAS ATT...
#
#       originalDateYear
# 0                 2019
# 1                 2019
# 2                 2019
# 3                 2019
# 4                 2019
# ...                ...
# 2956              2023
# 2957              2023
# 2958              2020
# 2959              2021
# 2960              2023
#
# [2961 rows x 5 columns]

# %%
def get_words(text: str):
    return [token for token in text.split() if token.isalpha()]

def count_uppercase_words(words: list[str]):
    return sum(1 for word in words if word.isupper())

def get_text_length(text: str):
    return len(text.split())

# %%
dataset_df["words"] = dataset_df["originalBodyText"].apply(get_words)
dataset_df["num_words"] = dataset_df["words"].apply(lambda words: len(words))
dataset_df["num_uppercase_words"] = dataset_df["words"].apply(count_uppercase_words)
dataset_df["proportion_uppercase_words"] = dataset_df["num_uppercase_words"] / dataset_df["num_words"]
dataset_df["text_length"] = dataset_df["originalBodyText"].apply(get_text_length)

dataset_df
# Out:
#                                                 ID  combinedLabel  \
# 0             Politifact_FALSE_Social media_687276          False
# 1              Politifact_FALSE_Social media_25111          False
# 2             Politifact_FALSE_Social media_735424          False
# 3             Politifact_FALSE_Social media_594307          False
# 4             Politifact_FALSE_Social media_839325          False
# ...                                            ...            ...
# 2956  Politifact_Pants on Fire_Social media_876628  Pants on Fire
# 2957  Politifact_Pants on Fire_Social media_231170  Pants on Fire
# 2958  Politifact_Pants on Fire_Social media_874359  Pants on Fire
# 2959  Politifact_Pants on Fire_Social media_635418  Pants on Fire
# 2960  Politifact_Pants on Fire_Social media_621529  Pants on Fire
#
#      originalTextType                                   originalBodyText  \
# 0        Social media  Mexico is paying for the Wall through the new ...
# 1        Social media  Chuck Schumer: "why should American citizens b...
# 2        Social media  Billions of dollars are sent to the State of C...
# 3        Social media  If 50 Billion $$ were set aside to go towards ...
# 4        Social media  Huge@#CD 9 news. \n@ncsbe\n sent letter to eve...
# ...               ...                                                ...
# 2956     Social media  A great lesson in Optics 101: The Monroe Doctr...
# 2957     Social media  “One of these Joe’s is not like the other… one...
# 2958     Social media  Autopsies Prove that COVID-19 is a Disseminate...
# 2959     Social media  She collapsed when she saw jfk jr. as she was ...
# 2960     Social media  ANYBODY ELSE FIND IT FUNNY THAT ISRAEL WAS ATT...
#
#       originalDateYear                                              words  \
# 0                 2019  [Mexico, is, paying, for, the, Wall, through, ...
# 1                 2019  [Chuck, should, American, citizens, be, respon...
# 2                 2019  [Billions, of, dollars, are, sent, to, the, St...
# 3                 2019  [If, Billion, were, set, aside, to, go, toward...
# 4                 2019  [sent, letter, to, every, person, requesting, ...
# ...                ...                                                ...
# 2956              2023  [A, great, lesson, in, Optics, The, Monroe, Do...
# 2957              2023  [of, these, is, not, like, the, one, of, these...
# 2958              2020  [Autopsies, Prove, that, is, a, Disseminated, ...
# 2959              2021  [She, collapsed, when, she, saw, jfk, as, she,...
# 2960              2023  [ANYBODY, ELSE, FIND, IT, FUNNY, THAT, ISRAEL,...
#
#       num_words  num_uppercase_words  proportion_uppercase_words  text_length
# 0            44                    1                    0.022727           50
# 1            36                    2                    0.055556           42
# 2            40                    2                    0.050000           48
# 3            32                    0                    0.000000           46
# 4            32                    0                    0.000000           41
# ...         ...                  ...                         ...          ...
# 2956        625                   30                    0.048000          780
# 2957         11                    0                    0.000000           17
# 2958        552                    4                    0.007246          664
# 2959         66                    5                    0.075758           77
# 2960         50                   50                    1.000000           53
#
# [2961 rows x 10 columns]

# %%
all_caps_df = dataset_df[dataset_df["proportion_uppercase_words"] == 1.0]
all_caps_df
# Out:
#                                                 ID  combinedLabel  \
# 41            Politifact_FALSE_Social media_831395          False
# 50             Politifact_FALSE_Social media_15704          False
# 55            Politifact_FALSE_Social media_427373          False
# 62            Politifact_FALSE_Social media_427060          False
# 134           Politifact_FALSE_Social media_510570          False
# ...                                            ...            ...
# 2933  Politifact_Pants on Fire_Social media_312815  Pants on Fire
# 2936  Politifact_Pants on Fire_Social media_938988  Pants on Fire
# 2941  Politifact_Pants on Fire_Social media_152853  Pants on Fire
# 2944  Politifact_Pants on Fire_Social media_508882  Pants on Fire
# 2960  Politifact_Pants on Fire_Social media_621529  Pants on Fire
#
#      originalTextType                                   originalBodyText  \
# 41       Social media  WHO CHANGED THE LONG STANDING WHISTLEBLOWER RU...
# 50       Social media  PRESIDENT TRUMP DONATED HIS SECOND QUARTER SAL...
# 55       Social media  LET ME GET THIS STRAIGHT BIDEN BLACKMAILED UKR...
# 62       Social media  THE MISSILES THAT WERE LAUNCHED AT AMERICAN FO...
# 134      Social media  REMEMBER WHEN ANONYMOUS SAID THEY WOULD EXPOSE...
# ...               ...                                                ...
# 2933     Social media  WELL NEVER HAVE TO WORRY\nABOUT CHINA ATTACKIN...
# 2936     Social media  FEMA CAMPS ARE OPEN FOR THE UPCOMING ARRESTS F...
# 2941     Social media  TO ANGER A CONSERVATIVE,\nLIE TO HIM. TO ANGER...
# 2944     Social media  THIS IS NEW HAMPSHIRE CONGRESSMAN\nARNIM ZOLA,...
# 2960     Social media  ANYBODY ELSE FIND IT FUNNY THAT ISRAEL WAS ATT...
#
#       originalDateYear                                              words  \
# 41                2019  [WHO, CHANGED, THE, LONG, STANDING, WHISTLEBLO...
# 50                2019  [PRESIDENT, TRUMP, DONATED, HIS, SECOND, QUART...
# 55                2019  [LET, ME, GET, THIS, STRAIGHT, BIDEN, BLACKMAI...
# 62                2020  [THE, MISSILES, THAT, WERE, LAUNCHED, AT, AMER...
# 134               2020  [REMEMBER, WHEN, ANONYMOUS, SAID, THEY, WOULD,...
# ...                ...                                                ...
# 2933              2019  [WELL, NEVER, HAVE, TO, WORRY, ABOUT, CHINA, A...
# 2936              2023  [FEMA, CAMPS, ARE, OPEN, FOR, THE, UPCOMING, A...
# 2941              2019  [TO, ANGER, A, LIE, TO, TO, ANGER, A, TELL, HI...
# 2944              2019  [THIS, IS, NEW, HAMPSHIRE, CONGRESSMAN, ARNIM,...
# 2960              2023  [ANYBODY, ELSE, FIND, IT, FUNNY, THAT, ISRAEL,...
#
#       num_words  num_uppercase_words  proportion_uppercase_words  text_length
# 41           16                   16                         1.0           18
# 50           24                   24                         1.0           27
# 55           34                   34                         1.0           35
# 62           21                   21                         1.0           25
# 134          29                   29                         1.0           34
# ...         ...                  ...                         ...          ...
# 2933         20                   20                         1.0           25
# 2936         11                   11                         1.0           12
# 2941         12                   12                         1.0           17
# 2944         20                   20                         1.0           23
# 2960         50                   50                         1.0           53
#
# [156 rows x 10 columns]
