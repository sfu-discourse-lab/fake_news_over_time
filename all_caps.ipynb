# %%
import pandas as pd
from dataset_config import BASE_FAKESPEAK_CONFIG, BASE_MISINFOTEXT_CONFIG
from helpers import get_groups, make_output_path, make_output_path_for_type

# %%
fakespeak_config = BASE_FAKESPEAK_CONFIG | {
    "save_cols": [BASE_FAKESPEAK_CONFIG["id_col"], BASE_FAKESPEAK_CONFIG["text_col"], "text_length"]
}

misinfotext_config = BASE_MISINFOTEXT_CONFIG | {
    "save_cols": [BASE_MISINFOTEXT_CONFIG["id_col"], BASE_FAKESPEAK_CONFIG["text_col"], "text_length"]
}

# %%
using_dataset = misinfotext_config

# %%
dataset_df = pd.read_excel(
    using_dataset["input_path"],
    sheet_name=using_dataset["sheet_name"],
    usecols=using_dataset["usecols"]
)
dataset_df.head()
# Out:
#                                           factcheckURL  \
# 0    http://www.politifact.com/arizona/statements/2...
# 1    http://www.politifact.com/california/statement...
# 2    http://www.politifact.com/california/statement...
# 3    http://www.politifact.com/california/statement...
# 4    http://www.politifact.com/california/statement...
# ..                                                 ...
# 650  http://www.politifact.com/wisconsin/statements...
# 651  http://www.politifact.com/wisconsin/statements...
# 652  http://www.politifact.com/wisconsin/statements...
# 653  http://www.politifact.com/wisconsin/statements...
# 654  http://www.politifact.com/wisconsin/statements...
#
#                                            originalURL  \
# 0    https://associatedmediacoverage.com/three-stat...
# 1    https://users.focalbeam.com/fs/distribution:wl...
# 2    http://www.sacbee.com/opinion/op-ed/soapbox/ar...
# 3    https://nocagastax.com/california-gas-tax-hike...
# 4    https://chu.house.gov/media-center/press-relea...
# ..                                                 ...
# 650  https://x.com/ScottWalker/status/9428776407421...
# 651  https://x.com/ScottWalker/status/9511017961011...
# 652  https://x.com/MahlonMitchell/status/9538161542...
# 653  http://dailycaller.com/2018/01/25/hey-look-sen...
# 654                     https://mahlonmitchell.com/bio
#
#                                       originalBodyText  \
# 0    Residents of multiple states will be asked to ...
# 1    Sacramento, CA - United States Senator Dianne ...
# 2    We should anticipate black and gray markets in...
# 3    As a ballot initiative calling for repeal of a...
# 4    WASHINGTON, DC  The House of Representatives t...
# ..                                                 ...
# 650  Road projects across the state are staying on ...
# 651  The last thing we need is more Madison in our ...
# 652  When \n@ScottWalker\n told firefighters we did...
# 653  Now that its 2018, an election year, I would l...
# 654  Mahlon Mitchell currently serves as President ...
#
#                                       originalHeadline originalTextType  \
# 0    Multiple States Have Agreed To Implement A ‘Tw...    News and blog
# 1    U.S. Senator Dianne Feinstein Opposes Prop. 64...    Press release
# 2            Why you should buy a locking gasoline cap    News and blog
# 3     California Gas-Tax-Hike Repeal Campaign Heats Up    News and blog
# 4         Rep. Chu Decries "Heartless" ACA Repeal Vote    Press release
# ..                                                 ...              ...
# 650                                                NaN     Social media
# 651                                                NaN     Social media
# 652                                                NaN     Social media
# 653  HEY LOOK! Senator Tammy Baldwin Is Back In Wis...    News and blog
# 654                       Mahlon Mitchell for Governor    Press release
#
#     originalDate  originalDateYear
# 0     2016-05-06              2016
# 1     2016-07-12              2016
# 2     2017-08-04              2017
# 3     2017-06-15              2017
# 4     2017-05-04              2017
# ..           ...               ...
# 650   2017-12-18              2017
# 651   2018-01-10              2018
# 652   2018-01-18              2018
# 653   2018-01-25              2018
# 654   2018-04-30              2018
#
# [655 rows x 7 columns]

# %%
def get_words(text: str):
    return [token for token in text.split() if token.isalpha()]

def count_uppercase_words(words: list[str]):
    return sum(1 for word in words if word.isupper())

def get_text_length(text: str):
    return len(text.split())

# %%
dataset_df["words"] = dataset_df[using_dataset["text_col"]].apply(get_words)
dataset_df["num_words"] = dataset_df["words"].apply(lambda words: len(words))
dataset_df["num_uppercase_words"] = dataset_df["words"].apply(count_uppercase_words)
dataset_df["proportion_uppercase_words"] = dataset_df["num_uppercase_words"] / dataset_df["num_words"]
dataset_df["text_length"] = dataset_df[using_dataset["text_col"]].apply(get_text_length)

dataset_df
# Out:
#                                           factcheckURL  \
# 0    http://www.politifact.com/arizona/statements/2...
# 1    http://www.politifact.com/california/statement...
# 2    http://www.politifact.com/california/statement...
# 3    http://www.politifact.com/california/statement...
# 4    http://www.politifact.com/california/statement...
# ..                                                 ...
# 650  http://www.politifact.com/wisconsin/statements...
# 651  http://www.politifact.com/wisconsin/statements...
# 652  http://www.politifact.com/wisconsin/statements...
# 653  http://www.politifact.com/wisconsin/statements...
# 654  http://www.politifact.com/wisconsin/statements...
#
#                                            originalURL  \
# 0    https://associatedmediacoverage.com/three-stat...
# 1    https://users.focalbeam.com/fs/distribution:wl...
# 2    http://www.sacbee.com/opinion/op-ed/soapbox/ar...
# 3    https://nocagastax.com/california-gas-tax-hike...
# 4    https://chu.house.gov/media-center/press-relea...
# ..                                                 ...
# 650  https://x.com/ScottWalker/status/9428776407421...
# 651  https://x.com/ScottWalker/status/9511017961011...
# 652  https://x.com/MahlonMitchell/status/9538161542...
# 653  http://dailycaller.com/2018/01/25/hey-look-sen...
# 654                     https://mahlonmitchell.com/bio
#
#                                       originalBodyText  \
# 0    Residents of multiple states will be asked to ...
# 1    Sacramento, CA - United States Senator Dianne ...
# 2    We should anticipate black and gray markets in...
# 3    As a ballot initiative calling for repeal of a...
# 4    WASHINGTON, DC  The House of Representatives t...
# ..                                                 ...
# 650  Road projects across the state are staying on ...
# 651  The last thing we need is more Madison in our ...
# 652  When \n@ScottWalker\n told firefighters we did...
# 653  Now that its 2018, an election year, I would l...
# 654  Mahlon Mitchell currently serves as President ...
#
#                                       originalHeadline originalTextType  \
# 0    Multiple States Have Agreed To Implement A ‘Tw...    News and blog
# 1    U.S. Senator Dianne Feinstein Opposes Prop. 64...    Press release
# 2            Why you should buy a locking gasoline cap    News and blog
# 3     California Gas-Tax-Hike Repeal Campaign Heats Up    News and blog
# 4         Rep. Chu Decries "Heartless" ACA Repeal Vote    Press release
# ..                                                 ...              ...
# 650                                                NaN     Social media
# 651                                                NaN     Social media
# 652                                                NaN     Social media
# 653  HEY LOOK! Senator Tammy Baldwin Is Back In Wis...    News and blog
# 654                       Mahlon Mitchell for Governor    Press release
#
#     originalDate  originalDateYear  \
# 0     2016-05-06              2016
# 1     2016-07-12              2016
# 2     2017-08-04              2017
# 3     2017-06-15              2017
# 4     2017-05-04              2017
# ..           ...               ...
# 650   2017-12-18              2017
# 651   2018-01-10              2018
# 652   2018-01-18              2018
# 653   2018-01-25              2018
# 654   2018-04-30              2018
#
#                                                  words  num_words  \
# 0    [Residents, of, multiple, states, will, be, as...        407
# 1    [CA, United, States, Senator, Dianne, Feinstei...        160
# 2    [We, should, anticipate, black, and, gray, mar...        272
# 3    [As, a, ballot, initiative, calling, for, repe...        372
# 4    [DC, The, House, of, Representatives, today, v...        577
# ..                                                 ...        ...
# 650  [Road, projects, across, the, state, are, stay...         26
# 651  [The, last, thing, we, need, is, more, Madison...         39
# 652  [When, told, firefighters, we, need, to, worry...         37
# 653  [Now, that, its, an, election, I, would, like,...        511
# 654  [Mahlon, Mitchell, currently, serves, as, Pres...        304
#
#      num_uppercase_words  proportion_uppercase_words  text_length
# 0                      0                    0.000000          481
# 1                      4                    0.025000          187
# 2                      4                    0.014706          335
# 3                      0                    0.000000          433
# 4                      2                    0.003466          669
# ..                   ...                         ...          ...
# 650                    0                    0.000000           27
# 651                    0                    0.000000           45
# 652                    1                    0.027027           47
# 653                    2                    0.003914          572
# 654                    0                    0.000000          337
#
# [655 rows x 12 columns]

# %%
all_caps_df = dataset_df[dataset_df["proportion_uppercase_words"] == 1.0]
all_caps_df
# Out:
#                                           factcheckURL  \
# 183  http://www.politifact.com/punditfact/statement...
# 502  http://www.politifact.com/truth-o-meter/statem...
# 506  http://www.politifact.com/truth-o-meter/statem...
# 514  http://www.politifact.com/truth-o-meter/statem...
#
#                                            originalURL  \
# 183  https://x.com/cbrandonellis/status/89526051024...
# 502  https://www.facebook.com/LiberalsAreCool/posts...
# 506           https://www.instagram.com/p/BCYF4O6mhex/
# 514  https://www.facebook.com/OccupyDemocrats/photo...
#
#                                       originalBodyText originalHeadline  \
# 183  BILL CLINTON GAVE NORTH KOREA $5 BILLION AND T...              NaN
# 502  TUITION-FREE PUBLIC UNIVERSITIES AND COLLEGES ...              NaN
# 506  "FIRST THEY IGNORE YOU, THEN THEY LAUGH AT YOU...              NaN
# 514  HAS TAKEN LESS VACATION DAYS THAN ANY OTHER PR...              NaN
#
#     originalTextType originalDate  originalDateYear  \
# 183     Social media   2017-08-09              2017
# 502     Social media   2016-06-02              2016
# 506     Social media   2016-02-29              2016
# 514     Social media   2016-08-20              2016
#
#                                                  words  num_words  \
# 183  [BILL, CLINTON, GAVE, NORTH, KOREA, BILLION, A...         15
# 502  [PUBLIC, UNIVERSITIES, AND, COLLEGES, ARE, JUS...         17
# 506  [THEY, IGNORE, THEN, THEY, LAUGH, AT, THEN, TH...         13
# 514  [HAS, TAKEN, LESS, VACATION, DAYS, THAN, ANY, ...         23
#
#      num_uppercase_words  proportion_uppercase_words  text_length
# 183                   15                         1.0           17
# 502                   17                         1.0           20
# 506                   13                         1.0           18
# 514                   23                         1.0           23

# %%
years, years_dfs = get_groups(dataset_df, using_dataset["year_col"])
years_dfs[0].head()
# Out:
#                                           factcheckURL  \
# 428  http://www.politifact.com/truth-o-meter/statem...
#
#                                            originalURL  \
# 428  https://www.johnmccain.com/Informing/News/Pres...
#
#                                       originalBodyText  \
# 428  "On Monday, Senator Clinton told an audience a...
#
#                                 originalHeadline originalTextType  \
# 428  Statement By John McCain on Hillary Clinton    Press release
#
#     originalDate  originalDateYear  \
# 428   2007-08-23              2007
#
#                                                  words  num_words  \
# 428  [Senator, Clinton, told, an, audience, at, the...        108
#
#      num_uppercase_words  proportion_uppercase_words  text_length
# 428                    0                         0.0          125

# %%
types, types_dfs = get_groups(dataset_df, using_dataset["type_col"])
types_dfs[0].head()
# Out:
#                                         factcheckURL  \
# 0  http://www.politifact.com/arizona/statements/2...
# 2  http://www.politifact.com/california/statement...
# 3  http://www.politifact.com/california/statement...
# 6  http://www.politifact.com/california/statement...
# 7  http://www.politifact.com/california/statement...
#
#                                          originalURL  \
# 0  https://associatedmediacoverage.com/three-stat...
# 2  http://www.sacbee.com/opinion/op-ed/soapbox/ar...
# 3  https://nocagastax.com/california-gas-tax-hike...
# 6  http://www.sfchronicle.com/opinion/openforum/a...
# 7  http://www.sfchronicle.com/politics/article/Th...
#
#                                     originalBodyText  \
# 0  Residents of multiple states will be asked to ...
# 2  We should anticipate black and gray markets in...
# 3  As a ballot initiative calling for repeal of a...
# 6  Recently, a group of special interests threate...
# 7  COSTA MESA, Orange County  It was a surreal vi...
#
#                                     originalHeadline originalTextType  \
# 0  Multiple States Have Agreed To Implement A ‘Tw...    News and blog
# 2          Why you should buy a locking gasoline cap    News and blog
# 3   California Gas-Tax-Hike Repeal Campaign Heats Up    News and blog
# 6  Repeal Californias gas tax increase, says GOP ...    News and blog
# 7  The pro-Russia, pro-weed, pro-Assange GOP cong...    News and blog
#
#   originalDate  originalDateYear  \
# 0   2016-05-06              2016
# 2   2017-08-04              2017
# 3   2017-06-15              2017
# 6   2017-10-19              2017
# 7   2017-09-14              2017
#
#                                                words  num_words  \
# 0  [Residents, of, multiple, states, will, be, as...        407
# 2  [We, should, anticipate, black, and, gray, mar...        272
# 3  [As, a, ballot, initiative, calling, for, repe...        372
# 6  [a, group, of, special, interests, threatened,...        422
# 7  [COSTA, Orange, County, It, was, a, surreal, v...        898
#
#    num_uppercase_words  proportion_uppercase_words  text_length
# 0                    0                    0.000000          481
# 2                    4                    0.014706          335
# 3                    0                    0.000000          433
# 6                    0                    0.000000          495
# 7                    5                    0.005568         1052

# %%
def get_summary_df(dfs: list[pd.DataFrame], years: list[int]):
    return pd.DataFrame(
        [df["text_length"].describe() for df in dfs],
        index=pd.Index(data=years, name="year")
    )

# %% [markdown]
# ## Writing dataframes to excel spreadsheet

# %%
def save_years(writer: pd.ExcelWriter, years: list[int], dfs: list[pd.DataFrame]):
    for year, df in zip(years, dfs):
        df.to_excel(
            writer,
            sheet_name=str(year),
            index=False,
            columns=using_dataset["save_cols"]
        )

    summary_df = get_summary_df(dfs, years)
    summary_df.to_excel(writer, sheet_name="Summary")

# %%
output_path = make_output_path(using_dataset, "all_caps")

writer = pd.ExcelWriter(output_path, engine="xlsxwriter")
save_years(writer, years, years_dfs)
writer.close()

# %%
for type, df in zip(types, types_dfs):
    years, years_dfs = get_groups(df, using_dataset["year_col"])

    output_path = make_output_path_for_type(using_dataset, type, "all_caps")

    writer = pd.ExcelWriter(output_path, engine="xlsxwriter")
    save_years(writer, years, years_dfs)
    writer.close()
