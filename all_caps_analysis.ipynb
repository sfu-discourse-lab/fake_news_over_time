# %%
import pandas as pd
import spacy
from spacy.tokens.doc import Doc
from helpers import load_data, get_groups, is_word

# %%
dataset_df = load_data()
dataset_df.head()
# Out:
#                                                   id  \
# 0  http://www.politifact.com/arizona/statements/2...
# 1  http://www.politifact.com/california/statement...
# 2  http://www.politifact.com/california/statement...
# 3  http://www.politifact.com/california/statement...
# 4  http://www.politifact.com/california/statement...
#
#                                                 text  \
# 0  Residents of multiple states will be asked to ...
# 1  Sacramento, CA - United States Senator Dianne ...
# 2  We should anticipate black and gray markets in...
# 3  As a ballot initiative calling for repeal of a...
# 4  WASHINGTON, DC  The House of Representatives t...
#
#                                             headline      text_type  year
# 0  Multiple States Have Agreed To Implement A ‘Tw...  News and blog  2016
# 1  U.S. Senator Dianne Feinstein Opposes Prop. 64...  Press release  2016
# 2          Why you should buy a locking gasoline cap  News and blog  2017
# 3   California Gas-Tax-Hike Repeal Campaign Heats Up  News and blog  2017
# 4       Rep. Chu Decries "Heartless" ACA Repeal Vote  Press release  2017

# %%
nlp = spacy.load("en_core_web_md")
# Out:
# c:\Users\Adam\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\spacy\util.py:969: UserWarning: [W095] Model 'en_core_web_md' (3.5.0) was trained with spaCy v3.5.0 and may not be 100% compatible with the current version (3.8.8). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# c:\Users\Adam\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\coreferee\manager.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
dataset_df["doc"] = list(nlp.pipe(dataset_df["text"]))

# %%
def get_proportion_upper_to_alpha_tokens(doc: Doc):
    try:
        word_tokens = [token for token in doc if is_word(token)]

        num_upper_tokens = sum(
            1 for token in word_tokens 
            if token.is_upper
        )
        
        num_alpha_tokens = sum(1 for token in word_tokens if token.is_alpha)

        # Sometimes spacy counts non-alpha tokens as uppercase (e.g. WW3).
        # If the proportion exceeds 1, then it's reasonable that
        # the whole text is uppercase.
        if num_upper_tokens > num_alpha_tokens:
            return 1

        return num_upper_tokens / num_alpha_tokens
    except:
        # Some articles don't have any words at all (e.g. just a link),
        # which ends up dividing by zero and throwing an exception.
        # So just return 0 in that case.
        return 0

# %%
dataset_df["proportion_upper_to_alpha_tokens"] = dataset_df["doc"].apply(get_proportion_upper_to_alpha_tokens)
dataset_df = dataset_df.sort_values("proportion_upper_to_alpha_tokens", ascending=False)

dataset_df.head()
# Out:
#                                                 id  \
# 2960  Politifact_Pants on Fire_Social media_621529
# 1437          Politifact_FALSE_Social media_314046
# 1528           Politifact_FALSE_Social media_50740
# 1523          Politifact_FALSE_Social media_843029
# 1522          Politifact_FALSE_Social media_727906
#
#                                                    text headline  \
# 2960  ANYBODY ELSE FIND IT FUNNY THAT ISRAEL WAS ATT...      NaN
# 1437  ITS IMPOSSIBLE TO RIGHTLY GOVERN A\nNATION WIT...      NaN
# 1528  PRESIDENT TRUMP IS ADDRESSING TO THE NATION TO...      NaN
# 1523  IF THE SHOT ACTUALLY\nSAVED LIVES, THEY'D BE P...      NaN
# 1522  JOHN F KENNEDY WAS PLANNING TO END THE FEDERAL...      NaN
#
#          text_type  year                                                doc  \
# 2960  Social media  2023  (ANYBODY, ELSE, FIND, IT, FUNNY, THAT, ISRAEL,...
# 1437  Social media  2019  (ITS, IMPOSSIBLE, TO, RIGHTLY, GOVERN, A, \n, ...
# 1528  Social media  2023  (PRESIDENT, TRUMP, IS, ADDRESSING, TO, THE, NA...
# 1523  Social media  2021  (IF, THE, SHOT, ACTUALLY, \n, SAVED, LIVES, ,,...
# 1522  Social media  2021  (JOHN, F, KENNEDY, WAS, PLANNING, TO, END, THE...
#
#       proportion_upper_to_alpha_tokens
# 2960                               1.0
# 1437                               1.0
# 1528                               1.0
# 1523                               1.0
# 1522                               1.0

# %%
years, years_dfs = get_groups(dataset_df, "year")
years_dfs[0].head()
# Out:
#                                                     id  \
# 433  http://www.politifact.com/truth-o-meter/statem...
# 450  http://www.politifact.com/truth-o-meter/statem...
# 447  http://www.politifact.com/truth-o-meter/statem...
# 435  http://www.politifact.com/truth-o-meter/statem...
# 443  http://www.politifact.com/truth-o-meter/statem...
#
#                                                   text  \
# 433  Washington, D.C., Mar 25 - In response to sugg...
# 450  "There's an inherent conflict of interest....T...
# 447  Global Warming: Given rising voter anger, memb...
# 435  A number of people in the news analysis busine...
# 443  For weeks, President Obama has told us that hi...
#
#                                               headline      text_type  year  \
# 433  Bachmann Demands Truth: Will Obama Administrat...  Press release  2009
# 450  AARP: Helping Seniors Or Helping Itself?\nAdmi...  Press release  2009
# 447                                \nThe Euro-Meddlers  News and blog  2009
# 435          One of these things is not like the other  News and blog  2009
# 443                      Miller Newsletter on Stimulus  Press release  2009
#
#                                                    doc  \
# 433  (Washington, ,, D.C., ,, Mar, 25, -, In, respo...
# 450  (", There, 's, an, inherent, conflict, of, int...
# 447  (Global, Warming, :, Given, rising, voter, ang...
# 435  (A, number, of, people, in, the, news, analysi...
# 443  (For, weeks, ,, President, Obama, has, told, u...
#
#      proportion_upper_to_alpha_tokens
# 433                          0.036585
# 450                          0.033195
# 447                          0.020408
# 435                          0.017316
# 443                          0.013587

# %%
types, types_dfs = get_groups(dataset_df, "text_type")
types_dfs[0].head()
# Out:
#                                                      id  \
# 220   http://www.politifact.com/punditfact/statement...
# 394   http://www.politifact.com/texas/statements/201...
# 325   http://www.politifact.com/punditfact/statement...
# 699               Politifact_FALSE_News and blog_701529
# 1114              Politifact_FALSE_News and blog_576637
#
#                                                    text  \
# 220   If this is true it will mean an opening for an...
# 394   Holder is against Texas Plans for Redistrictin...
# 325   AMID AN INTERVIEW ON CNN’S “AC360,” FORMER PRE...
# 699   This is BIG NEWS.\nAfter December 31, 2021, th...
# 1114  Citizens in **MANY** areas of the U.S.A. are s...
#
#                                                headline      text_type  year  \
# 220   CONFIRMED ! JUSTICE RUTH BADER GINSBURG IS RES...  News and blog  2017
# 394   Attny Gen. Eric Holder is Coming to Austin - W...  News and blog  2011
# 325   MITT ROMNEY: ‘TRUMP HAS SOME VERY SERIOUS EMOT...  News and blog  2018
# 699   HUGE. CDC Withdraws Use of PCR Test for COVID ...  News and blog  2021
# 1114  UPDATED **AGAIN ** 8:12 PM EDT -- TANKS & TROO...  News and blog  2023
#
#                                                     doc  \
# 220   (If, this, is, true, it, will, mean, an, openi...
# 394   (Holder, is, against, Texas, Plans, for, Redis...
# 325   (AMID, AN, INTERVIEW, ON, CNN, ’S, “, AC360, ,...
# 699   (This, is, BIG, NEWS, ., \n, After, December, ...
# 1114  (Citizens, in, *, *, MANY, *, *, areas, of, th...
#
#       proportion_upper_to_alpha_tokens
# 220                           0.612963
# 394                           0.483516
# 325                           0.172414
# 699                           0.150685
# 1114                          0.135065

# %%
def get_summary_df(dfs: list[pd.DataFrame], years: list[int]):
    return pd.DataFrame(
        [df["proportion_upper_to_alpha_tokens"].describe() for df in dfs],
        index=pd.Index(data=years, name="year")
    )

# %% [markdown]
# ## Writing dataframes to excel spreadsheet

# %%
def save_years(writer: pd.ExcelWriter, years: list[int], dfs: list[pd.DataFrame]):
    for year, df in zip(years, dfs):
        df.to_excel(
            writer,
            sheet_name=str(year),
            index=False,
            columns=["id", "year", "proportion_upper_to_alpha_tokens"]
        )

    get_summary_df(dfs, years).to_excel(writer, sheet_name="Proportion Summary")

# %%
writer = pd.ExcelWriter("./output/all_caps.xlsx", engine="xlsxwriter")
save_years(writer, years, years_dfs)
writer.close()

# %%
for type, df in zip(types, types_dfs):
    years, years_dfs = get_groups(df, "year")

    type_str = str(type).lower().replace(" ", "_")

    writer = pd.ExcelWriter(f"./output/{type_str}/all_caps_{type_str}.xlsx", engine="xlsxwriter")
    save_years(writer, years, years_dfs)
    writer.close()
