# %% [markdown]
# # Notebook for Sentiment Analysis Using spaCy
#
# Using spaCy for sentiment analysis (textblob for spacy), we want to find the overall sentiment from the articles in each year.
#
# Currently processes the "Fakespeak-ENG modified.xlsx" file (I've renamed my copy to "Fakespeak_ENG_modified.xlsx" to create a more consistent path), but will eventually be run on data from MisInfoText as well.
#
# From the original data file, we use the following columns: ID, combinedLabel, originalTextType, originalBodyText, originalDateYear
#
# We are processing text from the "originalBodyText" column.

# %%
import spacy
from spacytextblob.spacytextblob import SpacyTextBlob
import pandas as pd
from helpers import load_data, get_groups

# %% [markdown]
# ## Loading articles

# %%
dataset_df = load_data()
dataset_df.head()
# Out:
#                                                   id  \
# 0  http://www.politifact.com/arizona/statements/2...
# 1  http://www.politifact.com/california/statement...
# 2  http://www.politifact.com/california/statement...
# 3  http://www.politifact.com/california/statement...
# 4  http://www.politifact.com/california/statement...
#
#                                                 text  \
# 0  Residents of multiple states will be asked to ...
# 1  Sacramento, CA - United States Senator Dianne ...
# 2  We should anticipate black and gray markets in...
# 3  As a ballot initiative calling for repeal of a...
# 4  WASHINGTON, DC  The House of Representatives t...
#
#                                             headline      text_type  year
# 0  Multiple States Have Agreed To Implement A ‘Tw...  News and blog  2016
# 1  U.S. Senator Dianne Feinstein Opposes Prop. 64...  Press release  2016
# 2          Why you should buy a locking gasoline cap  News and blog  2017
# 3   California Gas-Tax-Hike Repeal Campaign Heats Up  News and blog  2017
# 4       Rep. Chu Decries "Heartless" ACA Repeal Vote  Press release  2017

# %% [markdown]
# ## Analyzing article sentiment using spaCy textblob
#
# [spaCy textblob](https://spacy.io/universe/project/spacy-textblob/)
#
# [Quick References](https://github.com/SamEdwardes/spacytextblob?tab=readme-ov-file#quick-reference)
#
# The two most relevant values returned by textblob are:
# * polarity: a float in [-1.0, 1.0] where -1.0 is extremely negative and 1.0 is extremely positive
# * subjectivity: a float in [0.0, 1.0] where 0.0 is very objective and 1.0 is very subjective

# %%
# make the model
nlp = spacy.load('en_core_web_md')
nlp.add_pipe('spacytextblob')
# Out:
# c:\Users\Adam\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\spacy\util.py:969: UserWarning: [W095] Model 'en_core_web_md' (3.5.0) was trained with spaCy v3.5.0 and may not be 100% compatible with the current version (3.8.8). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# c:\Users\Adam\AppData\Local\Python\pythoncore-3.11-64\Lib\site-packages\coreferee\manager.py:11: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
dataset_df["doc"] = list(nlp.pipe(dataset_df["text"]))
dataset_df["polarity"] = dataset_df["doc"].apply(lambda doc: doc._.blob.polarity)
dataset_df["subjectivity"] = dataset_df["doc"].apply(lambda doc: doc._.blob.subjectivity)

dataset_df.head()
# Out:
#                                                   id  \
# 0  http://www.politifact.com/arizona/statements/2...
# 1  http://www.politifact.com/california/statement...
# 2  http://www.politifact.com/california/statement...
# 3  http://www.politifact.com/california/statement...
# 4  http://www.politifact.com/california/statement...
#
#                                                 text  \
# 0  Residents of multiple states will be asked to ...
# 1  Sacramento, CA - United States Senator Dianne ...
# 2  We should anticipate black and gray markets in...
# 3  As a ballot initiative calling for repeal of a...
# 4  WASHINGTON, DC  The House of Representatives t...
#
#                                             headline      text_type  year  \
# 0  Multiple States Have Agreed To Implement A ‘Tw...  News and blog  2016
# 1  U.S. Senator Dianne Feinstein Opposes Prop. 64...  Press release  2016
# 2          Why you should buy a locking gasoline cap  News and blog  2017
# 3   California Gas-Tax-Hike Repeal Campaign Heats Up  News and blog  2017
# 4       Rep. Chu Decries "Heartless" ACA Repeal Vote  Press release  2017
#
#                                                  doc  polarity  subjectivity
# 0  (Residents, of, multiple, states, will, be, as...  0.026219      0.244984
# 1  (Sacramento, ,, CA, -, United, States, Senator...  0.021154      0.418590
# 2  (We, should, anticipate, black, and, gray, mar... -0.020094      0.394264
# 3  (As, a, ballot, initiative, calling, for, repe...  0.028671      0.420328
# 4  (WASHINGTON, ,, DC,  , The, House, of, Represe... -0.046510      0.418955

# %% [markdown]
# ## Filter the sentiments by year

# %%
years, years_dfs = get_groups(dataset_df, "year")
years_dfs[0].head()
# Out:
#                                                     id  \
# 433  http://www.politifact.com/truth-o-meter/statem...
# 434  http://www.politifact.com/truth-o-meter/statem...
# 435  http://www.politifact.com/truth-o-meter/statem...
# 436  http://www.politifact.com/truth-o-meter/statem...
# 437  http://www.politifact.com/truth-o-meter/statem...
#
#                                                   text  \
# 433  Washington, D.C., Mar 25 - In response to sugg...
# 434  When most Americans talk about the need for he...
# 435  A number of people in the news analysis busine...
# 436  Yesterday President Obama responded to my stat...
# 437  Secretary of Defense Robert Gates is extremely...
#
#                                               headline      text_type  year  \
# 433  Bachmann Demands Truth: Will Obama Administrat...  Press release  2009
# 434  Taxpayer-Funded Abortion Is Not Health-Care Re...  News and blog  2009
# 435          One of these things is not like the other  News and blog  2009
# 436                                                NaN   Social media  2009
# 437  Military to Pledge Oath To Obama, Not Constitu...  News and blog  2009
#
#                                                    doc  polarity  subjectivity
# 433  (Washington, ,, D.C., ,, Mar, 25, -, In, respo... -0.002273      0.178409
# 434  (When, most, Americans, talk, about, the, need...  0.090897      0.390104
# 435  (A, number, of, people, in, the, news, analysi...  0.017545      0.364272
# 436  (Yesterday, President, Obama, responded, to, m...  0.124426      0.503137
# 437  (Secretary, of, Defense, Robert, Gates, is, ex...  0.013445      0.387886

# %% [markdown]
# ## Create summary table
# Next we create a summary table containing the following information for each year:
# * polarity_max: highest polarity
# * polarity_min: lowest polarity
# * polarity_avg: average polarity
# * intensity_avg: average of sentiment scores, ignoring polarity (i.e. average taking absolute values)
# * subjectivity_max: highest subjectivity
# * subjectivity_min: lowest subjectivity
# * subjectivity_avg: average subjectivity
# * positive_article_count: total number of articles with polarity > 0
# * negative_article_count: total number of articles with polarity < 0
# * neutral_article_count: total number of articles with polairity = 0

# %%
def get_summary_table(years: list[int], dfs: list[pd.DataFrame]):
    return pd.DataFrame(
        data={
            "polarity_max": [df["polarity"].max() for df in dfs],
            "polarity_min": [df["polarity"].min() for df in dfs],
            "polarity_avg": [df["polarity"].mean() for df in dfs],
            "intensity_avg": [df["polarity"].abs().mean() for df in dfs],
            "subjectivity_max": [df["subjectivity"].max() for df in dfs],
            "subjectivity_min": [df["subjectivity"].min() for df in dfs],
            "subjectivity_avg": [df["subjectivity"].mean() for df in dfs],
            "positive_article_count": [df["polarity"][df["polarity"] > 0].count() for df in dfs],
            "negative_article_count": [df["polarity"][df["polarity"] < 0].count() for df in dfs],
            "neutral_article_count": [df["polarity"][df["polarity"] == 0].count() for df in dfs],
        },
        index=years
    )

# %%
summary_df = get_summary_table(years, years_dfs)
summary_df
# Out:
#       polarity_max  polarity_min  polarity_avg  intensity_avg  \
# 2009      0.237596     -0.044249      0.070177       0.075650
# 2010      0.375714     -0.094980      0.095071       0.110616
# 2011      0.255000     -0.330000      0.075608       0.103913
# 2012      0.206056     -0.054745      0.079749       0.088951
# 2013      0.250000     -0.262500      0.061929       0.089990
# 2014      0.500000     -0.087500      0.082586       0.093524
# 2015      0.246599     -0.475000      0.017919       0.084202
# 2016      0.800000     -0.700000      0.082629       0.119154
# 2017      0.737500     -1.000000      0.045831       0.117952
# 2018      0.540000     -0.500000      0.055117       0.118204
# 2019      0.700000     -1.000000      0.026148       0.145833
# 2020      0.937500     -1.000000      0.050932       0.134115
# 2021      1.000000     -0.937500      0.046474       0.132025
# 2022      0.840625     -1.000000      0.046710       0.125577
# 2023      1.000000     -1.000000      0.022785       0.135252
# 2024      0.800000     -0.875000      0.057826       0.141656
#
#       subjectivity_max  subjectivity_min  subjectivity_avg  \
# 2009          0.607064          0.178409          0.416238
# 2010          0.608172          0.303333          0.442185
# 2011          0.628070          0.281120          0.436895
# 2012          0.594855          0.312187          0.463587
# 2013          0.637500          0.000000          0.382729
# 2014          0.700000          0.000000          0.415251
# 2015          1.000000          0.000000          0.399886
# 2016          1.000000          0.000000          0.425452
# 2017          1.000000          0.000000          0.415415
# 2018          0.900000          0.000000          0.449506
# 2019          1.000000          0.000000          0.404988
# 2020          1.000000          0.000000          0.356599
# 2021          1.000000          0.000000          0.373022
# 2022          1.000000          0.000000          0.359300
# 2023          1.000000          0.000000          0.363308
# 2024          1.000000          0.000000          0.366642
#
#       positive_article_count  negative_article_count  neutral_article_count
# 2009                      15                       2                      0
# 2010                      20                       3                      0
# 2011                      37                       7                      0
# 2012                      23                       5                      0
# 2013                      47                      10                      4
# 2014                      24                       8                      2
# 2015                      28                       9                      5
# 2016                      66                      19                      6
# 2017                     145                      55                     23
# 2018                      84                      35                      3
# 2019                     138                      84                     61
# 2020                     382                     201                    190
# 2021                     366                     195                    145
# 2022                     246                     123                    113
# 2023                     248                     149                    117
# 2024                     101                      51                     51

# %%
types, types_dfs = get_groups(dataset_df, "text_type")
types_dfs[0].head()
# Out:
#                                                   id  \
# 0  http://www.politifact.com/arizona/statements/2...
# 2  http://www.politifact.com/california/statement...
# 3  http://www.politifact.com/california/statement...
# 6  http://www.politifact.com/california/statement...
# 7  http://www.politifact.com/california/statement...
#
#                                                 text  \
# 0  Residents of multiple states will be asked to ...
# 2  We should anticipate black and gray markets in...
# 3  As a ballot initiative calling for repeal of a...
# 6  Recently, a group of special interests threate...
# 7  COSTA MESA, Orange County  It was a surreal vi...
#
#                                             headline      text_type  year  \
# 0  Multiple States Have Agreed To Implement A ‘Tw...  News and blog  2016
# 2          Why you should buy a locking gasoline cap  News and blog  2017
# 3   California Gas-Tax-Hike Repeal Campaign Heats Up  News and blog  2017
# 6  Repeal Californias gas tax increase, says GOP ...  News and blog  2017
# 7  The pro-Russia, pro-weed, pro-Assange GOP cong...  News and blog  2017
#
#                                                  doc  polarity  subjectivity
# 0  (Residents, of, multiple, states, will, be, as...  0.026219      0.244984
# 2  (We, should, anticipate, black, and, gray, mar... -0.020094      0.394264
# 3  (As, a, ballot, initiative, calling, for, repe...  0.028671      0.420328
# 6  (Recently, ,, a, group, of, special, interests... -0.076841      0.534678
# 7  (COSTA, MESA, ,, Orange, County,  , It, was, a...  0.146143      0.455828

# %% [markdown]
# ## Write output to spreadsheet

# %%
def save_years(writer: pd.ExcelWriter, years: list[int], years_dfs: list[pd.DataFrame]):
    for year, df in zip(years, years_dfs):
        df.to_excel(
            writer,
            sheet_name=str(year),
            index=False,
            columns=["id", "polarity", "subjectivity", "year"]
        )
    
    get_summary_table(years, years_dfs).to_excel(writer, sheet_name="Summary")

# %%
writer = pd.ExcelWriter("./output/sentiment.xlsx", engine="xlsxwriter")
save_years(writer, years, years_dfs)
writer.close()

# %%
for type, df in zip(types, types_dfs):
    years, years_dfs = get_groups(df, "year")

    type_str = str(type).lower().replace(" ", "_")

    writer = pd.ExcelWriter(f"./output/{type_str}/sentiment_{type_str}.xlsx", engine="xlsxwriter")
    save_years(writer, years, years_dfs)
    writer.close()

# %% [markdown]
# ### Now we repeat this for headlines

# %%
# Get rows with existing headlines
dataset_headlines_df = dataset_df[dataset_df["headline"].notna()].copy()
dataset_headlines_df.head()
# Out:
#                                                   id  \
# 0  http://www.politifact.com/arizona/statements/2...
# 1  http://www.politifact.com/california/statement...
# 2  http://www.politifact.com/california/statement...
# 3  http://www.politifact.com/california/statement...
# 4  http://www.politifact.com/california/statement...
#
#                                                 text  \
# 0  Residents of multiple states will be asked to ...
# 1  Sacramento, CA - United States Senator Dianne ...
# 2  We should anticipate black and gray markets in...
# 3  As a ballot initiative calling for repeal of a...
# 4  WASHINGTON, DC  The House of Representatives t...
#
#                                             headline      text_type  year  \
# 0  Multiple States Have Agreed To Implement A ‘Tw...  News and blog  2016
# 1  U.S. Senator Dianne Feinstein Opposes Prop. 64...  Press release  2016
# 2          Why you should buy a locking gasoline cap  News and blog  2017
# 3   California Gas-Tax-Hike Repeal Campaign Heats Up  News and blog  2017
# 4       Rep. Chu Decries "Heartless" ACA Repeal Vote  Press release  2017
#
#                                                  doc  polarity  subjectivity
# 0  (Residents, of, multiple, states, will, be, as...  0.026219      0.244984
# 1  (Sacramento, ,, CA, -, United, States, Senator...  0.021154      0.418590
# 2  (We, should, anticipate, black, and, gray, mar... -0.020094      0.394264
# 3  (As, a, ballot, initiative, calling, for, repe...  0.028671      0.420328
# 4  (WASHINGTON, ,, DC,  , The, House, of, Represe... -0.046510      0.418955

# %%
dataset_headlines_df["doc"] = list(nlp.pipe(dataset_headlines_df["headline"]))
dataset_headlines_df["polarity"] = dataset_headlines_df["doc"].apply(lambda doc: doc._.blob.polarity)
dataset_headlines_df["subjectivity"] = dataset_headlines_df["doc"].apply(lambda doc: doc._.blob.subjectivity)

dataset_headlines_df.head()
# Out:
#                                                   id  \
# 0  http://www.politifact.com/arizona/statements/2...
# 1  http://www.politifact.com/california/statement...
# 2  http://www.politifact.com/california/statement...
# 3  http://www.politifact.com/california/statement...
# 4  http://www.politifact.com/california/statement...
#
#                                                 text  \
# 0  Residents of multiple states will be asked to ...
# 1  Sacramento, CA - United States Senator Dianne ...
# 2  We should anticipate black and gray markets in...
# 3  As a ballot initiative calling for repeal of a...
# 4  WASHINGTON, DC  The House of Representatives t...
#
#                                             headline      text_type  year  \
# 0  Multiple States Have Agreed To Implement A ‘Tw...  News and blog  2016
# 1  U.S. Senator Dianne Feinstein Opposes Prop. 64...  Press release  2016
# 2          Why you should buy a locking gasoline cap  News and blog  2017
# 3   California Gas-Tax-Hike Repeal Campaign Heats Up  News and blog  2017
# 4       Rep. Chu Decries "Heartless" ACA Repeal Vote  Press release  2017
#
#                                                  doc  polarity  subjectivity
# 0  (Multiple, States, Have, Agreed, To, Implement...       0.0           0.0
# 1  (U.S., Senator, Dianne, Feinstein, Opposes, Pr...       0.0           0.0
# 2  (Why, you, should, buy, a, locking, gasoline, ...       0.0           0.0
# 3  (California, Gas, -, Tax, -, Hike, Repeal, Cam...       0.0           0.0
# 4  (Rep., Chu, Decries, ", Heartless, ", ACA, Rep...       0.0           0.0

# %%
years, years_dfs = get_groups(dataset_headlines_df, "year")
years_dfs[0].head()
# Out:
#                                                     id  \
# 433  http://www.politifact.com/truth-o-meter/statem...
# 434  http://www.politifact.com/truth-o-meter/statem...
# 435  http://www.politifact.com/truth-o-meter/statem...
# 437  http://www.politifact.com/truth-o-meter/statem...
# 438  http://www.politifact.com/truth-o-meter/statem...
#
#                                                   text  \
# 433  Washington, D.C., Mar 25 - In response to sugg...
# 434  When most Americans talk about the need for he...
# 435  A number of people in the news analysis busine...
# 437  Secretary of Defense Robert Gates is extremely...
# 438  Now that the so-called stimulus plan is law, w...
#
#                                               headline      text_type  year  \
# 433  Bachmann Demands Truth: Will Obama Administrat...  Press release  2009
# 434  Taxpayer-Funded Abortion Is Not Health-Care Re...  News and blog  2009
# 435          One of these things is not like the other  News and blog  2009
# 437  Military to Pledge Oath To Obama, Not Constitu...  News and blog  2009
# 438                  Two GOP Governors on the Stimulus  News and blog  2009
#
#                                                    doc  polarity  subjectivity
# 433  (Bachmann, Demands, Truth, :, Will, Obama, Adm...     0.000         0.000
# 434  (Taxpayer, -, Funded, Abortion, Is, Not, Healt...     0.000         0.000
# 435  (One, of, these, things, is, not, like, the, o...    -0.125         0.375
# 437  (Military, to, Pledge, Oath, To, Obama, ,, Not...    -0.100         0.100
# 438           (Two, GOP, Governors, on, the, Stimulus)     0.000         0.000

# %%
summary_df = get_summary_table(years, years_dfs)
summary_df
# Out:
#       polarity_max  polarity_min  polarity_avg  intensity_avg  \
# 2009         0.500        -0.500      0.036310       0.132440
# 2010         0.500        -0.500      0.014296       0.114296
# 2011         1.000        -0.800      0.051359       0.138291
# 2012         0.700        -0.500      0.010652       0.110761
# 2013         0.750        -0.650      0.037728       0.131846
# 2014         0.200        -0.700     -0.016770       0.057510
# 2015         0.700        -0.500      0.046667       0.121111
# 2016         0.800        -0.600      0.018342       0.127081
# 2017         0.600        -0.875      0.001976       0.093257
# 2018         1.000        -1.000      0.006384       0.159683
# 2019         0.500        -0.150      0.105456       0.132992
# 2020         0.500        -0.800     -0.045323       0.109658
# 2021         0.625        -1.000      0.000304       0.123265
# 2022         0.500        -0.700      0.035902       0.110416
# 2023         0.800        -1.000      0.008473       0.113216
# 2024         0.250        -0.450      0.026395       0.095082
#
#       subjectivity_max  subjectivity_min  subjectivity_avg  \
# 2009              1.00               0.0          0.240216
# 2010              1.00               0.0          0.201187
# 2011              1.00               0.0          0.257254
# 2012              0.90               0.0          0.238033
# 2013              1.00               0.0          0.211604
# 2014              1.00               0.0          0.175720
# 2015              0.90               0.0          0.197963
# 2016              1.00               0.0          0.293928
# 2017              1.00               0.0          0.211646
# 2018              1.00               0.0          0.268206
# 2019              1.00               0.0          0.336100
# 2020              1.00               0.0          0.238005
# 2021              1.00               0.0          0.279742
# 2022              1.00               0.0          0.243935
# 2023              1.00               0.0          0.271194
# 2024              0.75               0.0          0.271272
#
#       positive_article_count  negative_article_count  neutral_article_count
# 2009                       3                       4                      9
# 2010                       5                       3                     14
# 2011                      12                       6                     26
# 2012                       7                       5                     16
# 2013                      14                       6                     31
# 2014                       4                       5                     18
# 2015                       8                       6                     16
# 2016                      17                      13                     31
# 2017                      36                      29                     94
# 2018                      24                      26                     42
# 2019                      11                       4                      8
# 2020                      17                      37                     66
# 2021                      43                      41                     81
# 2022                      25                      15                     40
# 2023                      21                      24                     55
# 2024                      10                       3                      8

# %%
types, types_dfs = get_groups(dataset_headlines_df, "text_type")
types_dfs[0].head()
# Out:
#                                                   id  \
# 0  http://www.politifact.com/arizona/statements/2...
# 2  http://www.politifact.com/california/statement...
# 3  http://www.politifact.com/california/statement...
# 6  http://www.politifact.com/california/statement...
# 7  http://www.politifact.com/california/statement...
#
#                                                 text  \
# 0  Residents of multiple states will be asked to ...
# 2  We should anticipate black and gray markets in...
# 3  As a ballot initiative calling for repeal of a...
# 6  Recently, a group of special interests threate...
# 7  COSTA MESA, Orange County  It was a surreal vi...
#
#                                             headline      text_type  year  \
# 0  Multiple States Have Agreed To Implement A ‘Tw...  News and blog  2016
# 2          Why you should buy a locking gasoline cap  News and blog  2017
# 3   California Gas-Tax-Hike Repeal Campaign Heats Up  News and blog  2017
# 6  Repeal Californias gas tax increase, says GOP ...  News and blog  2017
# 7  The pro-Russia, pro-weed, pro-Assange GOP cong...  News and blog  2017
#
#                                                  doc  polarity  subjectivity
# 0  (Multiple, States, Have, Agreed, To, Implement...  0.000000      0.000000
# 2  (Why, you, should, buy, a, locking, gasoline, ...  0.000000      0.000000
# 3  (California, Gas, -, Tax, -, Hike, Repeal, Cam...  0.000000      0.000000
# 6  (Repeal, Californias, gas, tax, increase, ,, s...  0.000000      0.000000
# 7  (The, pro, -, Russia, ,, pro, -, weed, ,, pro,... -0.388889      0.833333

# %%
writer = pd.ExcelWriter("./output/sentiment_headlines.xlsx", engine="xlsxwriter")
save_years(writer, years, years_dfs)
writer.close()

# %%
for type, df in zip(types, types_dfs):
    years, years_dfs = get_groups(df, "year")

    type_str = str(type).lower().replace(" ", "_")

    writer = pd.ExcelWriter(f"./output/{type_str}/sentiment_{type_str}_headlines.xlsx", engine="xlsxwriter")
    save_years(writer, years, years_dfs)
    writer.close()
