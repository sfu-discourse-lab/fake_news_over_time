# %%
import os
from helpers import generate_wordclouds_for_years

# %% [markdown]
# Create output folders, if don't already exist

# %%
ngrams_output_base_dir = "./visualization/ngrams/word_clouds"

# %%
# Body text
text_all_dir = f"{ngrams_output_base_dir}/text/all"
text_social_media_dir = f"{ngrams_output_base_dir}/text/social_media"
text_news_and_blog_dir = f"{ngrams_output_base_dir}/text/news_and_blog"
text_press_release_dir = f"{ngrams_output_base_dir}/text/press_release"

os.makedirs(text_all_dir, exist_ok=True)
os.makedirs(text_social_media_dir, exist_ok=True)
os.makedirs(text_news_and_blog_dir, exist_ok=True)
os.makedirs(text_press_release_dir, exist_ok=True)

# Headline text
headline_all_dir = f"{ngrams_output_base_dir}/headline/all"
headline_social_media_dir = f"{ngrams_output_base_dir}/headline/social_media"
headline_news_and_blog_dir = f"{ngrams_output_base_dir}/headline/news_and_blog"
headline_press_release_dir = f"{ngrams_output_base_dir}/headline/press_release"

os.makedirs(headline_all_dir, exist_ok=True)
os.makedirs(headline_social_media_dir, exist_ok=True)
os.makedirs(headline_news_and_blog_dir, exist_ok=True)
os.makedirs(headline_press_release_dir, exist_ok=True)

# %% [markdown]
# ### Generate wordclouds for ngrams in body text

# %%
def generate_wordclouds(filename: str):
    return generate_wordclouds_for_years(filename, "ngram_text", "ngram_count")

# %% [markdown]
# All text types

# %%
for year, wordcloud in generate_wordclouds("./data/MisInfoText/Analysis_output/MisInfoText_ngrams.xlsx"):
    wordcloud.to_file(f"{text_all_dir}/{year}.png")

for year, wordcloud in generate_wordclouds("./data/Fakespeak-ENG/Analysis_output/Fakespeak_ngrams.xlsx"):
    wordcloud.to_file(f"{text_all_dir}/{year}.png")

# %% [markdown]
# Social media

# %%
for year, wordcloud in generate_wordclouds("./data/MisInfoText/Analysis_output/social_media/MisInfoText_social_media_ngrams.xlsx"):
    wordcloud.to_file(f"{text_social_media_dir}/{year}.png")

for year, wordcloud in generate_wordclouds("./data/Fakespeak-ENG/Analysis_output/social_media/Fakespeak_social_media_ngrams.xlsx"):
    wordcloud.to_file(f"{text_social_media_dir}/{year}.png")

# %% [markdown]
# News and blog

# %%
for year, wordcloud in generate_wordclouds("./data/MisInfoText/Analysis_output/news_and_blog/MisInfoText_news_and_blog_ngrams.xlsx"):
    wordcloud.to_file(f"{text_news_and_blog_dir}/{year}.png")

for year, wordcloud in generate_wordclouds("./data/Fakespeak-ENG/Analysis_output/news_and_blog/Fakespeak_news_and_blog_ngrams.xlsx"):
    wordcloud.to_file(f"{text_news_and_blog_dir}/{year}.png")

# %% [markdown]
# Press release

# %%
for year, wordcloud in generate_wordclouds("./data/MisInfoText/Analysis_output/press_release/MisInfoText_press_release_ngrams.xlsx"):
    wordcloud.to_file(f"{text_press_release_dir}/{year}.png")

for year, wordcloud in generate_wordclouds("./data/Fakespeak-ENG/Analysis_output/press_release/Fakespeak_press_release_ngrams.xlsx"):
    wordcloud.to_file(f"{text_press_release_dir}/{year}.png")

# %% [markdown]
# ### Generate wordclouds for ngrams in headline text

# %% [markdown]
# All text types

# %%
for year, wordcloud in generate_wordclouds("./data/MisInfoText/Analysis_output/MisInfoText_ngrams_headlines.xlsx"):
    wordcloud.to_file(f"{headline_all_dir}/{year}.png")

for year, wordcloud in generate_wordclouds("./data/Fakespeak-ENG/Analysis_output/Fakespeak_ngrams_headlines.xlsx"):
    wordcloud.to_file(f"{headline_all_dir}/{year}.png")

# %% [markdown]
# Social media (not very interesting because almost all social media articles don't have headlines)

# %%
for year, wordcloud in generate_wordclouds("./data/MisInfoText/Analysis_output/social_media/MisInfoText_social_media_ngrams_headlines.xlsx"):
    wordcloud.to_file(f"{headline_social_media_dir}/{year}.png")

for year, wordcloud in generate_wordclouds("./data/Fakespeak-ENG/Analysis_output/social_media/Fakespeak_social_media_ngrams_headlines.xlsx"):
    wordcloud.to_file(f"{headline_social_media_dir}/{year}.png")

# %% [markdown]
# News and blog

# %%
for year, wordcloud in generate_wordclouds("./data/MisInfoText/Analysis_output/news_and_blog/MisInfoText_news_and_blog_ngrams_headlines.xlsx"):
    wordcloud.to_file(f"{headline_news_and_blog_dir}/{year}.png")

for year, wordcloud in generate_wordclouds("./data/Fakespeak-ENG/Analysis_output/news_and_blog/Fakespeak_news_and_blog_ngrams_headlines.xlsx"):
    wordcloud.to_file(f"{headline_news_and_blog_dir}/{year}.png")

# %% [markdown]
# Press release

# %%
for year, wordcloud in generate_wordclouds("./data/MisInfoText/Analysis_output/press_release/MisInfoText_press_release_ngrams_headlines.xlsx"):
    wordcloud.to_file(f"{headline_press_release_dir}/{year}.png")

for year, wordcloud in generate_wordclouds("./data/Fakespeak-ENG/Analysis_output/press_release/Fakespeak_press_release_ngrams_headlines.xlsx"):
    wordcloud.to_file(f"{headline_press_release_dir}/{year}.png")
