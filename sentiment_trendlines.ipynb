# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import Axes
import seaborn as sns
from helpers import get_years_dfs

# %%
sns.set_theme(context="paper", font_scale=2.5)

# %%
def get_full_df(input_path: str):
    return pd.concat(get_years_dfs(input_path))

# %%
def plot_polarities(df: pd.DataFrame, title: str, save_path: str):
    # Mosaic pattern allows filling in with empty space 
    # to center the single bottom row
    fig, ax_dict = plt.subplot_mosaic(
        mosaic="""AABB
        .CC.""",
        figsize=(24, 12), 
    )

    fig.suptitle(title)

    axes_flat = list(ax_dict.values())

    def plot_on_ax(i: int, df: pd.DataFrame, ax_title: str):
        ax = axes_flat[i]
        
        sns.lineplot(x="year", y="polarity", data=df, ax=ax, marker="o", linewidth=3, markersize=10)
        
        ax.set_title(ax_title)

        ax.set_xlabel("year")
        ax.set_xticks(df["year"].unique())
        ax.tick_params(axis="x", rotation=45)

        ax.set_ylabel("")

    positive_polarities_df = df[df["polarity"] > 0]
    negative_polarities_df = df[df["polarity"] < 0]

    plot_on_ax(0, df, "All polarities")
    plot_on_ax(1, positive_polarities_df, "Positive polarities")
    plot_on_ax(2, negative_polarities_df, "Negative polarities")

    plt.tight_layout()

    plt.draw()
    plt.savefig(save_path)

    plt.show()

# %%
def plot_subjectivity(df: pd.DataFrame, title: str, save_path: str):
    plt.figure(figsize=(12, 8))
    plt.title(title)
    
    sns.lineplot(x="year", y="subjectivity", data=df, marker="o", linewidth=3, markersize=10)

    plt.xticks(df["year"].unique(), rotation=45)
    plt.ylabel("")

    plt.tight_layout()

    plt.draw()
    plt.savefig(save_path)

    plt.show()

# %% [markdown]
# ### Body text

# %% [markdown]
# #### All text types

# %%
all_types_df = get_full_df("./output/sentiment.xlsx")
all_types_df.head()
# Out:
#                                                   id  polarity  subjectivity  \
# 0  http://www.politifact.com/truth-o-meter/statem... -0.002273      0.178409
# 1  http://www.politifact.com/truth-o-meter/statem...  0.090897      0.390104
# 2  http://www.politifact.com/truth-o-meter/statem...  0.017545      0.364272
# 3  http://www.politifact.com/truth-o-meter/statem...  0.124426      0.503137
# 4  http://www.politifact.com/truth-o-meter/statem...  0.013445      0.387886
#
#    year
# 0  2009
# 1  2009
# 2  2009
# 3  2009
# 4  2009

# %%
plot_polarities(
    df=all_types_df, 
    title="Body text sentiment polarities for all text types",
    save_path="./visualization/sentiment/body_polarities_all_types.png"
)

# %%
plot_subjectivity(
    df=all_types_df,
    title="Body text subjectivity for all text types",
    save_path="./visualization/sentiment/body_subjectivity_all_types.png"
)

# %% [markdown]
# #### News and blog

# %%
news_and_blog_df = get_full_df("./output/news_and_blog/sentiment_news_and_blog.xlsx")
news_and_blog_df.head()
# Out:
#                                                   id  polarity  subjectivity  \
# 0  http://www.politifact.com/truth-o-meter/statem...  0.090897      0.390104
# 1  http://www.politifact.com/truth-o-meter/statem...  0.017545      0.364272
# 2  http://www.politifact.com/truth-o-meter/statem...  0.013445      0.387886
# 3  http://www.politifact.com/truth-o-meter/statem...  0.107810      0.384300
# 4  http://www.politifact.com/truth-o-meter/statem...  0.014387      0.517553
#
#    year
# 0  2009
# 1  2009
# 2  2009
# 3  2009
# 4  2009

# %%
plot_polarities(
    df=news_and_blog_df, 
    title="Body text sentiment polarities for news and blog",
    save_path="./visualization/sentiment/body_polarities_news_and_blog.png"
)

# %%
plot_subjectivity(
    df=news_and_blog_df,
    title="Body text subjectivity for news and blog",
    save_path="./visualization/sentiment/body_subjectivity_news_and_blog.png"
)

# %% [markdown]
# #### Press release

# %%
press_release_df = get_full_df("./output/press_release/sentiment_press_release.xlsx")
press_release_df.head()
# Out:
#                                                   id  polarity  subjectivity  \
# 0  http://www.politifact.com/truth-o-meter/statem... -0.002273      0.178409
# 1  http://www.politifact.com/truth-o-meter/statem... -0.044249      0.607064
# 2  http://www.politifact.com/truth-o-meter/statem...  0.075942      0.485119
# 3  http://www.politifact.com/truth-o-meter/statem...  0.237596      0.341986
# 4  http://www.politifact.com/truth-o-meter/statem...  0.114837      0.437043
#
#    year
# 0  2009
# 1  2009
# 2  2009
# 3  2009
# 4  2009

# %%
plot_polarities(
    df=press_release_df, 
    title="Body text sentiment polarities for press release",
    save_path="./visualization/sentiment/body_polarities_press_release.png"
)

# %%
plot_subjectivity(
    df=press_release_df,
    title="Body text subjectivity for press release",
    save_path="./visualization/sentiment/body_subjectivity_press_release.png"
)

# %% [markdown]
# #### Social media

# %%
social_media_df = get_full_df("./output/social_media/sentiment_social_media.xlsx")
social_media_df.head()
# Out:
#                                                   id  polarity  subjectivity  \
# 0  http://www.politifact.com/truth-o-meter/statem...  0.124426      0.503137
# 0  http://www.politifact.com/rhode-island/stateme... -0.050000      0.400000
# 0  http://www.politifact.com/florida/statements/2...  0.000000      0.100000
# 1  http://www.politifact.com/florida/statements/2... -0.125000      0.100000
# 2  http://www.politifact.com/punditfact/statement...  0.027778      0.444444
#
#    year
# 0  2009
# 0  2010
# 0  2013
# 1  2013
# 2  2013

# %%
plot_polarities(
    df=social_media_df, 
    title="Body text sentiment polarities for social media",
    save_path="./visualization/sentiment/body_polarities_social_media.png"
)

# %%
plot_subjectivity(
    df=social_media_df,
    title="Body text subjectivity for social media",
    save_path="./visualization/sentiment/body_subjectivity_social_media.png"
)

# %% [markdown]
# ### Headline text
#
# Excluding social media headlines because there are so little of them.

# %% [markdown]
# #### All text types

# %%
all_types_headlines_df = get_full_df("./output/sentiment_headlines.xlsx")
all_types_headlines_df.head()
# Out:
#                                                   id  polarity  subjectivity  \
# 0  http://www.politifact.com/truth-o-meter/statem...     0.000         0.000
# 1  http://www.politifact.com/truth-o-meter/statem...     0.000         0.000
# 2  http://www.politifact.com/truth-o-meter/statem...    -0.125         0.375
# 3  http://www.politifact.com/truth-o-meter/statem...    -0.100         0.100
# 4  http://www.politifact.com/truth-o-meter/statem...     0.000         0.000
#
#    year
# 0  2009
# 1  2009
# 2  2009
# 3  2009
# 4  2009

# %%
plot_polarities(
    df=all_types_headlines_df, 
    title="Headline text sentiment polarities for all text types",
    save_path="./visualization/sentiment/headline_polarities_all_types.png"
)

# %%
plot_subjectivity(
    df=all_types_headlines_df,
    title="Headline text subjectivity for all text types",
    save_path="./visualization/sentiment/headline_subjectivity_all_types.png"
)

# %% [markdown]
# #### News and blog

# %%
news_and_blog_headlines_df = get_full_df("./output/news_and_blog/sentiment_news_and_blog_headlines.xlsx")
news_and_blog_headlines_df.head()
# Out:
#                                                   id  polarity  subjectivity  \
# 0  http://www.politifact.com/truth-o-meter/statem...     0.000         0.000
# 1  http://www.politifact.com/truth-o-meter/statem...    -0.125         0.375
# 2  http://www.politifact.com/truth-o-meter/statem...    -0.100         0.100
# 3  http://www.politifact.com/truth-o-meter/statem...     0.000         0.000
# 4  http://www.politifact.com/truth-o-meter/statem...     0.450         0.550
#
#    year
# 0  2009
# 1  2009
# 2  2009
# 3  2009
# 4  2009

# %%
plot_polarities(
    df=news_and_blog_headlines_df, 
    title="Headline text sentiment polarities for news and blog",
    save_path="./visualization/sentiment/headline_polarities_news_and_blog.png"
)

# %%
plot_subjectivity(
    df=news_and_blog_headlines_df,
    title="Headline text subjectivity for news and blog",
    save_path="./visualization/sentiment/headline_subjectivity_news_and_blog.png"
)

# %% [markdown]
# #### Press release

# %%
press_release_headlines_df = get_full_df("./output/press_release/sentiment_press_release_headlines.xlsx")
press_release_headlines_df.head()
# Out:
#                                                   id  polarity  subjectivity  \
# 0  http://www.politifact.com/truth-o-meter/statem...       0.0           0.0
# 1  http://www.politifact.com/truth-o-meter/statem...       0.0           0.0
# 2  http://www.politifact.com/truth-o-meter/statem...       0.0           0.0
# 3  http://www.politifact.com/truth-o-meter/statem...       0.0           1.0
# 4  http://www.politifact.com/truth-o-meter/statem...       0.5           0.5
#
#    year
# 0  2009
# 1  2009
# 2  2009
# 3  2009
# 4  2009

# %%
plot_polarities(
    df=press_release_headlines_df, 
    title="Headline text sentiment polarities for press release",
    save_path="./visualization/sentiment/headline_polarities_press_release.png"
)

# %%
plot_subjectivity(
    df=press_release_headlines_df,
    title="Headline text subjectivity for press release",
    save_path="./visualization/sentiment/headline_subjectivity_press_release.png"
)
